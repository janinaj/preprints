# %% [markdown]
# ## READ DATA

# %%
# parse date string and ignore the microseconds

from datetime import datetime

def parse_date(datestr):
    try:
        dt = datetime.strptime(datestr, '%Y-%m-%d')
        dt_format = 'ymd'
    except:
        try:
            dt = datetime.strptime(datestr, '%Y-%m')
            dt_format = 'ym'
        except:
            dt = datetime.strptime(datestr, '%Y')
            dt_format = 'y'
                    
    
    return dt, dt_format

# %%
import os, json

OSF_DATA = os.path.join('..', '..', 'data', 'osf', 'osf_all_data.json')

cutoff_date = parse_date('2019-6-1')[0]

main_subjects = set()

osf_records = []
with open(OSF_DATA, 'r') as f:
    for line in f:
        record = json.loads(line)

        record['date_published'] = parse_date(record['osf_record']['attributes']['date_published'][:10])[0]
        
        if record['date_published'] < cutoff_date and \
            (record['osf_record']['attributes']['date_withdrawn'] is None or 
            parse_date(record['osf_record']['attributes']['date_withdrawn'][:10])[0] >= cutoff_date):
            osf_records.append(record)
            
            for subject in record['osf_record']['attributes']['subjects']:
                main_subjects.add(subject[0]['text'])

# %%
len(osf_records)
# Out:
# 28398

# %%
OSF_PREPRINT_SERVER_FILE = os.path.join('..', '..', 'raw_data', 'osf-preprint-providers.json')

osf_servers = []
with open(OSF_PREPRINT_SERVER_FILE, 'r') as f:
    data = json.load(f)
    
    for server in data['data']:
        osf_servers.append(server['id'])
        #preprint_servers[server['id']] = { 'name' : server['attributes']['name'] }

# %%
osf_dois = []
for record in osf_records:
    osf_dois.append(record['doi'])

# %% [markdown]
# ## SAVE ANALYSIS FILE CONTAINING SUBSET OF METADATA

# %%
import pandas as pd

OSF_ANALYSIS_FILE = os.path.join('..', '..', 'data', 'osf_analysis.csv')

osf_analysis_records = []
for record in osf_records:
    server = record['osf_record']['relationships']['provider']['links']['related']['href'].replace( \
                'https://api.osf.io/v2/providers/preprints/', '').replace('/?format=json', '')
    
    record_subjects = set()
    for subject in record['osf_record']['attributes']['subjects']:
        record_subjects.add(subject[0]['text'])
        
    if record['osf_record']['attributes']['doi'] is not None:
        record['osf_record']['attributes']['doi'] = record['osf_record']['attributes']['doi'].lower()
    
        if record['osf_record']['attributes']['doi'] == \
            record['osf_record']['links']['preprint_doi'].replace('https://doi.org/', ''):
            record['osf_record']['attributes']['doi'] = None
            
        if 'osf.io/' in record['osf_record']['attributes']['doi']:
            published_doi_is_osf_doi = True
            
            if record['osf_record']['attributes']['doi'] in osf_dois:
                published_doi_is_osf_record = True
            else:
                published_doi_is_osf_record = False
        else:
            published_doi_is_osf_doi = False
    
    if record['osf_peerrev_publications'] is not None and 'message' in record['osf_peerrev_publications']:
        osf_peerrev_publication = record['osf_peerrev_publications']['message']
        try:
            published_online_date = osf_peerrev_publication['published-online']['date-parts'][0]
        except:
            published_online_date = None

        try:
            published_print_date = osf_peerrev_publication['published-print']['date-parts'][0]
        except:
            published_print_date = None

        try:
            issued_date = osf_peerrev_publication['issued']['date-parts'][0]
        except:
            issued_date = None

        try:
            created_date = osf_peerrev_publication['created']['date-parts'][0]
        except:
            created_date = None
        
        
        if osf_peerrev_publication['type'] == 'posted-content':
            published_doi_is_preprint = True
        else:
            published_doi_is_preprint = False
            
        published_title = osf_peerrev_publication['title']
        
        published_authors = []
        
        if 'author' in osf_peerrev_publication:
            for author in osf_peerrev_publication['author']:
                author_name = ''
                if 'given' in author:
                    author_name = author['given']

                if 'family' in author:
                    author_name = author_name + ' ' + author['family']

                if 'suffix' in author:
                    author_name = author_name + ' ' + author['suffix']

                # it seems that if name is present, there are no other name fields (e.g. given, family)
                if 'name' in author:
                    author_name = author_name + ' ' + author['name']

                published_authors.append(author_name)
            
    else:
        published_online_date = None
        published_print_date = None
        issued_date = None
        created_date = None
        
        published_doi_is_preprint = None
        published_doi_is_osf_record = True
        published_doi_is_osf_record = None
        published_doi_is_osf_doi = None
        
        published_title = None
        published_authors = []
    
    preprint_authors = []
    for author_list in record['osf_authors'][0]:
        for author in author_list['data']:
            if author['attributes']['bibliographic']:
                try:
                    author_data = author['embeds']['users']['data']['attributes']
                except Exception as e:
                    author_data = author['embeds']['users']['errors'][0]['meta']
        
                preprint_authors.append(author_data['full_name'])
    
    row = {
        'id' : 'osf.io/' + record['id'],
        'preprint_title' : record['osf_record']['attributes']['title'],
        'server' : server,
        'preprint_date_published' : record['date_published'],
        'submitted_doi' : record['osf_record']['attributes']['doi'],
        'published_online_date' : published_online_date,
        'published_print_date' : published_print_date,
        'issued_date' : issued_date,
        'created_date' : created_date,
        'main_subjects' : len(record_subjects),
        'specific_subjects' : len(record['osf_record']['attributes']['subjects']),
        'preprint_authors' : preprint_authors,
        'preprint_total_authors' : len(preprint_authors),
        'published_title' : published_title,
        'published_authors' : published_authors,
        'published_total_authors' : len(published_authors),
        'published_doi_is_preprint' : published_doi_is_preprint,
        'published_doi_is_osf_record' : published_doi_is_osf_record,
        'published_doi_is_osf_doi' : published_doi_is_osf_doi, # not necessarily an OSF record
    }
    
    for subject in main_subjects:
        if subject in record_subjects:
            row['SUBJ_' + subject] = 1
        else:
            row['SUBJ_' + subject] = 0
    
    osf_analysis_records.append(row)
    
df_osf_analysis_records = pd.DataFrame(osf_analysis_records)
df_osf_analysis_records.to_csv(OSF_ANALYSIS_FILE)

# %% [markdown]
# ## PRELIMINARY STATISTICS

# %% [markdown]
# ### TOTAL NUMBER OF PUBLICATIONS AND AUTHORS PER PUBLICATION

# %%
import numpy as np
import statistics

preprint_servers = {}
for server in osf_servers:
    preprint_servers[server] = {'records' : 0,
                                'date of first submission' : None,
                                'records with submitted DOIs' : 0,
                                'records with OSF-related DOIs' : 0,
                                'records with OSF publication DOIs' : 0,
                                'authors per record' : [] }

submitted_osf_dois = []
    
for record in osf_records:
    server = record['osf_record']['relationships']['provider']['links']['related']['href'].replace( \
                'https://api.osf.io/v2/providers/preprints/', '').replace('/?format=json', '')
    
    preprint_servers[server]['records'] += 1
    
    if preprint_servers[server]['date of first submission'] == None or \
        record['date_published'] < preprint_servers[server]['date of first submission']:
        preprint_servers[server]['date of first submission'] = record['date_published']

    if record['osf_record']['attributes']['doi'] is not None and \
        record['osf_record']['attributes']['doi'] != \
        record['osf_record']['links']['preprint_doi'].replace('https://doi.org/', ''):
        preprint_servers[server]['records with submitted DOIs'] += 1
        
        if 'osf.io' in record['osf_record']['attributes']['doi'].lower():
            preprint_servers[server]['records with OSF-related DOIs'] += 1
            
            if record['osf_record']['attributes']['doi'].lower() in osf_dois:
                preprint_servers[server]['records with OSF publication DOIs'] += 1
                
                try:
                    peerrev_dp = parse_date('-'.join([str(dt) for dt in \
                                      record['osf_peerrev_publications']['message']['issued']['date-parts'][0]]))[0]
                except:
                    '-'.join([str(dt) for dt in \
                                      record['osf_peerrev_publications']['message']['issued']['date-parts'][0]])
                             
                submitted_osf_dois.append({
                    'preprint' : 'osf.io/' + record['id'],
                    'submitted_doi' : record['osf_record']['attributes']['doi'].lower(),
                    'preprint_date_published' : record['date_published'],
                    'peerrev_date_published' : peerrev_dp,
                    'date_diff' : peerrev_dp - record['date_published']
                })
                
    if len(record['osf_authors'][0]) > 0:
        preprint_servers[server]['authors per record'].append(\
            record['osf_authors'][0][0]['links']['meta']['total_bibliographic'])
    else:
        preprint_servers[server]['authors per record'].append(0)
            
# get author statistics
for server in preprint_servers.keys():
    if preprint_servers[server]['date of first submission'] is not None:
        preprint_servers[server]['date of first submission'] = \
            preprint_servers[server]['date of first submission'].isoformat()
    
    if len(preprint_servers[server]['authors per record']) > 0:
        q75, q25 = np.percentile(preprint_servers[server]['authors per record'], [75 ,25])
        
        if q25 == q75:
            preprint_servers[server]['authors-IQR'] = int(q25)
        else:
            preprint_servers[server]['authors-IQR'] = '{}-{}'.format(int(q25), int(q75))
            
        preprint_servers[server]['authors-median'] = statistics.median(preprint_servers[server]['authors per record'])
        preprint_servers[server]['authors-range'] = '{}-{}'.format(\
           min(preprint_servers[server]['authors per record']), max(preprint_servers[server]['authors per record']))
    else:
        preprint_servers[server]['authors-IQR'] = '--'
        preprint_servers[server]['authors-median'] = '--'
        preprint_servers[server]['authors-range'] = '--'

# %%
import pandas as pd

pd.DataFrame(submitted_osf_dois)
# Out:
#    date_diff peerrev_date_published      preprint preprint_date_published  \
# 0     0 days             2019-05-29  osf.io/pz23f              2019-05-29
# 1  -536 days             2017-10-21  osf.io/hz9m4              2019-04-10
# 2  -536 days             2017-10-21  osf.io/kshf3              2019-04-10
# 3  -160 days             2018-09-28  osf.io/nua2x              2019-03-07
# 4    -2 days             2019-03-04  osf.io/y5du2              2019-03-06
# 5  -208 days             2018-08-06  osf.io/gs67u              2019-03-02
# 6    -1 days             2019-02-27  osf.io/4mkts              2019-02-28
# 7    -1 days             2019-02-27  osf.io/6pxcy              2019-02-28
# 8    -1 days             2019-02-27  osf.io/75z3n              2019-02-28
# 9   -74 days             2018-12-15  osf.io/tca4z              2019-02-27
# 10    0 days             2019-02-26  osf.io/p4wue              2019-02-26
# 11    0 days             2019-02-25  osf.io/ucgkj              2019-02-25
# 12  -75 days             2018-12-11  osf.io/t64av              2019-02-24
# 13  -12 days             2019-01-16  osf.io/hke6j              2019-01-28
# 14  -11 days             2019-01-16  osf.io/jcx5g              2019-01-27
# 15  -12 days             2019-01-09  osf.io/re4bs              2019-01-21
# 16  -11 days             2019-01-09  osf.io/yfq9b              2019-01-20
# 17   -9 days             2019-01-09  osf.io/n73tx              2019-01-18
# 18  -36 days             2018-12-13  osf.io/3dqmy              2019-01-18
# 19   -9 days             2019-01-09  osf.io/f6pk7              2019-01-18
# 20   -8 days             2019-01-09  osf.io/wgh5s              2019-01-17
# 21   -8 days             2019-01-09  osf.io/f2dpc              2019-01-17
# 22   -8 days             2019-01-09  osf.io/mq54d              2019-01-17
# 23   -8 days             2019-01-09  osf.io/4xpnv              2019-01-17
# 24   -9 days             2018-12-13  osf.io/fd7uw              2018-12-22
# 25   -9 days             2018-12-13  osf.io/umsxr              2018-12-22
# 26   -8 days             2018-12-13  osf.io/2psjt              2018-12-21
# 27   -7 days             2018-12-13  osf.io/z4vqg              2018-12-20
# 28   -7 days             2018-12-13  osf.io/hczdq              2018-12-20
# 29   -6 days             2018-12-13  osf.io/mxjpk              2018-12-19
# 30   -6 days             2018-12-13  osf.io/bsxvj              2018-12-19
# 31   -6 days             2018-12-13  osf.io/zgxyv              2018-12-19
# 32   -4 days             2018-12-13  osf.io/utmbg              2018-12-17
# 33   -4 days             2018-12-13  osf.io/ga8hv              2018-12-17
#
#             submitted_doi
# 0   10.31227/osf.io/62rks
# 1   10.31227/osf.io/he853
# 2   10.31227/osf.io/he853
# 3   10.31219/osf.io/79ext
# 4   10.31227/osf.io/ksy4d
# 5   10.31227/osf.io/wxsrg
# 6   10.31227/osf.io/7hm4p
# 7   10.31227/osf.io/7hm4p
# 8   10.31227/osf.io/7hm4p
# 9   10.31227/osf.io/rfsyx
# 10  10.31227/osf.io/rb5d4
# 11  10.31227/osf.io/4cdr8
# 12  10.31234/osf.io/fh7zb
# 13  10.31227/osf.io/fh7dp
# 14  10.31227/osf.io/fh7dp
# 15  10.31227/osf.io/naxz3
# 16  10.31227/osf.io/naxz3
# 17  10.31227/osf.io/naxz3
# 18  10.31227/osf.io/3wgmv
# 19  10.31227/osf.io/naxz3
# 20  10.31227/osf.io/naxz3
# 21  10.31227/osf.io/naxz3
# 22  10.31227/osf.io/naxz3
# 23  10.31227/osf.io/naxz3
# 24  10.31227/osf.io/3wgmv
# 25  10.31227/osf.io/3wgmv
# 26  10.31227/osf.io/3wgmv
# 27  10.31227/osf.io/3wgmv
# 28  10.31227/osf.io/3wgmv
# 29  10.31227/osf.io/3wgmv
# 30  10.31227/osf.io/3wgmv
# 31  10.31227/osf.io/3wgmv
# 32  10.31227/osf.io/3wgmv
# 33  10.31227/osf.io/3wgmv

# %%
import pandas as pd

df = pd.DataFrame(preprint_servers).transpose()
df = df.drop(columns = 'authors per record')

df.to_csv(os.path.join('..', '..', 'data_analysis_results', 'osf.csv'))

df
# Out:
#               authors-IQR authors-median authors-range  \
# africarxiv            1-2              1          1-21
# agrixiv               1-2              1          1-23
# arabixiv                1              1           1-8
# bodoarxiv               1              1           1-2
# eartharxiv            2-5              4          1-35
# ecoevorxiv            3-6              4          1-53
# ecsarxiv              1-5              3          1-18
# engrxiv               1-4              2          1-21
# focusarchive          1-3              2           1-9
# frenxiv               1-2              1          1-22
# inarxiv               1-2              1          1-65
# indiarxiv              --             --            --
# lawarxiv                1              1          1-45
# lissa                 1-2              1           1-9
# marxiv                1-4              2          0-33
# mediarxiv               1              1           1-4
# metaarxiv             2-6              3          1-32
# mindrxiv              1-4              2          1-14
# nutrixiv              1-3              1           1-9
# osf                   1-2              1          0-78
# paleorxiv             2-4              2          1-10
# psyarxiv              2-4              3         0-173
# livedata               --             --            --
# socarxiv              1-2              1         0-166
# sportrxiv             3-5              4          1-36
# thesiscommons           1              1           1-4
#
#               date of first submission records  \
# africarxiv         2018-06-22T00:00:00      50
# agrixiv            2017-02-15T00:00:00     126
# arabixiv           2018-01-14T00:00:00     297
# bodoarxiv          2019-03-19T00:00:00      21
# eartharxiv         2017-10-23T00:00:00     821
# ecoevorxiv         2018-03-21T00:00:00      66
# ecsarxiv           2018-05-11T00:00:00      61
# engrxiv            2016-07-27T00:00:00     541
# focusarchive       2017-09-20T00:00:00      39
# frenxiv            2018-07-06T00:00:00      42
# inarxiv            2017-08-20T00:00:00    8000
# indiarxiv                         None       0
# lawarxiv           2016-07-16T00:00:00    1038
# lissa              2017-07-12T00:00:00     177
# marxiv             2017-11-09T00:00:00     366
# mediarxiv          2019-02-13T00:00:00      45
# metaarxiv          2017-03-03T00:00:00      48
# mindrxiv           2017-07-07T00:00:00     147
# nutrixiv           2017-08-24T00:00:00      33
# osf                2016-08-29T00:00:00    7329
# paleorxiv          2017-08-18T00:00:00     128
# psyarxiv           2016-08-15T00:00:00    4833
# livedata                          None       0
# socarxiv           2016-07-13T00:00:00    3669
# sportrxiv          2017-08-18T00:00:00      90
# thesiscommons      2017-04-21T00:00:00     431
#
#               records with OSF publication DOIs records with OSF-related DOIs  \
# africarxiv                                    0                             0
# agrixiv                                       0                             1
# arabixiv                                      0                             0
# bodoarxiv                                     0                             0
# eartharxiv                                    0                             0
# ecoevorxiv                                    0                             1
# ecsarxiv                                      0                             0
# engrxiv                                       0                             0
# focusarchive                                  0                             0
# frenxiv                                       0                             0
# inarxiv                                      31                           271
# indiarxiv                                     0                             0
# lawarxiv                                      0                             2
# lissa                                         0                             5
# marxiv                                        0                             0
# mediarxiv                                     0                             1
# metaarxiv                                     0                             0
# mindrxiv                                      0                             0
# nutrixiv                                      0                             0
# osf                                           2                           136
# paleorxiv                                     0                             0
# psyarxiv                                      1                             8
# livedata                                      0                             0
# socarxiv                                      0                            12
# sportrxiv                                     0                             1
# thesiscommons                                 0                             3
#
#               records with submitted DOIs
# africarxiv                              7
# agrixiv                                10
# arabixiv                              162
# bodoarxiv                              13
# eartharxiv                            364
# ecoevorxiv                             14
# ecsarxiv                                1
# engrxiv                               154
# focusarchive                            0
# frenxiv                                24
# inarxiv                               532
# indiarxiv                               0
# lawarxiv                               51
# lissa                                  36
# marxiv                                205
# mediarxiv                              11
# metaarxiv                               5
# mindrxiv                               51
# nutrixiv                               10
# osf                                  1005
# paleorxiv                              90
# psyarxiv                              940
# livedata                                0
# socarxiv                             1130
# sportrxiv                              21
# thesiscommons                          27

# %% [markdown]
# ### GROWTH IN THE NUMBER OF PUBLICATIONS

# %%
OUTPUT_FOLDER_GROWTH = os.path.join('..', '..', 'data_analysis_results', 'growth_per_month')
if not os.path.exists(OUTPUT_FOLDER_GROWTH):
    os.mkdir(OUTPUT_FOLDER_GROWTH)

# %%
preprint_servers = {}
for server in servers:
    preprint_servers[server] = {}

all_servers = {}

for record in osf_records:
    server = record['osf_record']['relationships']['provider']['links']['related']['href'].replace( \
                'https://api.osf.io/v2/providers/preprints/', '').replace('/?format=json', '')
    
    if record['date_published'].year not in all_servers:
        all_servers[record['date_published'].year] = defaultdict(int)
    
    all_servers[record['date_published'].year][record['date_published'].month] += 1
    
    if record['date_published'].year not in preprint_servers[server]:
        preprint_servers[server][record['date_published'].year] = defaultdict(int)
    
    preprint_servers[server][record['date_published'].year][record['date_published'].month] += 1

# %%
import calendar
all_servers_pub_per_month = []
for year in sorted(all_servers.keys()):
    for month, count in sorted(all_servers[year].items()):
        all_servers_pub_per_month.append({ 'year' : year, 
                                   'month' : calendar.month_name[month],
                                   'publications' : count})

# %%
df = pd.DataFrame(all_servers_pub_per_month)
df.to_csv(os.path.join(OUTPUT_FOLDER_GROWTH, 'all_servers_pub_per_month.csv'))

display(df)
# Out:
#         month  publications  year
# 0        July           290  2016
# 1      August           230  2016
# 2   September           158  2016
# 3     October            69  2016
# 4    November            67  2016
# 5    December           221  2016
# 6     January           253  2017
# 7    February           188  2017
# 8       March           292  2017
# 9       April           225  2017
# 10        May           393  2017
# 11       June           289  2017
# 12       July           296  2017
# 13     August           625  2017
# 14  September           774  2017
# 15    October           880  2017
# 16   November           962  2017
# 17   December           752  2017
# 18    January           984  2018
# 19   February           790  2018
# 20      March           794  2018
# 21      April          1002  2018
# 22        May          1144  2018
# 23       June           873  2018
# 24       July          1102  2018
# 25     August           938  2018
# 26  September           815  2018
# 27    October          1173  2018
# 28   November          1376  2018
# 29   December          1965  2018
# 30    January          1877  2019
# 31   February          1670  2019
# 32      March          1378  2019
# 33      April          1728  2019
# 34        May          1825  2019

# %%
import calendar

for server, data in preprint_servers.items():
    pub_per_month = []
    for year in sorted(data.keys()):
        for month, count in sorted(data[year].items()):
            pub_per_month.append({ 'year' : year, 
                                       'month' : calendar.month_name[month],
                                       'publications' : count})
    df = pd.DataFrame(pub_per_month)
    df.to_csv(os.path.join(OUTPUT_FOLDER_GROWTH, server + '.csv'))

# %% [markdown]
# #### GROWTH IN THE NUMBER OF PUBLICATIONS (FOR BIOLOGY AND LIFE SCIENCES)

# %%
OUTPUT_FOLDER_GROWTH_BIO = os.path.join('..', '..', 'data_analysis_results', 'osf_bio_growth_per_month')
if not os.path.exists(OUTPUT_FOLDER_GROWTH_BIO):
    os.mkdir(OUTPUT_FOLDER_GROWTH_BIO)

# %%
preprint_servers = {}
for server in osf_servers:
    preprint_servers[server] = {}

all_servers = {}

for record in osf_records:
    record_is_biology_related = False
    for subject in record['osf_record']['attributes']['subjects']:
        if subject[0]['text'] == 'Life Sciences':
            record_is_biology_related = True
            break
            
    if record_is_biology_related:
        server = record['osf_record']['relationships']['provider']['links']['related']['href'].replace( \
                    'https://api.osf.io/v2/providers/preprints/', '').replace('/?format=json', '')

        if record['date_published'].year not in all_servers:
            all_servers[record['date_published'].year] = defaultdict(int)

        all_servers[record['date_published'].year][record['date_published'].month] += 1

        if record['date_published'].year not in preprint_servers[server]:
            preprint_servers[server][record['date_published'].year] = defaultdict(int)

        preprint_servers[server][record['date_published'].year][record['date_published'].month] += 1

# %%
import calendar
all_servers_pub_per_month = []
for year in sorted(all_servers.keys()):
    for month, count in sorted(all_servers[year].items()):
        all_servers_pub_per_month.append({ 'year' : year, 
                                   'month' : calendar.month_name[month],
                                   'publications' : count})

# %%
df = pd.DataFrame(all_servers_pub_per_month)
df.to_csv(os.path.join(OUTPUT_FOLDER_GROWTH_BIO, 'all_servers_pub_per_month.csv'))

display(df)
# Out:
#         month  publications  year
# 0      August             2  2016
# 1   September             1  2016
# 2     October             1  2016
# 3    November             1  2016
# 4    December            55  2016
# 5     January            12  2017
# 6    February             9  2017
# 7       March            12  2017
# 8       April            11  2017
# 9         May            13  2017
# 10       June             8  2017
# 11       July            14  2017
# 12     August            56  2017
# 13  September            78  2017
# 14    October            45  2017
# 15   November            68  2017
# 16   December            36  2017
# 17    January            59  2018
# 18   February            56  2018
# 19      March            82  2018
# 20      April            78  2018
# 21        May            98  2018
# 22       June            86  2018
# 23       July            68  2018
# 24     August           104  2018
# 25  September            55  2018
# 26    October            53  2018
# 27   November            78  2018
# 28   December            80  2018
# 29    January           124  2019
# 30   February            77  2019
# 31      March            78  2019
# 32      April            89  2019
# 33        May            95  2019

# %%
import calendar

for server, data in preprint_servers.items():
    pub_per_month = []
    for year in sorted(data.keys()):
        for month, count in sorted(data[year].items()):
            pub_per_month.append({ 'year' : year, 
                                       'month' : calendar.month_name[month],
                                       'publications' : count})
    df = pd.DataFrame(pub_per_month)
    df.to_csv(os.path.join(OUTPUT_FOLDER_GROWTH_BIO, server + '.csv'))

# %% [markdown]
# ### DUPLICATE RECORDS

# %%
OUTPUT_FOLDER_DUPLICATE = os.path.join('..', '..', 'data_analysis_results', 'duplicate_records')
if not os.path.exists(OUTPUT_FOLDER_DUPLICATE):
    os.mkdir(OUTPUT_FOLDER_DUPLICATE)

# %%
titles = {}

for record in osf_records:
    server = record['osf_record']['relationships']['provider']['links']['related']['href'].replace( \
                'https://api.osf.io/v2/providers/preprints/', '').replace('/?format=json', '')
    
    if record['osf_record']['attributes']['title'] not in titles:
        titles[record['osf_record']['attributes']['title']] = []
        
    authors = []
    for author_list in record['osf_authors'][0]:
        for author in author_list['data']:
            if author['attributes']['bibliographic']:
                try:
                    author_data = author['embeds']['users']['data']['attributes']
                    author_id = author['embeds']['users']['data']['id']
                except Exception as e:
                    author_data = author['embeds']['users']['errors'][0]['meta']
        
                authors.append(author_data['full_name'])
            
    titles[record['osf_record']['attributes']['title']].append({'id' : record['id'],
                                                               'authors' : authors,
                                                               'server' : server,
                                                               'doi' : record['osf_record']['attributes']['doi'],
                                                               'date' : record['osf_record']['attributes']['date_published'][:10]})

# %%
a = 0
for title, r in titles.items():
    if len(r) >1:
        a += 1
a
# Out:
# 848

# %%
def have_same_authors(author_list_1, author_list_2):   
    if len(author_list_1) == len(author_list_2):
        for k in range(len(author_list_1)):
            if author_list_1[k] != author_list_2[k]:
                return False

        return True
    else:
        return False

# %%
# this processes all records with duplicate titles

from collections import defaultdict

# SAME: authors, date, server, doi
sa_sdp_ss_sdoi = []

# SAME: authors, date, doi DIFF: server
sa_sdp_ds_sdoi = []

# SAME: authors, date, doi DIFF: server
sa_sdp_ds_sdoi = []

for title, records in titles.items():
    if len(records) > 1:
        date_published = set()
        servers = set()
        dois = set()
        
        for record in records:
            date_published.add(record['date'])
            servers.add(record['server'])
            dois.add(record['doi'])
         
        all_same_authors = True
        for i in range(len(records)):
            for j in range(i + 1, len(records)):
                if not have_same_authors(records[i]['authors'], records[j]['authors']):
                    all_same_authors = False
                    break
            if not all_same_authors:
                break

        if all_same_authors and len(servers) == 1 and len(date_published) == 1 and len(dois) == 1:
            ids = []
            for record in records:
                ids.append(record['id'])
            
            sa_sdp_ss_sdoi.append({
                'title' : title,
                'server' : list(servers)[0],
                'date_published' : list(date_published)[0],
                'ids' : ids,
                'doi' : list(dois)[0]
            })
            
        if all_same_authors and len(servers) > 1 and len(date_published) == 1 and len(dois) == 1:
            ids = []
            for record in records:
                ids.append(record['id'])
            
            sa_sdp_ds_sdoi.append({
                'title' : title,
                'server' : servers,
                'date_published' : list(date_published)[0],
                'ids' : ids,
                'doi' : list(dois)[0]
            })
        
        if all_same_authors and len(servers) > 1 and len(date_published) == 1 and len(dois) == 1:
            ids = []
            for record in records:
                ids.append(record['id'])
            
            sa_sdp_ds_sdoi.append({
                'title' : title,
                'server' : servers,
                'date_published' : list(date_published)[0],
                'ids' : ids,
                'doi' : list(dois)[0]
            })

# %%
df_sa_sdp_ss_sdoi = pd.DataFrame(sa_sdp_ss_sdoi)
df_sa_sdp_ss_sdoi.to_csv(os.path.join(OUTPUT_FOLDER_DUPLICATE, 'same_au_dp_serv_doi.csv'))

# %%
df_sa_sdp_ds_sdoi = pd.DataFrame(sa_sdp_ds_sdoi)
df_sa_sdp_ds_sdoi.to_csv(os.path.join(OUTPUT_FOLDER_DUPLICATE, 'same_au_dp_doi_diff_serv.csv'))

# %%
from collections import defaultdict

date_diff = defaultdict(int)

samesies = 0
not_same = 0
not_recs = 0 
recs = 0
for title, records in titles.items():
    if len(records) > 1:
        date_published = defaultdict(int)
        
        servers = set()
        for record in records:
            date_published[record['date']] += 1
            servers.add(record['server'])
            
        if len(date_published.keys()) == 1:
            if len(servers) > 1:
#                 print(servers)
                not_same += 1
                not_recs += len(records)
                
#                 if len(records) > 2:
#                     print(records)
            else:
                
                
                all_same_authors = True
                for i in range(len(records)):
                    for j in range(i + 1, len(records)):
                        if not have_same_authors(records[i]['authors'], records[j]['authors']):
                            all_same_authors = False
                            break
                    if not all_same_authors:
                        break
                
                if all_same_authors:
                    samesies += 1
                    recs += len(records)
                else:
                    for record in records:
                        print(record['id'])
                        print(record['authors'])
                
                print('----')
            
#         date_diff[len(date_published.keys())] += 1
        
#         if len(date_published.keys()) > 1:
#             print(date_published)
#             for record in records:
#                 print('osf.io/' + record['id'])

# date_diff
print(recs)
print(not_same)
print(not_recs)
samesies
# Out:
# jfegz
# ['Rafika andella']
# npfq4
# ['Dela Wulandari']
# ----
# 3d8uk
# ['Putri Pattitria Ningrum Nasution', 'Hade Afriansyah']
# 6er4b
# ['Aulia Alqiva', 'Hade Afriansyah']
# ----
# vpk5z
# ['Achmad Affandi', 'Hade Afriansyah']
# 7hqfx
# ['Achmad Affandi']
# ----
# w4c8b
# ['gusti', 'ratna', 'titin afwirdha']
# kqc2d
# ['gusti']
# ----
# ja9u6
# ['Adhitya dwi putra']
# ayvjm
# ['galant emerald']
# ----
# ----
# f6q4g
# ['nuruzzaitun adawiyah']
# tebjh
# ['clairine gitta zerlina sutedjo ']
# cksn3
# ['Gita Sirini Purwanto']
# ----
# ----
# psqrv
# ['Rahmawati Nur Arifah']
# a2qgy
# ['Dewi Nopitaningrum']
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# c4whb
# ['Arif Fadillah']
# zhf28
# ['Salma Sakinah']
# ----
# ----
# y2fcs
# ['Refki Prayoga']
# b63ac
# ['Ranita Sari']
# ndgek
# ['Mayang sunesti']
# bnd5s
# ['Muhammad Lubis Angsori']
# vhr83
# ['Muhamad Alwi Alfagih']
# dm29e
# ['Dwi Febriana']
# ----
# a2wfe
# ['Muhammad Lubis Angsori']
# da3ns
# ['Muhamad Alwi Alfagih']
# 6u7fg
# ['Dwi Febriana']
# ----
# 9txhn
# ['Muhammad Lubis Angsori']
# qkw5a
# ['Muhamad Alwi Alfagih']
# 2krzc
# ['Dwi Febriana']
# ----
# ----
# ayfxs
# ['GILLAN FATAHILLAH']
# eg3pf
# ['Gillan Fatahillah']
# ----
# ----
# ----
# ----
# ----
# h9xgp
# ['Elvina Agustin', 'Aminar Sutra Dewi']
# rn6cs
# ['Capry Dudellah Rode', 'Aminar Sutra Dewi']
# ----
# z7jvp
# ['syarif maulana']
# xqg37
# ['M Ridho Tri Putra']
# ----
# 68agy
# ['syapri kurniawan']
# e4h7k
# ['Angga pratama']
# c3gvs
# ['Yuliyanah']
# ----
# vf36d
# ['Muhammad epri sulistio']
# rvgx3
# ['Robi Suganda']
# pqrsx
# ['Aldesion Denagi Zenda']
# ----
# z83e9
# ['vivi eryani']
# xtpc7
# ['Gillan Fatahillah']
# ----
# 9wxg8
# ['Nur Fajri Aldiansyah']
# 7ym5n
# ['Friska Steviana']
# cj37u
# ['Firdha Zakiah']
# ----
# ----
# ----
# 26mbp
# ['Dahrani']
# nj5cx
# ['Seprida Hanum Harahap']
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# 6sz2j
# ['Timur Damar Piyangka']
# ywrv2
# ['Bennyta Fortuna Apriliyanti']
# ----
# dpf38
# ['sheila laxsmi degitasari ']
# tuczy
# ['Salsabila Azmy']
# ----
# ----
# ----
# ----
# 23vfw
# ['Md. Mahmudul Alam']
# zqgrx
# ['Mohammad Mashnun Hossain', 'Md. Mahmudul Alam', 'Shawon Muhammad Shahriar']
# ----
# rx4a3
# ['Md. Mahmudul Alam', 'Chamhuri Siwar', 'Mohd Ekhwan bin Toriman', 'Rafiqul Islam Molla', 'Basri Talib']
# gjcd5
# ['Md. Mahmudul Alam', 'Chamhuri Siwar', 'Basri Talib', 'Mazlin Mokhtar', 'Mohd Ekhwan bin Toriman']
# ----
# 5zs8f
# ['Janet Faustine Harli']
# p85tx
# ['Gabrielle Geraldine']
# ----
# ----
# ----
# ----
# n4f68
# ['Siti nur hidayah']
# sn5c8
# ['Siti nur hidayah']
# d9ut7
# ['Nurul ahyunina']
# ----
# ----
# ----
# e2vpr
# ['Susi Muntama', 'Miswatunkhasanah']
# 5xabv
# ['Miswatunkhasanah', 'Susi Muntama']
# 48xky
# ['Miswatunkhasanah', 'Susi Muntama']
# 4b8tq
# ['Susi Muntama', 'Miswatunkhasanah']
# ----
# ----
# ----
# ----
# ----
# 9cjdp
# ['Wildayati', 'Rahadian  Zainul']
# g3w8p
# ['Rahadian  Zainul', 'Wildayati']
# ----
# 3htwg
# ['Angga Nasution']
# yrfcd
# ['Arifmuhammad']
# 4javh
# ['Siti hanifah kharismawati']
# 3kn6e
# ['Wullandari']
# ----
# ----
# ----
# ----
# ----
# j5a48
# ['IKO UMBU KARUGU LIMU']
# m5es8
# ['moses jakson umbu mawu']
# ----
# rmxk4
# ['Sisiliya Flanforistina']
# frbcn
# ['Sisiliya Flanforistina']
# vj3a5
# ['Triyo Asri Widayanti']
# ----
# ----
# 2tnb5
# ['Razzaq Arrasyidul Aziz']
# 7kg8f
# ['wijirahayu']
# ----
# t6p3g
# ['Riva fitriyaningsih']
# 5mjna
# ['warda silvia ']
# ----
# r5zyw
# ['yosephina maria cinta']
# 763zv
# ['Teresia Widya Ningsih']
# ----
# ----
# ----
# kzxb8
# ['Fajar Juliandy']
# a7dgf
# ['Hasriadi']
# ----
# ----
# ----
# t6jd4
# ['Muhammad Handoko']
# qwph5
# ['Irodatil Hudiah Khasanah']
# ----
# 37ps2
# ['Muhammad Handoko']
# yjatg
# ['Irodatil Hudiah Khasanah']
# ug642
# ['Muhammad Handoko']
# ----
# 6vefx
# ['Muhammad Handoko']
# 3nh7t
# ['Irodatil Hudiah Khasanah']
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# r6wku
# ['Nofitasari', 'Saleha Astri Rahaningmas', 'Sri Wahyuni', 'Muh. Izhar Mahendra']
# sbydq
# ['Nofitasari']
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# 7p5gb
# ['Anggriadin']
# 62wra
# ['Ulfa Dwiyanti']
# ----
# ----
# ----
# ----
# zb6ur
# ['martinus sumarno']
# 65xsf
# ['Martinus Sumarno']
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# gnkad
# ['theodore jeremy alexander']
# dkn23
# ['Paulus Pensies Anggoro']
# ----
# ----
# ----
# gvfxs
# ['Theresia Mahdalena']
# bazpe
# ['melinia']
# ----
# crb7k
# ['Septya Indah Sulastri ']
# 9xfc2
# ['Arum Umayah']
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# 8bqfz
# ['Asrizal Asrizal', 'Hufri', 'Festiyed Festiyed']
# 6zswd
# ['Asrizal Asrizal', 'Hufri', 'Festiyed']
# ----
# ----
# ----
# ----
# 5p4xv
# ['Maretta Arviyana', 'syahrul Ramadhan', 'tressyalina']
# djg67
# ['Mayora', 'syahrul Ramadhan', 'tressyalina']
# ----
# ----
# ----
# ----
# e5kvc
# ['Sri Yanto', 'Muhammad Faiz']
# t2qnu
# ['Azwar Rahmatullah', 'Muhammad Husein Ar-rafi', 'Nurbia']
# ----
# ----
# mdt9w
# ['Herli mardiansyah']
# c9ma8
# ['Rifan wahyudi']
# ----
# 9w35q
# ['Nadya Karina Putri']
# 6ktjm
# ['Iis solehawati']
# ----
# y2x69
# ['Refki Prayoga']
# akj2g
# ['Dicka Rianta Putra']
# qyhbz
# ['Supri hardiansyay']
# 65sjq
# ['Muhamad Epri Sulistyo']
# erytd
# ['Robi Suganda']
# j2zru
# ['Muhammad Lubis Angsori']
# b4dfy
# ['Aris Suwandi']
# 7jb8u
# ['Rizki Suhendra Putra']
# vrusm
# ['Muhamad Alwi Alfagih']
# wc9kn
# ['Aldesion Denagi Zenda']
# ----
# ----
# sm29r
# ['GILLAN FATAHILLAH']
# xvyjk
# ['PENI JUWI ANDIRA']
# u7wyq
# ['PENI JUWI ANDIRA']
# sh7cx
# ['Vivi eryani']
# k9n6y
# ['PENI JUWI ANDIRA']
# nrcm3
# ['Dwi Febriana']
# h258u
# ['Winariyani']
# kejdx
# ['Dwi Febriana']
# k5zmy
# ['Winariyani']
# wpcnj
# ['Dwi Febriana']
# dkq2g
# ['Winariyani']
# 9d7f3
# ['Winariyani']
# ----
# ----
# dm7wf
# ['ARISTO', 'Ketut Wisarja', 'I Ketut Sudarsana']
# 8pjfy
# ['ARISTO']
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# 42pm9
# ["Ni'mahtus Sholikhah", 'Angela Deninda Meiliana Karisa']
# vqf6x
# ['much thareq kartiko adi bawono', 'jeco valiant reinhart']
# ----
# ----
# ----
# s3my7
# ['setiyo wati']
# 8tcrb
# ['Setiyowati']
# ----
# ----
# ----
# ----
# ----
# b3gjx
# ['Gregorio Martínez', 'William Senior', 'Arístide Márquez']
# bcgpk
# ['Gregorio Martínez', 'William Senior']
# ----
# ----
# ----
# ----
# 303
# 43
# 87
# 141

# %%
from collections import defaultdict

date_diff = defaultdict(int)

for title, records in titles.items():
    if len(records) > 1:
        date_published = defaultdict(int)
        
        for record in records:
            date_published[record['date']] += 1
        
        date_diff[len(date_published.keys())] += 1
        
        if len(date_published.keys()) > 1:
            print(date_published)
            for record in records:
                print('osf.io/' + record['id'])

date_diff
# Out:
# defaultdict(<class 'int'>, {'2019-05-31': 1, '2018-10-12': 1})
# osf.io/scj5d
# osf.io/v93xm
# defaultdict(<class 'int'>, {'2019-05-30': 1, '2019-03-07': 1})
# osf.io/7zw5g
# osf.io/4a9xt
# defaultdict(<class 'int'>, {'2019-05-30': 1, '2019-05-28': 1})
# osf.io/h3q2r
# osf.io/tfqhp
# defaultdict(<class 'int'>, {'2019-05-29': 1, '2019-05-27': 1, '2019-05-21': 2, '2019-04-28': 1})
# osf.io/htnp2
# osf.io/w3uc6
# osf.io/p4dtb
# osf.io/dgyhp
# osf.io/aejhy
# defaultdict(<class 'int'>, {'2019-05-29': 1, '2019-05-21': 1, '2019-05-20': 1, '2019-05-19': 1, '2019-03-25': 1})
# osf.io/9zqwh
# osf.io/wc76d
# osf.io/mg97x
# osf.io/ufrh8
# osf.io/cb8zp
# defaultdict(<class 'int'>, {'2019-05-28': 1, '2019-05-25': 1})
# osf.io/hz48a
# osf.io/c8f3b
# defaultdict(<class 'int'>, {'2019-05-28': 1, '2019-04-29': 1})
# osf.io/5dnw9
# osf.io/bjz8f
# defaultdict(<class 'int'>, {'2019-05-27': 1, '2019-05-25': 1})
# osf.io/wfxm5
# osf.io/ndpxv
# defaultdict(<class 'int'>, {'2019-05-27': 2, '2019-05-26': 1})
# osf.io/ype3k
# osf.io/7e4u8
# osf.io/ymu7f
# defaultdict(<class 'int'>, {'2019-05-27': 1, '2019-05-26': 1})
# osf.io/ybq2a
# osf.io/asy9d
# defaultdict(<class 'int'>, {'2019-05-27': 1, '2019-05-25': 1})
# osf.io/rusv4
# osf.io/bp2uz
# defaultdict(<class 'int'>, {'2019-05-27': 1, '2019-05-25': 1})
# osf.io/dxh6b
# osf.io/5wkrx
# defaultdict(<class 'int'>, {'2019-05-27': 1, '2019-05-26': 1})
# osf.io/984eb
# osf.io/qagjm
# defaultdict(<class 'int'>, {'2019-05-27': 1, '2019-05-25': 1})
# osf.io/wy4zr
# osf.io/yd38k
# defaultdict(<class 'int'>, {'2019-05-27': 1, '2019-05-20': 1})
# osf.io/swmq3
# osf.io/dreak
# defaultdict(<class 'int'>, {'2019-05-28': 1, '2019-05-10': 1})
# osf.io/7zf8u
# osf.io/a3rqs
# defaultdict(<class 'int'>, {'2019-05-25': 1, '2019-05-21': 1, '2019-05-17': 2, '2019-05-15': 4, '2019-05-14': 8, '2019-05-13': 5})
# osf.io/2cpkx
# osf.io/ztgpd
# osf.io/vwcem
# osf.io/7ay6u
# osf.io/f2eru
# osf.io/6eryh
# osf.io/ew6h3
# osf.io/8vkdw
# osf.io/kt5r9
# osf.io/6fspr
# osf.io/pbkvs
# osf.io/ghk4q
# osf.io/rqh7e
# osf.io/d8jke
# osf.io/h2jwm
# osf.io/fqa5d
# osf.io/ak54b
# osf.io/jfdx9
# osf.io/8g6av
# osf.io/feqmw
# osf.io/9bd23
# defaultdict(<class 'int'>, {'2019-05-25': 1, '2019-05-20': 1})
# osf.io/ed7f5
# osf.io/r2tfa
# defaultdict(<class 'int'>, {'2019-05-24': 1, '2019-05-25': 1})
# osf.io/amu6j
# osf.io/5jquv
# defaultdict(<class 'int'>, {'2019-05-24': 1, '2019-03-26': 1})
# osf.io/b5p3v
# osf.io/xvyw3
# defaultdict(<class 'int'>, {'2019-05-24': 1, '2019-05-18': 1})
# osf.io/pbgnm
# osf.io/9gmp4
# defaultdict(<class 'int'>, {'2019-05-23': 1, '2019-05-16': 1})
# osf.io/cz54j
# osf.io/d3ruw
# defaultdict(<class 'int'>, {'2019-05-23': 1, '2018-07-02': 1})
# osf.io/ex3fm
# osf.io/qyfxc
# defaultdict(<class 'int'>, {'2019-05-21': 1, '2019-05-13': 1})
# osf.io/8wcb9
# osf.io/v5x2w
# defaultdict(<class 'int'>, {'2019-05-21': 1, '2019-05-17': 1})
# osf.io/36cf7
# osf.io/kqutp
# defaultdict(<class 'int'>, {'2019-05-21': 1, '2019-05-14': 2, '2019-05-13': 1})
# osf.io/a6rpx
# osf.io/j8yqa
# osf.io/kupzs
# osf.io/tvm9e
# defaultdict(<class 'int'>, {'2019-05-21': 1, '2019-05-17': 1, '2019-05-16': 1, '2019-05-15': 2, '2019-05-14': 3, '2019-05-13': 7})
# osf.io/zjguf
# osf.io/ecfx5
# osf.io/fs5a8
# osf.io/3rvjm
# osf.io/e5cwu
# osf.io/9zjrc
# osf.io/2n6x5
# osf.io/8aewc
# osf.io/nztvm
# osf.io/h6jms
# osf.io/jqa3v
# osf.io/s3fub
# osf.io/6m734
# osf.io/8cve5
# osf.io/76kre
# defaultdict(<class 'int'>, {'2019-05-21': 1, '2019-05-12': 1, '2019-04-09': 1})
# osf.io/4xasv
# osf.io/szdbq
# osf.io/bgqew
# defaultdict(<class 'int'>, {'2019-05-20': 1, '2019-05-18': 2})
# osf.io/ugsy5
# osf.io/r4qsj
# osf.io/tqx7g
# defaultdict(<class 'int'>, {'2019-05-20': 1, '2019-05-13': 1})
# osf.io/z3m8y
# osf.io/nwbxs
# defaultdict(<class 'int'>, {'2019-05-20': 1, '2019-05-14': 1})
# osf.io/gn5ra
# osf.io/w32mu
# defaultdict(<class 'int'>, {'2019-05-19': 1, '2019-05-13': 1})
# osf.io/qvg6d
# osf.io/fumv5
# defaultdict(<class 'int'>, {'2019-05-19': 1, '2019-05-06': 1})
# osf.io/v368p
# osf.io/849pe
# defaultdict(<class 'int'>, {'2019-05-18': 1, '2019-05-15': 1})
# osf.io/hvew9
# osf.io/y38cz
# defaultdict(<class 'int'>, {'2019-05-18': 1, '2019-05-06': 1})
# osf.io/e4yrg
# osf.io/yz5vs
# defaultdict(<class 'int'>, {'2019-05-18': 1, '2019-05-14': 1})
# osf.io/t5yvk
# osf.io/tmab4
# defaultdict(<class 'int'>, {'2019-05-18': 1, '2019-05-17': 1, '2019-05-15': 1, '2019-05-14': 1})
# osf.io/wpq28
# osf.io/g25r4
# osf.io/hc4k8
# osf.io/wgbku
# defaultdict(<class 'int'>, {'2019-05-18': 1, '2019-05-10': 1})
# osf.io/a7je5
# osf.io/vez7b
# defaultdict(<class 'int'>, {'2019-05-17': 1, '2019-05-11': 1})
# osf.io/9svfa
# osf.io/69g3j
# defaultdict(<class 'int'>, {'2019-05-17': 1, '2019-04-25': 1})
# osf.io/7hny3
# osf.io/cdzk5
# defaultdict(<class 'int'>, {'2019-05-17': 1, '2019-05-15': 1, '2019-05-10': 1})
# osf.io/q7uf3
# osf.io/n432h
# osf.io/djxga
# defaultdict(<class 'int'>, {'2019-05-17': 1, '2019-05-15': 1, '2019-05-14': 1, '2019-05-13': 2})
# osf.io/cwf4b
# osf.io/ers4m
# osf.io/9cyzn
# osf.io/73tg4
# osf.io/4jrwm
# defaultdict(<class 'int'>, {'2019-05-16': 1, '2019-05-14': 1})
# osf.io/8j357
# osf.io/tjkep
# defaultdict(<class 'int'>, {'2019-05-16': 1, '2019-05-15': 1})
# osf.io/8v5nu
# osf.io/zqnju
# defaultdict(<class 'int'>, {'2019-05-16': 1, '2019-05-13': 1, '2019-05-12': 1})
# osf.io/5a8j3
# osf.io/8usm7
# osf.io/9ujym
# defaultdict(<class 'int'>, {'2019-05-15': 1, '2019-05-14': 3, '2019-05-13': 2})
# osf.io/95wqd
# osf.io/cpbjr
# osf.io/9r8cn
# osf.io/c583w
# osf.io/n9f5u
# osf.io/q4ruy
# defaultdict(<class 'int'>, {'2019-05-15': 1, '2019-05-13': 1})
# osf.io/cbp7f
# osf.io/h7s86
# defaultdict(<class 'int'>, {'2019-05-15': 1, '2019-05-02': 1})
# osf.io/mcp3h
# osf.io/zpcmf
# defaultdict(<class 'int'>, {'2019-05-14': 1, '2019-05-08': 1})
# osf.io/y9762
# osf.io/qzrac
# defaultdict(<class 'int'>, {'2019-05-14': 1, '2019-05-09': 1})
# osf.io/8d47n
# osf.io/k4udv
# defaultdict(<class 'int'>, {'2019-05-13': 1, '2019-04-21': 1})
# osf.io/tgw3s
# osf.io/s2d9w
# defaultdict(<class 'int'>, {'2019-05-13': 1, '2019-04-18': 1})
# osf.io/jbev5
# osf.io/fwbj6
# defaultdict(<class 'int'>, {'2019-05-13': 1, '2019-04-30': 1})
# osf.io/84qnp
# osf.io/dmzn3
# defaultdict(<class 'int'>, {'2019-05-13': 1, '2019-04-20': 1})
# osf.io/eafz5
# osf.io/awbk3
# defaultdict(<class 'int'>, {'2019-05-13': 1, '2019-04-19': 1})
# osf.io/4dekp
# osf.io/d4wtx
# defaultdict(<class 'int'>, {'2019-05-12': 2, '2019-04-18': 1})
# osf.io/bjp2g
# osf.io/8uhdr
# osf.io/xav3g
# defaultdict(<class 'int'>, {'2019-05-12': 1, '2019-04-19': 1})
# osf.io/awke7
# osf.io/bmcwp
# defaultdict(<class 'int'>, {'2019-05-12': 1, '2019-04-19': 1})
# osf.io/9fm3j
# osf.io/nzcev
# defaultdict(<class 'int'>, {'2019-05-12': 1, '2019-04-19': 2, '2019-04-18': 2})
# osf.io/pk4vy
# osf.io/ybg6x
# osf.io/rc8sg
# osf.io/w396a
# osf.io/gjy5z
# defaultdict(<class 'int'>, {'2019-05-12': 1, '2019-04-19': 1, '2019-04-18': 1})
# osf.io/qjp89
# osf.io/dmk6a
# osf.io/4x8sn
# defaultdict(<class 'int'>, {'2019-05-12': 1, '2019-05-13': 1})
# osf.io/u6wa2
# osf.io/ycxnj
# defaultdict(<class 'int'>, {'2019-05-12': 1, '2019-04-18': 1})
# osf.io/gdahj
# osf.io/8wfx7
# defaultdict(<class 'int'>, {'2019-05-12': 1, '2019-04-19': 1})
# osf.io/c5gke
# osf.io/62ezn
# defaultdict(<class 'int'>, {'2019-05-12': 1, '2018-10-31': 1})
# osf.io/e46qz
# osf.io/8y6xz
# defaultdict(<class 'int'>, {'2019-05-12': 1, '2019-04-18': 1})
# osf.io/p42v9
# osf.io/ck5wt
# defaultdict(<class 'int'>, {'2019-05-12': 1, '2019-04-23': 1})
# osf.io/nv2ka
# osf.io/adr7t
# defaultdict(<class 'int'>, {'2019-05-12': 2, '2019-05-05': 1})
# osf.io/8wxhq
# osf.io/cfqre
# osf.io/7tmy4
# defaultdict(<class 'int'>, {'2019-05-12': 1, '2019-04-23': 1})
# osf.io/4bcfk
# osf.io/jynrd
# defaultdict(<class 'int'>, {'2019-05-12': 1, '2019-05-10': 2})
# osf.io/xc2zf
# osf.io/9826m
# osf.io/m4zpu
# defaultdict(<class 'int'>, {'2019-05-12': 1, '2019-05-04': 1})
# osf.io/mvt95
# osf.io/5x9q3
# defaultdict(<class 'int'>, {'2019-05-10': 1, '2018-05-11': 1})
# osf.io/e3uyq
# osf.io/9dbw2
# defaultdict(<class 'int'>, {'2019-05-09': 1, '2018-10-19': 1})
# osf.io/vdqzw
# osf.io/ebdv5
# defaultdict(<class 'int'>, {'2019-05-09': 2, '2019-05-04': 1})
# osf.io/fqyjm
# osf.io/zue8b
# osf.io/7hm6u
# defaultdict(<class 'int'>, {'2019-05-09': 1, '2019-02-25': 1, '2019-02-17': 1})
# osf.io/ucp7q
# osf.io/7xvzq
# osf.io/86t7h
# defaultdict(<class 'int'>, {'2019-05-09': 1, '2019-05-04': 1})
# osf.io/xe8ay
# osf.io/cvrey
# defaultdict(<class 'int'>, {'2019-05-09': 1, '2019-02-15': 1})
# osf.io/zw2uj
# osf.io/ngwzd
# defaultdict(<class 'int'>, {'2019-05-09': 1, '2019-05-03': 1})
# osf.io/e4vgr
# osf.io/6em9x
# defaultdict(<class 'int'>, {'2019-05-07': 1, '2019-05-03': 1})
# osf.io/8ex4r
# osf.io/9uv4c
# defaultdict(<class 'int'>, {'2019-05-07': 1, '2019-05-03': 1})
# osf.io/wn8s7
# osf.io/u6d3t
# defaultdict(<class 'int'>, {'2019-05-07': 2, '2019-05-01': 2})
# osf.io/epraq
# osf.io/y39k7
# osf.io/6s3dz
# osf.io/p6hxu
# defaultdict(<class 'int'>, {'2019-05-23': 1, '2019-04-13': 1})
# osf.io/wns25
# osf.io/evuhd
# defaultdict(<class 'int'>, {'2019-05-23': 1, '2019-04-13': 1})
# osf.io/96zj5
# osf.io/wn7x4
# defaultdict(<class 'int'>, {'2019-05-23': 1, '2019-04-08': 1})
# osf.io/g9b5e
# osf.io/j3hf6
# defaultdict(<class 'int'>, {'2019-05-23': 1, '2019-04-08': 1})
# osf.io/kxbwe
# osf.io/et28w
# defaultdict(<class 'int'>, {'2019-05-23': 1, '2019-04-08': 1})
# osf.io/d63jb
# osf.io/vd4m8
# defaultdict(<class 'int'>, {'2019-05-23': 1, '2019-04-08': 1})
# osf.io/etysw
# osf.io/2ga84
# defaultdict(<class 'int'>, {'2019-05-05': 1, '2019-04-30': 1})
# osf.io/9gwsy
# osf.io/hgqm9
# defaultdict(<class 'int'>, {'2019-05-05': 1, '2019-05-01': 1})
# osf.io/c5bpv
# osf.io/ud5b7
# defaultdict(<class 'int'>, {'2019-05-04': 1, '2019-05-06': 1})
# osf.io/tj4we
# osf.io/zj2mv
# defaultdict(<class 'int'>, {'2019-05-03': 1, '2019-01-08': 1})
# osf.io/5wghr
# osf.io/8evtr
# defaultdict(<class 'int'>, {'2019-05-03': 1, '2019-01-08': 1, '2019-01-04': 1})
# osf.io/2qcvs
# osf.io/45dsb
# osf.io/yn7kj
# defaultdict(<class 'int'>, {'2019-05-02': 1, '2019-04-21': 1})
# osf.io/n8q9x
# osf.io/3zf7y
# defaultdict(<class 'int'>, {'2019-05-01': 1, '2019-04-29': 1})
# osf.io/79jqn
# osf.io/nh83d
# defaultdict(<class 'int'>, {'2019-05-01': 1, '2019-04-27': 1})
# osf.io/k82ca
# osf.io/2x7s9
# defaultdict(<class 'int'>, {'2019-04-30': 1, '2019-04-09': 1})
# osf.io/386sm
# osf.io/y7u6q
# defaultdict(<class 'int'>, {'2019-05-03': 1, '2019-04-30': 1})
# osf.io/zsf2a
# osf.io/v74up
# defaultdict(<class 'int'>, {'2019-05-01': 1, '2019-05-02': 1})
# osf.io/jzp98
# osf.io/mt8sv
# defaultdict(<class 'int'>, {'2019-04-29': 1, '2019-02-17': 1})
# osf.io/yj4qk
# osf.io/6djq9
# defaultdict(<class 'int'>, {'2019-04-28': 1, '2019-04-20': 1})
# osf.io/x93mr
# osf.io/426na
# defaultdict(<class 'int'>, {'2019-04-27': 1, '2019-04-30': 1})
# osf.io/e5jqn
# osf.io/4txsb
# defaultdict(<class 'int'>, {'2019-04-26': 1, '2018-11-17': 1})
# osf.io/yrb5x
# osf.io/7fzrd
# defaultdict(<class 'int'>, {'2019-04-25': 1, '2019-04-24': 7, '2019-04-23': 1, '2019-04-17': 1})
# osf.io/fvk79
# osf.io/7ts8j
# osf.io/9sbt2
# osf.io/j3d5t
# osf.io/jg25a
# osf.io/7j4y9
# osf.io/5qmw2
# osf.io/jv2mx
# osf.io/u9w3s
# osf.io/nq5sf
# defaultdict(<class 'int'>, {'2019-04-25': 1, '2019-04-12': 1})
# osf.io/5wzux
# osf.io/47r8d
# defaultdict(<class 'int'>, {'2019-04-25': 1, '2019-04-11': 1})
# osf.io/uwxa7
# osf.io/qksmd
# defaultdict(<class 'int'>, {'2019-04-25': 1, '2019-04-22': 1, '2019-04-11': 3})
# osf.io/qagne
# osf.io/c3hvj
# osf.io/wuj8c
# osf.io/3tu9s
# osf.io/jhm9z
# defaultdict(<class 'int'>, {'2019-04-25': 1, '2019-04-16': 1, '2019-04-11': 1})
# osf.io/v84sx
# osf.io/r3485
# osf.io/dwhev
# defaultdict(<class 'int'>, {'2019-04-25': 3, '2019-04-21': 1, '2019-04-11': 3})
# osf.io/pjkym
# osf.io/5r2bc
# osf.io/9qxec
# osf.io/52dhw
# osf.io/btc9r
# osf.io/vsj2b
# osf.io/h7gf2
# defaultdict(<class 'int'>, {'2019-04-25': 1, '2019-04-24': 1})
# osf.io/udr2h
# osf.io/4ezvf
# defaultdict(<class 'int'>, {'2019-04-24': 1, '2019-03-30': 1})
# osf.io/5w8up
# osf.io/nvg2h
# defaultdict(<class 'int'>, {'2019-04-24': 2, '2019-04-17': 1, '2019-04-16': 1, '2019-04-13': 3, '2019-04-12': 2})
# osf.io/qcbn3
# osf.io/hctsw
# osf.io/pwd6j
# osf.io/r2yxk
# osf.io/gxsk9
# osf.io/dmy9p
# osf.io/z9q6r
# osf.io/cke3n
# osf.io/4f98q
# defaultdict(<class 'int'>, {'2019-04-24': 2, '2019-04-17': 1, '2019-04-16': 1, '2019-04-13': 3, '2019-04-12': 2})
# osf.io/gaw8r
# osf.io/c7rbw
# osf.io/hsf89
# osf.io/fzkqs
# osf.io/jq98t
# osf.io/hbdsz
# osf.io/hgq42
# osf.io/u9kw7
# osf.io/qyjmh
# defaultdict(<class 'int'>, {'2019-04-24': 1, '2019-04-14': 1})
# osf.io/4q7er
# osf.io/pa74z
# defaultdict(<class 'int'>, {'2019-04-24': 1, '2019-04-21': 1, '2019-04-13': 1})
# osf.io/gs3cb
# osf.io/k25tr
# osf.io/qk64f
# defaultdict(<class 'int'>, {'2019-04-24': 1, '2019-04-21': 1, '2019-04-13': 1})
# osf.io/gz2y9
# osf.io/4mcya
# osf.io/jnsbz
# defaultdict(<class 'int'>, {'2019-04-24': 1, '2019-04-14': 1})
# osf.io/w9ezq
# osf.io/dr9be
# defaultdict(<class 'int'>, {'2019-04-24': 1, '2019-04-10': 5, '2019-04-09': 2})
# osf.io/c283y
# osf.io/esw7y
# osf.io/2jw5f
# osf.io/aw2ye
# osf.io/ja5cy
# osf.io/tdeyp
# osf.io/9shdr
# osf.io/29htz
# defaultdict(<class 'int'>, {'2019-04-24': 1, '2019-04-11': 1})
# osf.io/vxu7j
# osf.io/r48jx
# defaultdict(<class 'int'>, {'2019-04-24': 1, '2019-04-11': 1})
# osf.io/7pvk8
# osf.io/qpvk7
# defaultdict(<class 'int'>, {'2019-04-24': 1, '2019-04-14': 1})
# osf.io/up9m5
# osf.io/yrz7a
# defaultdict(<class 'int'>, {'2019-04-24': 1, '2019-04-11': 1, '2019-04-09': 1})
# osf.io/j94z8
# osf.io/bzscj
# osf.io/nhypz
# defaultdict(<class 'int'>, {'2019-04-24': 1, '2019-04-22': 1})
# osf.io/s9zm4
# osf.io/gbhcu
# defaultdict(<class 'int'>, {'2019-04-23': 1, '2019-03-28': 1})
# osf.io/b9apk
# osf.io/862zp
# defaultdict(<class 'int'>, {'2019-04-23': 1, '2019-04-09': 1})
# osf.io/m6ge2
# osf.io/t3kzb
# defaultdict(<class 'int'>, {'2019-04-22': 1, '2019-04-16': 1})
# osf.io/35ymr
# osf.io/abvmp
# defaultdict(<class 'int'>, {'2019-04-22': 1, '2019-04-16': 1})
# osf.io/9nywm
# osf.io/vtsw5
# defaultdict(<class 'int'>, {'2019-04-21': 1, '2019-04-20': 1})
# osf.io/6xewc
# osf.io/b4vtu
# defaultdict(<class 'int'>, {'2019-04-20': 1, '2019-04-19': 1})
# osf.io/dmt9k
# osf.io/4a7ke
# defaultdict(<class 'int'>, {'2019-04-19': 1, '2019-04-18': 1})
# osf.io/96pcm
# osf.io/8rtv5
# defaultdict(<class 'int'>, {'2019-04-20': 1, '2019-04-18': 1})
# osf.io/wkang
# osf.io/cmh8q
# defaultdict(<class 'int'>, {'2019-04-18': 1, '2019-04-15': 1})
# osf.io/a6vk3
# osf.io/9nda7
# defaultdict(<class 'int'>, {'2019-04-18': 1, '2019-04-15': 1})
# osf.io/8ca9s
# osf.io/rty6b
# defaultdict(<class 'int'>, {'2019-04-18': 3, '2019-04-17': 1})
# osf.io/rgvmd
# osf.io/xsft7
# osf.io/2ky36
# osf.io/crspf
# defaultdict(<class 'int'>, {'2019-04-17': 1, '2019-04-16': 1})
# osf.io/85e7v
# osf.io/g7j32
# defaultdict(<class 'int'>, {'2019-04-16': 1, '2018-06-25': 1})
# osf.io/n7ghz
# osf.io/8ywk3
# defaultdict(<class 'int'>, {'2019-04-15': 1, '2019-03-11': 1})
# osf.io/w35pc
# osf.io/b8he7
# defaultdict(<class 'int'>, {'2019-04-15': 1, '2019-03-30': 1})
# osf.io/t2rqy
# osf.io/y4e5c
# defaultdict(<class 'int'>, {'2019-04-14': 1, '2019-04-12': 1, '2019-03-29': 1})
# osf.io/yqv8j
# osf.io/yzxcg
# osf.io/nvpbh
# defaultdict(<class 'int'>, {'2019-04-13': 1, '2019-01-26': 1, '2019-01-07': 1, '2018-12-27': 1, '2018-12-11': 1, '2018-11-21': 2})
# osf.io/9f2sr
# osf.io/yfdj7
# osf.io/3mk2s
# osf.io/mf89p
# osf.io/9m4ns
# osf.io/xmw9q
# osf.io/x52jc
# defaultdict(<class 'int'>, {'2019-04-12': 1, '2019-03-30': 1})
# osf.io/jfncv
# osf.io/ckufr
# defaultdict(<class 'int'>, {'2019-04-12': 1, '2019-03-30': 1})
# osf.io/kmd69
# osf.io/4r69h
# defaultdict(<class 'int'>, {'2019-04-12': 1, '2019-03-30': 1})
# osf.io/64z3g
# osf.io/jb8q7
# defaultdict(<class 'int'>, {'2019-04-11': 1, '2019-03-30': 1, '2019-03-29': 1})
# osf.io/ta74b
# osf.io/hj6rz
# osf.io/9eqa7
# defaultdict(<class 'int'>, {'2019-04-10': 1, '2018-09-11': 1, '2018-05-13': 1})
# osf.io/qkx4a
# osf.io/x3b5y
# osf.io/yt4gr
# defaultdict(<class 'int'>, {'2019-04-11': 1, '2019-04-10': 1})
# osf.io/hr86y
# osf.io/2ph79
# defaultdict(<class 'int'>, {'2019-04-09': 1, '2019-04-08': 1})
# osf.io/bx7j2
# osf.io/gq235
# defaultdict(<class 'int'>, {'2019-04-07': 1, '2019-03-20': 1})
# osf.io/9wjmg
# osf.io/wvum2
# defaultdict(<class 'int'>, {'2019-04-05': 1, '2019-01-10': 3})
# osf.io/f2x6r
# osf.io/bp2cu
# osf.io/ecjth
# osf.io/8mwes
# defaultdict(<class 'int'>, {'2019-04-04': 1, '2019-01-23': 1})
# osf.io/wgxkb
# osf.io/bknrf
# defaultdict(<class 'int'>, {'2019-04-04': 1, '2019-03-29': 1, '2019-03-28': 2})
# osf.io/hc78e
# osf.io/47wfd
# osf.io/j6s4q
# osf.io/mqxtn
# defaultdict(<class 'int'>, {'2019-04-04': 1, '2018-05-03': 1})
# osf.io/2e8k7
# osf.io/gv7eh
# defaultdict(<class 'int'>, {'2019-04-02': 1, '2018-11-18': 1})
# osf.io/e6gyn
# osf.io/jrh9g
# defaultdict(<class 'int'>, {'2019-04-01': 2, '2019-03-20': 1, '2019-01-21': 1, '2018-12-13': 1})
# osf.io/y4m8c
# osf.io/ntjyu
# osf.io/stz9g
# osf.io/qwftu
# osf.io/equt7
# defaultdict(<class 'int'>, {'2019-03-31': 1, '2018-10-12': 1})
# osf.io/7jfqk
# osf.io/gtn5p
# defaultdict(<class 'int'>, {'2019-03-31': 1, '2019-02-25': 1})
# osf.io/ehcwt
# osf.io/h4y8z
# defaultdict(<class 'int'>, {'2019-03-31': 1, '2019-03-18': 1})
# osf.io/4avh2
# osf.io/7grmx
# defaultdict(<class 'int'>, {'2019-03-30': 1, '2018-12-27': 1, '2018-11-19': 2})
# osf.io/v4pse
# osf.io/wmk8f
# osf.io/dzba9
# osf.io/gu5qf
# defaultdict(<class 'int'>, {'2019-03-30': 1, '2018-11-02': 1})
# osf.io/4vjef
# osf.io/6bh29
# defaultdict(<class 'int'>, {'2019-03-30': 1, '2019-03-28': 1})
# osf.io/awknq
# osf.io/hv8mk
# defaultdict(<class 'int'>, {'2019-03-29': 1, '2019-01-25': 1})
# osf.io/kpdfq
# osf.io/xct2w
# defaultdict(<class 'int'>, {'2019-03-29': 1, '2019-01-28': 1, '2018-12-26': 1, '2018-12-20': 3, '2018-12-12': 1})
# osf.io/dfazu
# osf.io/z5yaj
# osf.io/stgz5
# osf.io/vzhcn
# osf.io/dvzrm
# osf.io/gv7nk
# osf.io/taezc
# defaultdict(<class 'int'>, {'2019-03-29': 1, '2019-03-28': 2})
# osf.io/hzb87
# osf.io/m69c3
# osf.io/tupdf
# defaultdict(<class 'int'>, {'2019-03-28': 1, '2019-02-10': 2, '2019-02-09': 1, '2019-01-30': 1, '2019-01-26': 1, '2018-11-26': 1, '2018-11-25': 1, '2018-11-24': 1, '2018-11-23': 2, '2018-11-22': 4, '2018-11-21': 2, '2018-11-20': 1, '2018-11-19': 1, '2018-11-17': 1, '2018-11-16': 1})
# osf.io/hr9b6
# osf.io/94rwb
# osf.io/8z3hr
# osf.io/bxumd
# osf.io/xhwfu
# osf.io/nx396
# osf.io/grw2e
# osf.io/9ec57
# osf.io/nwfrx
# osf.io/wug7d
# osf.io/7wd2r
# osf.io/tz2b4
# osf.io/7qtcb
# osf.io/ns3z8
# osf.io/t34wd
# osf.io/urf8g
# osf.io/et57w
# osf.io/7x9h4
# osf.io/2vy4k
# osf.io/h2pa4
# osf.io/gpf7q
# defaultdict(<class 'int'>, {'2019-03-28': 1, '2018-12-18': 1})
# osf.io/t7nqa
# osf.io/c4ks5
# defaultdict(<class 'int'>, {'2019-03-28': 1, '2018-12-27': 1})
# osf.io/7jv4m
# osf.io/7g5s2
# defaultdict(<class 'int'>, {'2019-03-27': 1, '2019-03-20': 1})
# osf.io/mzfh6
# osf.io/94de8
# defaultdict(<class 'int'>, {'2019-03-26': 2, '2019-02-01': 1})
# osf.io/d93vf
# osf.io/8taem
# osf.io/g9ecb
# defaultdict(<class 'int'>, {'2019-03-25': 2, '2018-05-27': 1})
# osf.io/nbxkq
# osf.io/tmq93
# osf.io/86p7b
# defaultdict(<class 'int'>, {'2019-03-25': 1, '2018-08-01': 1})
# osf.io/3vnsz
# osf.io/pxrv6
# defaultdict(<class 'int'>, {'2019-03-25': 1, '2019-03-23': 1})
# osf.io/k26tq
# osf.io/hua4k
# defaultdict(<class 'int'>, {'2019-03-23': 1, '2018-12-31': 1})
# osf.io/nxysh
# osf.io/8vwaz
# defaultdict(<class 'int'>, {'2019-03-22': 1, '2019-02-25': 1, '2019-02-17': 1})
# osf.io/fs3qk
# osf.io/dhr84
# osf.io/8gure
# defaultdict(<class 'int'>, {'2019-03-21': 1, '2019-02-19': 1})
# osf.io/qvf38
# osf.io/vtyuh
# defaultdict(<class 'int'>, {'2019-03-20': 1, '2019-03-19': 1})
# osf.io/8xpyg
# osf.io/uf38j
# defaultdict(<class 'int'>, {'2019-03-19': 1, '2019-03-11': 1})
# osf.io/vwe4g
# osf.io/9a8z7
# defaultdict(<class 'int'>, {'2019-03-18': 1, '2019-03-09': 1})
# osf.io/y8wdu
# osf.io/7wt8s
# defaultdict(<class 'int'>, {'2019-03-18': 1, '2019-03-01': 1})
# osf.io/m4gte
# osf.io/392df
# defaultdict(<class 'int'>, {'2019-03-18': 1, '2019-02-24': 1})
# osf.io/bd8gz
# osf.io/tyzdu
# defaultdict(<class 'int'>, {'2019-03-17': 1, '2019-03-05': 1, '2019-02-17': 1})
# osf.io/fc8mg
# osf.io/dk4tw
# osf.io/btnxr
# defaultdict(<class 'int'>, {'2019-03-16': 1, '2019-03-15': 1})
# osf.io/yxusz
# osf.io/mz6ta
# defaultdict(<class 'int'>, {'2019-03-16': 1, '2019-03-15': 1})
# osf.io/ja95c
# osf.io/f6j4m
# defaultdict(<class 'int'>, {'2019-03-16': 1, '2019-03-15': 1})
# osf.io/hk9v6
# osf.io/894ks
# defaultdict(<class 'int'>, {'2019-03-16': 1, '2019-03-15': 1})
# osf.io/pywb8
# osf.io/ktmce
# defaultdict(<class 'int'>, {'2019-03-15': 1, '2019-03-06': 2, '2019-03-01': 1})
# osf.io/684h7
# osf.io/8r9vs
# osf.io/4zh7k
# osf.io/24j9z
# defaultdict(<class 'int'>, {'2019-03-14': 1, '2018-09-21': 1})
# osf.io/9qjpe
# osf.io/gw926
# defaultdict(<class 'int'>, {'2019-03-14': 1, '2018-09-21': 1})
# osf.io/qdkb5
# osf.io/zxnbv
# defaultdict(<class 'int'>, {'2019-03-11': 1, '2018-11-09': 1})
# osf.io/497xr
# osf.io/4z39a
# defaultdict(<class 'int'>, {'2019-03-11': 1, '2018-11-09': 1})
# osf.io/wkz9j
# osf.io/3n4re
# defaultdict(<class 'int'>, {'2019-03-09': 1, '2019-03-02': 2})
# osf.io/my65q
# osf.io/z67gd
# osf.io/hpbng
# defaultdict(<class 'int'>, {'2019-03-08': 1, '2019-02-28': 1})
# osf.io/4dbmc
# osf.io/n92gc
# defaultdict(<class 'int'>, {'2019-03-07': 1, '2018-05-08': 1})
# osf.io/am4vx
# osf.io/yravm
# defaultdict(<class 'int'>, {'2019-03-07': 1, '2018-10-02': 1, '2018-09-30': 1})
# osf.io/hrzbw
# osf.io/7r6fw
# osf.io/rcp2g
# defaultdict(<class 'int'>, {'2019-03-07': 1, '2018-10-02': 1, '2018-09-28': 1})
# osf.io/nua2x
# osf.io/8phn2
# osf.io/79ext
# defaultdict(<class 'int'>, {'2019-03-07': 1, '2018-08-29': 1})
# osf.io/pjkw5
# osf.io/tp8qa
# defaultdict(<class 'int'>, {'2019-03-07': 1, '2019-02-24': 1})
# osf.io/aeb9q
# osf.io/tybmr
# defaultdict(<class 'int'>, {'2019-03-07': 1, '2019-02-25': 1, '2019-02-24': 2, '2019-02-22': 1})
# osf.io/vn3bt
# osf.io/ch4z6
# osf.io/ky7wn
# osf.io/syvre
# osf.io/69xwg
# defaultdict(<class 'int'>, {'2019-03-06': 1, '2019-02-24': 1})
# osf.io/y5du2
# osf.io/u8znf
# defaultdict(<class 'int'>, {'2019-03-01': 1, '2019-02-26': 1})
# osf.io/y4edt
# osf.io/pzm73
# defaultdict(<class 'int'>, {'2019-02-28': 1, '2019-02-26': 1})
# osf.io/gujzd
# osf.io/auyt5
# defaultdict(<class 'int'>, {'2019-02-28': 2, '2019-02-27': 1})
# osf.io/hys3k
# osf.io/cr5xu
# osf.io/gqys2
# defaultdict(<class 'int'>, {'2019-02-28': 4, '2019-02-27': 2})
# osf.io/k8sgc
# osf.io/7eycn
# osf.io/rxfns
# osf.io/9pby4
# osf.io/fd9pv
# osf.io/y7bu5
# defaultdict(<class 'int'>, {'2019-02-28': 1, '2019-02-17': 1, '2019-02-15': 1})
# osf.io/d7wbr
# osf.io/bd823
# osf.io/prcm6
# defaultdict(<class 'int'>, {'2019-02-28': 1, '2019-02-27': 2})
# osf.io/py53j
# osf.io/x4nd7
# osf.io/u3t5z
# defaultdict(<class 'int'>, {'2019-02-28': 1, '2019-02-26': 1})
# osf.io/sj6cg
# osf.io/bgpr9
# defaultdict(<class 'int'>, {'2019-02-27': 1, '2017-12-28': 1, '2017-12-02': 1})
# osf.io/wyt25
# osf.io/hrtyz
# osf.io/ky6nq
# defaultdict(<class 'int'>, {'2019-02-27': 1, '2018-12-15': 1})
# osf.io/tca4z
# osf.io/rfsyx
# defaultdict(<class 'int'>, {'2019-02-27': 1, '2019-02-24': 1})
# osf.io/76p2d
# osf.io/m53r6
# defaultdict(<class 'int'>, {'2019-02-27': 1, '2019-02-26': 1})
# osf.io/rbgnc
# osf.io/y4en5
# defaultdict(<class 'int'>, {'2019-02-27': 2, '2019-02-26': 2, '2019-02-22': 1})
# osf.io/hrgc7
# osf.io/q7pdv
# osf.io/mvq3r
# osf.io/gfyqc
# osf.io/25dah
# defaultdict(<class 'int'>, {'2019-02-27': 1, '2019-02-18': 1})
# osf.io/dm8yk
# osf.io/e8vjq
# defaultdict(<class 'int'>, {'2019-02-26': 1, '2019-02-15': 1})
# osf.io/mp4wk
# osf.io/3hbsj
# defaultdict(<class 'int'>, {'2019-02-26': 1, '2019-02-25': 1})
# osf.io/mgd6a
# osf.io/wzjaq
# defaultdict(<class 'int'>, {'2019-02-25': 3, '2019-02-18': 1})
# osf.io/btwyj
# osf.io/b5hx7
# osf.io/unejq
# osf.io/e4rxv
# defaultdict(<class 'int'>, {'2019-02-25': 2, '2019-02-24': 2})
# osf.io/ncax8
# osf.io/ce7gk
# osf.io/fpbjq
# osf.io/kweab
# defaultdict(<class 'int'>, {'2019-02-25': 1, '2019-02-23': 1})
# osf.io/we2qr
# osf.io/3yunr
# defaultdict(<class 'int'>, {'2019-03-05': 1, '2019-02-20': 1, '2019-02-17': 1})
# osf.io/zqamh
# osf.io/7abuq
# osf.io/mcwbh
# defaultdict(<class 'int'>, {'2019-03-05': 1, '2019-02-14': 1})
# osf.io/qxym6
# osf.io/36wnf
# defaultdict(<class 'int'>, {'2019-02-24': 1, '2018-12-11': 1})
# osf.io/t64av
# osf.io/fh7zb
# defaultdict(<class 'int'>, {'2019-02-23': 1, '2019-02-04': 1})
# osf.io/68n3k
# osf.io/8bjyr
# defaultdict(<class 'int'>, {'2019-02-23': 1, '2019-02-04': 1})
# osf.io/h5rk7
# osf.io/qrkv2
# defaultdict(<class 'int'>, {'2019-02-22': 1, '2019-02-13': 1})
# osf.io/6cuw3
# osf.io/hcgz3
# defaultdict(<class 'int'>, {'2019-02-21': 1, '2018-10-12': 1})
# osf.io/pdur9
# osf.io/uj79b
# defaultdict(<class 'int'>, {'2019-02-21': 1, '2019-02-17': 1})
# osf.io/s7fg9
# osf.io/fdv5e
# defaultdict(<class 'int'>, {'2019-02-21': 1, '2019-02-07': 2})
# osf.io/qfybj
# osf.io/s4nad
# osf.io/6j5nr
# defaultdict(<class 'int'>, {'2019-02-20': 1, '2019-02-17': 1, '2019-02-08': 1})
# osf.io/w8v4a
# osf.io/qrpft
# osf.io/69mq7
# defaultdict(<class 'int'>, {'2019-02-20': 1, '2018-10-13': 1})
# osf.io/u34we
# osf.io/sepv4
# defaultdict(<class 'int'>, {'2019-02-20': 1, '2018-10-13': 1})
# osf.io/yw39u
# osf.io/6nx7m
# defaultdict(<class 'int'>, {'2019-02-19': 1, '2017-12-30': 1})
# osf.io/3dhcg
# osf.io/9w26e
# defaultdict(<class 'int'>, {'2019-02-16': 1, '2019-02-02': 1})
# osf.io/kfq78
# osf.io/ux5z9
# defaultdict(<class 'int'>, {'2019-02-14': 1, '2019-01-30': 1})
# osf.io/dqv8g
# osf.io/zces5
# defaultdict(<class 'int'>, {'2019-02-14': 1, '2019-01-31': 1})
# osf.io/e65qf
# osf.io/fb69w
# defaultdict(<class 'int'>, {'2019-02-14': 1, '2019-01-31': 1})
# osf.io/v9n8z
# osf.io/7kr4v
# defaultdict(<class 'int'>, {'2019-02-12': 1, '2019-02-03': 1})
# osf.io/7gcb8
# osf.io/3vwsa
# defaultdict(<class 'int'>, {'2019-02-11': 1, '2019-02-01': 1, '2019-01-29': 1})
# osf.io/c76tk
# osf.io/86gtm
# osf.io/s3y8v
# defaultdict(<class 'int'>, {'2019-02-10': 1, '2019-01-30': 1})
# osf.io/xhgqw
# osf.io/n638j
# defaultdict(<class 'int'>, {'2019-02-10': 1, '2018-12-22': 1})
# osf.io/efvxu
# osf.io/pd3mj
# defaultdict(<class 'int'>, {'2019-02-10': 1, '2018-12-18': 2})
# osf.io/qfxne
# osf.io/qhcbt
# osf.io/49m72
# defaultdict(<class 'int'>, {'2019-02-10': 3, '2019-02-09': 1, '2019-01-29': 1})
# osf.io/46exr
# osf.io/esra9
# osf.io/hvdcj
# osf.io/vnk6z
# osf.io/m5tbh
# defaultdict(<class 'int'>, {'2019-02-10': 1, '2019-02-09': 1, '2019-01-29': 1})
# osf.io/t7zak
# osf.io/jxkh2
# osf.io/spzte
# defaultdict(<class 'int'>, {'2019-02-10': 1, '2019-01-25': 4})
# osf.io/rs724
# osf.io/6qr3p
# osf.io/yt3rc
# osf.io/h572x
# osf.io/s9rvq
# defaultdict(<class 'int'>, {'2019-02-10': 1, '2019-01-31': 1})
# osf.io/5msyh
# osf.io/48vzc
# defaultdict(<class 'int'>, {'2019-02-10': 1, '2018-12-18': 1, '2018-12-14': 1})
# osf.io/4d7wf
# osf.io/vtp9f
# osf.io/dwf8s
# defaultdict(<class 'int'>, {'2019-02-10': 1, '2019-01-31': 1, '2019-01-26': 1})
# osf.io/guwye
# osf.io/ujgka
# osf.io/dnvfe
# defaultdict(<class 'int'>, {'2019-02-10': 1, '2019-01-21': 1})
# osf.io/hwby5
# osf.io/yhb5a
# defaultdict(<class 'int'>, {'2019-02-10': 1, '2019-01-26': 1})
# osf.io/ygtzs
# osf.io/pdbgx
# defaultdict(<class 'int'>, {'2019-02-09': 1, '2019-01-27': 1})
# osf.io/yr7hu
# osf.io/s8kx6
# defaultdict(<class 'int'>, {'2019-02-09': 1, '2018-12-24': 1})
# osf.io/uf2n5
# osf.io/93mx6
# defaultdict(<class 'int'>, {'2019-02-09': 1, '2018-12-12': 1})
# osf.io/gakmv
# osf.io/jqmxh
# defaultdict(<class 'int'>, {'2019-02-09': 1, '2018-12-19': 1})
# osf.io/qxkbt
# osf.io/emswu
# defaultdict(<class 'int'>, {'2019-02-09': 1, '2018-11-26': 1, '2018-11-22': 1, '2018-11-19': 1})
# osf.io/2zbef
# osf.io/fn582
# osf.io/5rkqv
# osf.io/gxjr4
# defaultdict(<class 'int'>, {'2019-02-09': 1, '2019-01-23': 1})
# osf.io/veag5
# osf.io/8kurw
# defaultdict(<class 'int'>, {'2019-02-09': 1, '2019-01-23': 1})
# osf.io/kduxq
# osf.io/gxdwp
# defaultdict(<class 'int'>, {'2019-02-09': 1, '2018-12-27': 1})
# osf.io/uzanw
# osf.io/p6frq
# defaultdict(<class 'int'>, {'2019-02-09': 1, '2018-12-21': 1})
# osf.io/tg4rm
# osf.io/npq4b
# defaultdict(<class 'int'>, {'2019-02-09': 1, '2018-12-27': 1})
# osf.io/7j9xq
# osf.io/nfhyd
# defaultdict(<class 'int'>, {'2019-02-09': 1, '2019-01-29': 1})
# osf.io/srudc
# osf.io/2s5np
# defaultdict(<class 'int'>, {'2019-02-09': 1, '2018-12-23': 1})
# osf.io/f5taz
# osf.io/ndzyp
# defaultdict(<class 'int'>, {'2019-02-09': 1, '2018-12-19': 1})
# osf.io/tb2p9
# osf.io/nstb8
# defaultdict(<class 'int'>, {'2019-02-09': 1, '2018-12-25': 1})
# osf.io/tbu5q
# osf.io/wd6gq
# defaultdict(<class 'int'>, {'2019-02-08': 1, '2018-11-26': 1})
# osf.io/jb3kq
# osf.io/87vky
# defaultdict(<class 'int'>, {'2019-02-07': 1, '2019-01-12': 1})
# osf.io/6dbux
# osf.io/fudpy
# defaultdict(<class 'int'>, {'2019-02-07': 1, '2017-11-17': 1})
# osf.io/zyhj4
# osf.io/swh27
# defaultdict(<class 'int'>, {'2019-02-06': 1, '2019-02-01': 2})
# osf.io/26tqc
# osf.io/hjdka
# osf.io/atnw6
# defaultdict(<class 'int'>, {'2019-02-06': 1, '2018-12-17': 1})
# osf.io/b3sr9
# osf.io/bt6xs
# defaultdict(<class 'int'>, {'2019-02-05': 2, '2018-11-17': 1})
# osf.io/x286m
# osf.io/sj7t8
# osf.io/r4ep3
# defaultdict(<class 'int'>, {'2019-02-04': 1, '2019-01-30': 1})
# osf.io/bjvny
# osf.io/g6ren
# defaultdict(<class 'int'>, {'2019-02-04': 1, '2019-02-01': 1})
# osf.io/dwa7p
# osf.io/r89fw
# defaultdict(<class 'int'>, {'2019-02-04': 1, '2018-12-22': 1})
# osf.io/7vfk4
# osf.io/jqcgz
# defaultdict(<class 'int'>, {'2019-02-03': 1, '2019-02-12': 1})
# osf.io/gwu4h
# osf.io/3muny
# defaultdict(<class 'int'>, {'2019-02-03': 1, '2019-02-01': 1})
# osf.io/279hm
# osf.io/uxrkv
# defaultdict(<class 'int'>, {'2019-02-02': 1, '2019-01-31': 2})
# osf.io/ycvrh
# osf.io/gd3vj
# osf.io/tpsvb
# defaultdict(<class 'int'>, {'2019-02-01': 1, '2019-01-31': 1})
# osf.io/jgdw5
# osf.io/e486z
# defaultdict(<class 'int'>, {'2019-02-01': 1, '2019-01-31': 1, '2019-01-29': 1})
# osf.io/yqtku
# osf.io/e87sq
# osf.io/d456p
# defaultdict(<class 'int'>, {'2019-02-01': 1, '2019-01-29': 1})
# osf.io/qpwh6
# osf.io/m37xj
# defaultdict(<class 'int'>, {'2019-01-31': 1, '2019-01-26': 1})
# osf.io/yd24e
# osf.io/6h743
# defaultdict(<class 'int'>, {'2019-01-31': 1, '2019-01-23': 1})
# osf.io/wpc4h
# osf.io/ybtzq
# defaultdict(<class 'int'>, {'2019-01-31': 2, '2019-01-30': 1})
# osf.io/y76uv
# osf.io/kjcrb
# osf.io/qrxu5
# defaultdict(<class 'int'>, {'2019-01-31': 3, '2019-01-30': 3})
# osf.io/erw2g
# osf.io/yudv8
# osf.io/qmgdt
# osf.io/32uwg
# osf.io/r3xwb
# osf.io/gxd6u
# defaultdict(<class 'int'>, {'2019-01-31': 1, '2019-01-30': 3})
# osf.io/my23q
# osf.io/phn2q
# osf.io/9r5wp
# osf.io/b9zuq
# defaultdict(<class 'int'>, {'2019-01-31': 1, '2019-01-30': 2})
# osf.io/bcgxa
# osf.io/2zuct
# osf.io/y4wue
# defaultdict(<class 'int'>, {'2019-01-31': 3, '2018-12-26': 2, '2018-12-12': 1, '2018-11-18': 2})
# osf.io/69kfr
# osf.io/hszxc
# osf.io/gvd3a
# osf.io/g3fwr
# osf.io/f6buc
# osf.io/v9tks
# osf.io/4ra87
# osf.io/x7vqg
# defaultdict(<class 'int'>, {'2019-01-29': 1, '2018-12-12': 1})
# osf.io/9pgk2
# osf.io/wgz58
# defaultdict(<class 'int'>, {'2019-01-28': 1, '2019-01-27': 1, '2019-01-17': 1, '2019-01-09': 1})
# osf.io/hke6j
# osf.io/jcx5g
# osf.io/6pnuz
# osf.io/naxz3
# defaultdict(<class 'int'>, {'2019-01-26': 1, '2019-01-24': 1})
# osf.io/swkam
# osf.io/hc4br
# defaultdict(<class 'int'>, {'2019-01-26': 1, '2018-12-20': 1, '2018-11-20': 1})
# osf.io/3w2gx
# osf.io/tva26
# osf.io/b35fn
# defaultdict(<class 'int'>, {'2019-01-26': 1, '2019-01-20': 1})
# osf.io/vd2sz
# osf.io/q768k
# defaultdict(<class 'int'>, {'2019-01-24': 1, '2018-12-25': 1, '2018-12-20': 1, '2018-12-12': 1, '2018-11-19': 2})
# osf.io/kardb
# osf.io/s7v52
# osf.io/cu9h3
# osf.io/5qjm6
# osf.io/hcqk9
# osf.io/3qbxr
# defaultdict(<class 'int'>, {'2019-01-24': 1, '2018-12-25': 1, '2018-12-20': 1, '2018-11-19': 1})
# osf.io/4ag29
# osf.io/dgr83
# osf.io/pjexs
# osf.io/zpvah
# defaultdict(<class 'int'>, {'2019-01-24': 1, '2019-01-22': 1})
# osf.io/fc354
# osf.io/wn9hq
# defaultdict(<class 'int'>, {'2019-01-23': 1, '2019-01-22': 1})
# osf.io/kh9bf
# osf.io/pjcyq
# defaultdict(<class 'int'>, {'2019-01-22': 1, '2019-01-20': 1})
# osf.io/y742b
# osf.io/43vmt
# defaultdict(<class 'int'>, {'2019-01-22': 1, '2019-01-18': 1})
# osf.io/pmu8q
# osf.io/dyp9x
# defaultdict(<class 'int'>, {'2019-01-21': 1, '2019-01-20': 3, '2019-01-19': 1, '2019-01-18': 2, '2019-01-17': 1})
# osf.io/m3y8v
# osf.io/gpvrc
# osf.io/x6nzp
# osf.io/e86px
# osf.io/n2jtc
# osf.io/mwdk7
# osf.io/8x7bp
# osf.io/aykpu
# defaultdict(<class 'int'>, {'2019-01-21': 1, '2019-01-16': 1})
# osf.io/tqd6b
# osf.io/rw8e9
# defaultdict(<class 'int'>, {'2019-01-21': 1, '2019-01-20': 3, '2019-01-18': 1, '2019-01-17': 2})
# osf.io/w6y83
# osf.io/rygnj
# osf.io/u6z7w
# osf.io/72p3d
# osf.io/s3v8a
# osf.io/v9n6h
# osf.io/59ywa
# defaultdict(<class 'int'>, {'2019-01-21': 1, '2019-01-20': 1})
# osf.io/re4bs
# osf.io/yfq9b
# defaultdict(<class 'int'>, {'2019-01-20': 1, '2019-01-17': 1})
# osf.io/jpgbv
# osf.io/2ad43
# defaultdict(<class 'int'>, {'2019-01-20': 1, '2019-01-18': 1})
# osf.io/s6zkf
# osf.io/xumh6
# defaultdict(<class 'int'>, {'2019-01-20': 1, '2019-01-17': 2})
# osf.io/r9cyp
# osf.io/9hujf
# osf.io/u8dzq
# defaultdict(<class 'int'>, {'2019-01-20': 1, '2019-01-18': 1})
# osf.io/eg6ak
# osf.io/p46ez
# defaultdict(<class 'int'>, {'2019-01-15': 2, '2019-01-14': 1})
# osf.io/8anej
# osf.io/znvpk
# osf.io/pnrw4
# defaultdict(<class 'int'>, {'2019-01-15': 1, '2019-01-18': 1})
# osf.io/gq2ew
# osf.io/d3sx2
# defaultdict(<class 'int'>, {'2019-01-13': 1, '2018-12-24': 2, '2018-12-23': 1, '2018-12-14': 1})
# osf.io/k7u3y
# osf.io/k87rp
# osf.io/3epsy
# osf.io/euwn7
# osf.io/fhsmp
# defaultdict(<class 'int'>, {'2019-01-09': 1, '2019-01-07': 1, '2019-01-04': 1})
# osf.io/46ncp
# osf.io/d8ar9
# osf.io/zcqgr
# defaultdict(<class 'int'>, {'2019-01-08': 1, '2019-01-04': 1})
# osf.io/5bfmj
# osf.io/mtyd3
# defaultdict(<class 'int'>, {'2019-01-08': 1, '2019-01-04': 1})
# osf.io/hsnvq
# osf.io/uscwv
# defaultdict(<class 'int'>, {'2019-01-08': 1, '2019-01-04': 1})
# osf.io/7mzqp
# osf.io/yk3zt
# defaultdict(<class 'int'>, {'2019-01-08': 1, '2019-01-04': 2})
# osf.io/uch36
# osf.io/pbvys
# osf.io/gcerk
# defaultdict(<class 'int'>, {'2019-01-07': 1, '2019-01-04': 1, '2018-12-26': 1, '2018-12-12': 1})
# osf.io/c6jpa
# osf.io/yr4vp
# osf.io/xm32p
# osf.io/4dbhg
# defaultdict(<class 'int'>, {'2019-01-07': 1, '2019-01-04': 1})
# osf.io/mh8d5
# osf.io/rft7d
# defaultdict(<class 'int'>, {'2019-01-07': 1, '2019-01-04': 1})
# osf.io/hjtgv
# osf.io/b3rk6
# defaultdict(<class 'int'>, {'2019-01-06': 1, '2018-12-30': 1})
# osf.io/z58dr
# osf.io/kd6jb
# defaultdict(<class 'int'>, {'2019-01-06': 1, '2018-12-19': 1})
# osf.io/p9kvu
# osf.io/zse83
# defaultdict(<class 'int'>, {'2019-01-05': 1, '2018-12-20': 1})
# osf.io/rv2w6
# osf.io/dvrtn
# defaultdict(<class 'int'>, {'2019-01-03': 1, '2019-01-04': 1})
# osf.io/mkshn
# osf.io/n9s4m
# defaultdict(<class 'int'>, {'2019-01-02': 1, '2018-12-26': 1})
# osf.io/hf7qp
# osf.io/5rhv8
# defaultdict(<class 'int'>, {'2018-12-30': 1, '2018-12-29': 1})
# osf.io/rgkqj
# osf.io/6vk8g
# defaultdict(<class 'int'>, {'2018-12-30': 1, '2018-12-29': 1})
# osf.io/rdn34
# osf.io/cm36r
# defaultdict(<class 'int'>, {'2018-12-30': 1, '2018-12-27': 1})
# osf.io/bmhav
# osf.io/56j2e
# defaultdict(<class 'int'>, {'2018-12-29': 1, '2018-11-17': 1})
# osf.io/p64wu
# osf.io/2kph4
# defaultdict(<class 'int'>, {'2018-12-27': 1, '2018-12-25': 1, '2018-11-18': 2})
# osf.io/7ysh6
# osf.io/43b5j
# osf.io/a7gxk
# osf.io/pg86h
# defaultdict(<class 'int'>, {'2018-12-27': 2, '2018-12-14': 1, '2018-11-19': 2})
# osf.io/w8cpg
# osf.io/9gqep
# osf.io/smuhd
# osf.io/4qmpe
# osf.io/4tcx5
# defaultdict(<class 'int'>, {'2018-12-27': 1, '2018-12-26': 1, '2018-12-11': 1, '2018-11-25': 2})
# osf.io/3zfae
# osf.io/b9spz
# osf.io/fjuk7
# osf.io/qb8dk
# osf.io/h3wj2
# defaultdict(<class 'int'>, {'2018-12-26': 1, '2018-12-19': 1})
# osf.io/kqa4u
# osf.io/ycs8d
# defaultdict(<class 'int'>, {'2018-12-26': 1, '2018-11-21': 2})
# osf.io/3jrfc
# osf.io/tuhkc
# osf.io/qwtmc
# defaultdict(<class 'int'>, {'2018-12-26': 1, '2018-12-25': 1})
# osf.io/29765
# osf.io/ds2e7
# defaultdict(<class 'int'>, {'2018-12-26': 1, '2018-12-18': 1})
# osf.io/dne89
# osf.io/fnhzc
# defaultdict(<class 'int'>, {'2018-12-25': 1, '2018-12-17': 1})
# osf.io/x74n3
# osf.io/5vt3f
# defaultdict(<class 'int'>, {'2018-12-24': 2, '2018-12-12': 1, '2018-11-18': 2})
# osf.io/6fkh4
# osf.io/5yg46
# osf.io/rqy9b
# osf.io/2efzc
# osf.io/56hqv
# defaultdict(<class 'int'>, {'2018-12-24': 3, '2018-12-22': 3, '2018-11-17': 1})
# osf.io/hvbn5
# osf.io/p8w9v
# osf.io/aup5y
# osf.io/y25az
# osf.io/k4d3y
# osf.io/rq3gv
# osf.io/hf6rn
# defaultdict(<class 'int'>, {'2018-12-24': 1, '2018-12-08': 1})
# osf.io/jeqnc
# osf.io/b2rdh
# defaultdict(<class 'int'>, {'2018-12-23': 1, '2018-12-05': 1})
# osf.io/5nkhg
# osf.io/uf7tg
# defaultdict(<class 'int'>, {'2018-12-23': 2, '2018-12-19': 1})
# osf.io/ma87u
# osf.io/97yqk
# osf.io/gyr34
# defaultdict(<class 'int'>, {'2018-12-23': 1, '2018-12-10': 1})
# osf.io/db49m
# osf.io/4pqsc
# defaultdict(<class 'int'>, {'2018-12-22': 1, '2018-12-19': 1})
# osf.io/xmzc3
# osf.io/7u9a8
# defaultdict(<class 'int'>, {'2018-12-21': 1, '2018-06-19': 1})
# osf.io/sn4ep
# osf.io/kj5c4
# defaultdict(<class 'int'>, {'2018-12-21': 1, '2018-11-20': 1})
# osf.io/5s7kw
# osf.io/27zdt
# defaultdict(<class 'int'>, {'2018-12-20': 1, '2018-12-13': 1})
# osf.io/dh32x
# osf.io/n4kra
# defaultdict(<class 'int'>, {'2018-12-20': 1, '2018-12-13': 1})
# osf.io/et642
# osf.io/f6neu
# defaultdict(<class 'int'>, {'2018-12-20': 2, '2018-12-15': 1})
# osf.io/z3t4m
# osf.io/8xsd6
# osf.io/jgvcd
# defaultdict(<class 'int'>, {'2018-12-20': 1, '2018-12-12': 1})
# osf.io/ek94j
# osf.io/4b3ac
# defaultdict(<class 'int'>, {'2018-12-19': 1, '2018-12-17': 1})
# osf.io/gd7b3
# osf.io/ga8hv
# defaultdict(<class 'int'>, {'2018-12-16': 1, '2018-11-29': 1})
# osf.io/nx59v
# osf.io/6tfwg
# defaultdict(<class 'int'>, {'2018-12-16': 1, '2018-11-29': 1})
# osf.io/zgkqp
# osf.io/ry536
# defaultdict(<class 'int'>, {'2018-12-16': 1, '2018-11-29': 1})
# osf.io/w2kr9
# osf.io/962sc
# defaultdict(<class 'int'>, {'2018-12-16': 1, '2018-11-29': 1})
# osf.io/bsza6
# osf.io/9n82q
# defaultdict(<class 'int'>, {'2018-12-16': 1, '2018-12-14': 1})
# osf.io/rk8yv
# osf.io/f7nbp
# defaultdict(<class 'int'>, {'2018-12-16': 1, '2018-12-14': 1})
# osf.io/fxyh7
# osf.io/zj763
# defaultdict(<class 'int'>, {'2018-12-16': 1, '2018-09-28': 1})
# osf.io/zgrnq
# osf.io/dfa4b
# defaultdict(<class 'int'>, {'2018-12-14': 1, '2018-11-21': 2})
# osf.io/bshd8
# osf.io/hs2mw
# osf.io/5un2w
# defaultdict(<class 'int'>, {'2018-12-13': 1, '2018-11-27': 1})
# osf.io/kvqmp
# osf.io/8sy9z
# defaultdict(<class 'int'>, {'2018-12-13': 1, '2018-12-11': 1})
# osf.io/cnxzh
# osf.io/vqa7t
# defaultdict(<class 'int'>, {'2018-12-13': 1, '2018-12-09': 1})
# osf.io/p6n23
# osf.io/5hjr2
# defaultdict(<class 'int'>, {'2018-12-13': 1, '2018-11-19': 2})
# osf.io/4hb2f
# osf.io/tjrsy
# osf.io/w8seq
# defaultdict(<class 'int'>, {'2018-12-13': 1, '2018-12-11': 1})
# osf.io/qbu7w
# osf.io/v8gnj
# defaultdict(<class 'int'>, {'2018-12-13': 1, '2018-12-12': 1})
# osf.io/46rkt
# osf.io/ugz2h
# defaultdict(<class 'int'>, {'2018-12-13': 1, '2018-12-11': 1})
# osf.io/3zvsf
# osf.io/rb5y2
# defaultdict(<class 'int'>, {'2018-12-13': 1, '2018-11-21': 1})
# osf.io/svmxf
# osf.io/gn8v2
# defaultdict(<class 'int'>, {'2018-12-13': 1, '2018-12-12': 1})
# osf.io/c7xrs
# osf.io/3c7mf
# defaultdict(<class 'int'>, {'2018-12-13': 1, '2018-12-12': 1})
# osf.io/zydwq
# osf.io/q5jhn
# defaultdict(<class 'int'>, {'2018-12-13': 2, '2018-12-12': 2})
# osf.io/dmsu3
# osf.io/5zdqg
# osf.io/2f985
# osf.io/fwm73
# defaultdict(<class 'int'>, {'2018-12-13': 1, '2018-12-12': 3})
# osf.io/nra6d
# osf.io/qbfm2
# osf.io/mhv2x
# osf.io/w3fha
# defaultdict(<class 'int'>, {'2018-12-13': 3, '2018-12-12': 5})
# osf.io/nz4yj
# osf.io/39une
# osf.io/bw7s4
# osf.io/j8yhv
# osf.io/95g8d
# osf.io/8jfa9
# osf.io/z239k
# osf.io/dbjze
# defaultdict(<class 'int'>, {'2018-12-11': 1, '2018-11-22': 2, '2018-11-17': 1})
# osf.io/b5g9z
# osf.io/bc365
# osf.io/kdq9v
# osf.io/nmfsc
# defaultdict(<class 'int'>, {'2018-12-11': 1, '2018-12-07': 1})
# osf.io/rwg4b
# osf.io/cfj79
# defaultdict(<class 'int'>, {'2018-12-11': 1, '2018-12-02': 1, '2018-11-30': 1})
# osf.io/39sqp
# osf.io/4jh6k
# osf.io/d9nqz
# defaultdict(<class 'int'>, {'2018-12-11': 2, '2018-12-06': 1})
# osf.io/n4856
# osf.io/dhxwv
# osf.io/4dapf
# defaultdict(<class 'int'>, {'2018-12-10': 1, '2018-12-06': 1})
# osf.io/2b63t
# osf.io/8e4hj
# defaultdict(<class 'int'>, {'2018-12-10': 1, '2018-12-06': 1})
# osf.io/45jc6
# osf.io/5jnfa
# defaultdict(<class 'int'>, {'2018-12-10': 1, '2018-12-02': 1})
# osf.io/6phuf
# osf.io/hd56q
# defaultdict(<class 'int'>, {'2018-12-10': 1, '2018-12-09': 4})
# osf.io/v58t6
# osf.io/jyq29
# osf.io/5j4e9
# osf.io/feugk
# osf.io/8ecd5
# defaultdict(<class 'int'>, {'2018-12-08': 1, '2018-12-01': 1})
# osf.io/28vke
# osf.io/fxvaz
# defaultdict(<class 'int'>, {'2018-12-08': 1, '2018-12-01': 1})
# osf.io/cdsv7
# osf.io/drtm3
# defaultdict(<class 'int'>, {'2018-12-07': 2, '2018-12-04': 1})
# osf.io/zyswp
# osf.io/rgkw5
# osf.io/b7kmx
# defaultdict(<class 'int'>, {'2018-12-06': 1, '2018-12-01': 1})
# osf.io/u54z2
# osf.io/qxt4d
# defaultdict(<class 'int'>, {'2018-12-06': 1, '2018-12-02': 1})
# osf.io/jfr9c
# osf.io/7hme5
# defaultdict(<class 'int'>, {'2018-12-06': 1, '2018-12-01': 1})
# osf.io/54pkj
# osf.io/7r6j4
# defaultdict(<class 'int'>, {'2018-12-06': 1, '2018-11-30': 1})
# osf.io/dmr7q
# osf.io/f5cej
# defaultdict(<class 'int'>, {'2018-12-06': 1, '2018-11-29': 1})
# osf.io/a39xc
# osf.io/jxyk9
# defaultdict(<class 'int'>, {'2018-12-05': 1, '2018-11-27': 1})
# osf.io/475vc
# osf.io/bmu4s
# defaultdict(<class 'int'>, {'2018-12-05': 1, '2018-12-01': 1})
# osf.io/ab5vx
# osf.io/9krgv
# defaultdict(<class 'int'>, {'2018-12-05': 1, '2018-11-24': 1, '2018-11-22': 1})
# osf.io/jg39z
# osf.io/6zvrd
# osf.io/zwgyx
# defaultdict(<class 'int'>, {'2018-12-05': 1, '2018-11-22': 1})
# osf.io/9zpbg
# osf.io/2k5d3
# defaultdict(<class 'int'>, {'2018-12-05': 1, '2018-11-24': 1})
# osf.io/zbe4p
# osf.io/mfx7w
# defaultdict(<class 'int'>, {'2018-12-05': 1, '2018-11-24': 1, '2018-11-22': 1})
# osf.io/tdbnc
# osf.io/c2gkq
# osf.io/f2r65
# defaultdict(<class 'int'>, {'2018-12-05': 1, '2018-11-24': 1})
# osf.io/7f5u8
# osf.io/rgcqf
# defaultdict(<class 'int'>, {'2018-12-04': 1, '2018-11-22': 1})
# osf.io/cfhw3
# osf.io/k2puy
# defaultdict(<class 'int'>, {'2018-11-27': 1, '2018-11-24': 1})
# osf.io/h3a6v
# osf.io/p8db4
# defaultdict(<class 'int'>, {'2018-11-26': 1, '2018-11-24': 1})
# osf.io/zhaf6
# osf.io/69n7v
# defaultdict(<class 'int'>, {'2018-11-26': 1, '2018-11-25': 1})
# osf.io/ndze7
# osf.io/rkdqb
# defaultdict(<class 'int'>, {'2018-11-26': 1, '2018-11-24': 1})
# osf.io/cez7u
# osf.io/jbx46
# defaultdict(<class 'int'>, {'2018-11-24': 1, '2018-11-23': 1})
# osf.io/bkfqs
# osf.io/46qvr
# defaultdict(<class 'int'>, {'2018-11-23': 1, '2018-11-22': 1})
# osf.io/mvjw8
# osf.io/mezfs
# defaultdict(<class 'int'>, {'2018-11-23': 1, '2018-11-17': 1})
# osf.io/wfubr
# osf.io/rbdc5
# defaultdict(<class 'int'>, {'2018-11-22': 1, '2018-11-17': 1})
# osf.io/6sgvc
# osf.io/dkb3r
# defaultdict(<class 'int'>, {'2018-11-22': 1, '2018-11-19': 1})
# osf.io/mvnq8
# osf.io/shvnu
# defaultdict(<class 'int'>, {'2018-11-21': 1, '2018-11-20': 1})
# osf.io/kdpu6
# osf.io/vkjgh
# defaultdict(<class 'int'>, {'2018-11-21': 1, '2018-10-22': 1})
# osf.io/378bk
# osf.io/k4q3g
# defaultdict(<class 'int'>, {'2018-11-20': 1, '2017-02-14': 1})
# osf.io/duaeb
# osf.io/w6dn5
# defaultdict(<class 'int'>, {'2018-11-19': 1, '2018-10-22': 1})
# osf.io/7utxs
# osf.io/qk9ph
# defaultdict(<class 'int'>, {'2018-11-18': 1, '2018-11-16': 1})
# osf.io/6bncu
# osf.io/xqyf7
# defaultdict(<class 'int'>, {'2018-11-14': 1, '2018-11-06': 1})
# osf.io/bs8qd
# osf.io/cq56k
# defaultdict(<class 'int'>, {'2018-11-14': 1, '2018-10-24': 1})
# osf.io/bt5gd
# osf.io/g629q
# defaultdict(<class 'int'>, {'2018-11-12': 1, '2018-05-11': 1})
# osf.io/c6phw
# osf.io/pqz46
# defaultdict(<class 'int'>, {'2018-11-12': 1, '2018-10-20': 1})
# osf.io/nzfc9
# osf.io/asv3b
# defaultdict(<class 'int'>, {'2018-11-12': 1, '2018-10-21': 1})
# osf.io/7kr82
# osf.io/uac2k
# defaultdict(<class 'int'>, {'2018-11-10': 1, '2018-11-11': 1, '2017-12-11': 1})
# osf.io/4ck8r
# osf.io/btxz9
# osf.io/ga8wx
# defaultdict(<class 'int'>, {'2018-11-05': 1, '2017-01-20': 1})
# osf.io/fwt59
# osf.io/zbpqe
# defaultdict(<class 'int'>, {'2018-11-03': 1, '2018-10-19': 1})
# osf.io/j2tnv
# osf.io/6vgxz
# defaultdict(<class 'int'>, {'2018-11-02': 1, '2018-08-17': 1})
# osf.io/uk3vp
# osf.io/3y6sm
# defaultdict(<class 'int'>, {'2018-10-19': 1, '2018-09-21': 1})
# osf.io/ayjq9
# osf.io/9b587
# defaultdict(<class 'int'>, {'2018-10-19': 1, '2018-09-21': 1})
# osf.io/ny5gu
# osf.io/jym6a
# defaultdict(<class 'int'>, {'2018-10-19': 1, '2018-09-21': 1})
# osf.io/upt8j
# osf.io/t3cvw
# defaultdict(<class 'int'>, {'2018-10-18': 1, '2018-10-12': 1})
# osf.io/q57ye
# osf.io/fujrb
# defaultdict(<class 'int'>, {'2018-10-13': 1, '2018-01-25': 1})
# osf.io/kawyz
# osf.io/cbms8
# defaultdict(<class 'int'>, {'2018-10-10': 1, '2018-10-08': 1})
# osf.io/rjuqx
# osf.io/4swau
# defaultdict(<class 'int'>, {'2018-10-10': 1, '2018-02-10': 1})
# osf.io/d4na6
# osf.io/kb3u2
# defaultdict(<class 'int'>, {'2018-10-05': 1, '2018-08-23': 1})
# osf.io/kun3r
# osf.io/z4vk2
# defaultdict(<class 'int'>, {'2018-09-30': 1, '2018-07-30': 1})
# osf.io/3df6j
# osf.io/yrxpd
# defaultdict(<class 'int'>, {'2018-09-26': 1, '2018-07-09': 1})
# osf.io/uy7sw
# osf.io/geapz
# defaultdict(<class 'int'>, {'2018-09-26': 1, '2018-09-21': 1})
# osf.io/qrmks
# osf.io/gdxmq
# defaultdict(<class 'int'>, {'2018-09-26': 1, '2018-09-21': 1})
# osf.io/kqamh
# osf.io/zeq9x
# defaultdict(<class 'int'>, {'2018-09-21': 1, '2018-04-16': 1})
# osf.io/3ub4t
# osf.io/9bdyh
# defaultdict(<class 'int'>, {'2018-09-18': 1, '2018-05-15': 1})
# osf.io/jb3um
# osf.io/hwn8a
# defaultdict(<class 'int'>, {'2018-09-18': 1, '2018-05-15': 1})
# osf.io/g7hpy
# osf.io/jc6f5
# defaultdict(<class 'int'>, {'2018-09-18': 1, '2018-04-14': 1})
# osf.io/nfrmx
# osf.io/7qkj6
# defaultdict(<class 'int'>, {'2018-09-17': 1, '2018-09-03': 1})
# osf.io/tmyka
# osf.io/v4yj2
# defaultdict(<class 'int'>, {'2018-09-06': 1, '2018-09-03': 1, '2018-09-01': 1})
# osf.io/8bvw2
# osf.io/7m9uk
# osf.io/sfjqc
# defaultdict(<class 'int'>, {'2018-09-04': 1, '2018-08-26': 1})
# osf.io/r5jgx
# osf.io/4huqp
# defaultdict(<class 'int'>, {'2018-08-29': 1, '2018-06-30': 1})
# osf.io/3km9s
# osf.io/29qp6
# defaultdict(<class 'int'>, {'2018-08-29': 1, '2018-06-30': 1})
# osf.io/qh5jx
# osf.io/djv8y
# defaultdict(<class 'int'>, {'2018-08-29': 2, '2018-06-30': 1})
# osf.io/ubtms
# osf.io/bct8p
# osf.io/349ja
# defaultdict(<class 'int'>, {'2018-08-22': 1, '2017-01-22': 1})
# osf.io/bsfqz
# osf.io/xaqn6
# defaultdict(<class 'int'>, {'2018-08-20': 1, '2018-03-26': 1, '2017-12-07': 1})
# osf.io/86bd2
# osf.io/j94p3
# osf.io/hyf8c
# defaultdict(<class 'int'>, {'2018-08-07': 1, '2017-06-03': 1})
# osf.io/vz7qf
# osf.io/849am
# defaultdict(<class 'int'>, {'2018-08-05': 1, '2018-08-04': 1})
# osf.io/968fm
# osf.io/hf2a9
# defaultdict(<class 'int'>, {'2018-07-30': 1, '2018-05-06': 1})
# osf.io/7z46h
# osf.io/9wjhq
# defaultdict(<class 'int'>, {'2018-07-24': 1, '2018-05-25': 1})
# osf.io/4c7vx
# osf.io/vz2h8
# defaultdict(<class 'int'>, {'2018-07-22': 1, '2018-07-09': 1})
# osf.io/7nz6m
# osf.io/xg4wa
# defaultdict(<class 'int'>, {'2018-07-21': 4, '2018-07-20': 1})
# osf.io/zjdkg
# osf.io/mtv2e
# osf.io/42qrx
# osf.io/v6szg
# osf.io/7mdtc
# defaultdict(<class 'int'>, {'2018-07-21': 2, '2018-07-20': 1, '2018-07-19': 1})
# osf.io/xupr9
# osf.io/gyjuh
# osf.io/mv7cu
# osf.io/jkyb6
# defaultdict(<class 'int'>, {'2018-07-18': 1, '2018-06-22': 1})
# osf.io/wxvrn
# osf.io/kq4vu
# defaultdict(<class 'int'>, {'2018-07-18': 1, '2018-07-12': 1})
# osf.io/dujhv
# osf.io/42u8n
# defaultdict(<class 'int'>, {'2018-07-17': 1, '2018-07-13': 1})
# osf.io/tm8c5
# osf.io/ayu89
# defaultdict(<class 'int'>, {'2018-07-13': 1, '2018-07-11': 1})
# osf.io/zg6wr
# osf.io/mvdqr
# defaultdict(<class 'int'>, {'2018-07-10': 1, '2017-11-25': 1})
# osf.io/6aer7
# osf.io/5phnq
# defaultdict(<class 'int'>, {'2018-07-09': 1, '2018-07-10': 1})
# osf.io/gavq5
# osf.io/w5huy
# defaultdict(<class 'int'>, {'2018-07-13': 1, '2018-05-08': 1})
# osf.io/nf86q
# osf.io/rta5p
# defaultdict(<class 'int'>, {'2018-07-06': 1, '2018-03-29': 1})
# osf.io/2rvpt
# osf.io/ycjkv
# defaultdict(<class 'int'>, {'2018-07-06': 1, '2018-02-27': 1})
# osf.io/kjzgh
# osf.io/eqzbu
# defaultdict(<class 'int'>, {'2018-07-06': 1, '2018-01-30': 1})
# osf.io/8kf3x
# osf.io/879z2
# defaultdict(<class 'int'>, {'2018-07-06': 1, '2018-02-22': 1})
# osf.io/tw7gm
# osf.io/gs9kp
# defaultdict(<class 'int'>, {'2018-07-06': 1, '2018-02-03': 1})
# osf.io/689my
# osf.io/cxbdw
# defaultdict(<class 'int'>, {'2018-07-06': 1, '2018-01-30': 1})
# osf.io/yvjub
# osf.io/ry3vj
# defaultdict(<class 'int'>, {'2018-07-06': 1, '2018-02-20': 1})
# osf.io/ywsz5
# osf.io/xptj2
# defaultdict(<class 'int'>, {'2018-07-06': 1, '2018-02-02': 1})
# osf.io/gms59
# osf.io/7wcg5
# defaultdict(<class 'int'>, {'2018-07-05': 1, '2018-07-04': 1})
# osf.io/nqf79
# osf.io/ekdrj
# defaultdict(<class 'int'>, {'2018-07-05': 1, '2018-07-04': 1})
# osf.io/nvz3p
# osf.io/d96hk
# defaultdict(<class 'int'>, {'2018-07-05': 1, '2018-07-04': 1})
# osf.io/gtp9w
# osf.io/8brdy
# defaultdict(<class 'int'>, {'2018-07-05': 1, '2018-07-04': 1})
# osf.io/jw2sq
# osf.io/mknv4
# defaultdict(<class 'int'>, {'2018-07-05': 1, '2018-07-04': 1})
# osf.io/xea38
# osf.io/wm9e2
# defaultdict(<class 'int'>, {'2018-07-05': 1, '2018-07-04': 1})
# osf.io/vx73z
# osf.io/qa23j
# defaultdict(<class 'int'>, {'2018-07-05': 1, '2018-07-04': 1})
# osf.io/6qyhd
# osf.io/v9dtz
# defaultdict(<class 'int'>, {'2018-07-05': 1, '2018-07-04': 1})
# osf.io/7dmvk
# osf.io/4c75a
# defaultdict(<class 'int'>, {'2018-07-05': 1, '2018-07-04': 1})
# osf.io/dpk5t
# osf.io/9d2r3
# defaultdict(<class 'int'>, {'2018-07-05': 1, '2018-07-04': 1})
# osf.io/2354e
# osf.io/23tuz
# defaultdict(<class 'int'>, {'2018-07-05': 1, '2018-07-04': 1})
# osf.io/vjepm
# osf.io/r27vb
# defaultdict(<class 'int'>, {'2018-07-05': 1, '2018-07-04': 1})
# osf.io/3e5sv
# osf.io/45k6m
# defaultdict(<class 'int'>, {'2018-07-05': 1, '2018-07-04': 1})
# osf.io/8cdpb
# osf.io/mt56e
# defaultdict(<class 'int'>, {'2018-07-03': 1, '2018-01-12': 1})
# osf.io/qwpbz
# osf.io/6bvaz
# defaultdict(<class 'int'>, {'2018-07-03': 1, '2018-01-12': 1})
# osf.io/rhwcx
# osf.io/zcv4b
# defaultdict(<class 'int'>, {'2018-07-03': 1, '2018-01-12': 1})
# osf.io/mxthp
# osf.io/vfq95
# defaultdict(<class 'int'>, {'2018-07-03': 1, '2018-01-12': 1})
# osf.io/gtr5n
# osf.io/2g7w4
# defaultdict(<class 'int'>, {'2018-07-03': 1, '2018-01-12': 1})
# osf.io/j4ybh
# osf.io/fc8jb
# defaultdict(<class 'int'>, {'2018-07-03': 1, '2018-01-12': 1})
# osf.io/8dnwp
# osf.io/xrm6a
# defaultdict(<class 'int'>, {'2018-07-03': 1, '2018-01-12': 1})
# osf.io/3bvuf
# osf.io/53s69
# defaultdict(<class 'int'>, {'2018-07-03': 1, '2018-01-12': 1})
# osf.io/25tse
# osf.io/jw5yh
# defaultdict(<class 'int'>, {'2018-07-03': 1, '2018-01-12': 1})
# osf.io/r874n
# osf.io/42fze
# defaultdict(<class 'int'>, {'2018-07-03': 1, '2018-01-12': 1})
# osf.io/ksfzw
# osf.io/n7mks
# defaultdict(<class 'int'>, {'2018-07-02': 1, '2018-01-12': 1})
# osf.io/k32d9
# osf.io/fv7e4
# defaultdict(<class 'int'>, {'2018-07-02': 1, '2018-01-12': 1})
# osf.io/kvst9
# osf.io/fyxmg
# defaultdict(<class 'int'>, {'2018-07-02': 1, '2018-01-12': 1})
# osf.io/h8axv
# osf.io/5q9mb
# defaultdict(<class 'int'>, {'2018-07-02': 1, '2018-01-12': 1})
# osf.io/d2ftr
# osf.io/u2cgd
# defaultdict(<class 'int'>, {'2018-07-02': 1, '2018-01-12': 1})
# osf.io/vmu6q
# osf.io/ap4x8
# defaultdict(<class 'int'>, {'2018-07-02': 1, '2018-01-12': 1})
# osf.io/6rmuw
# osf.io/huv9a
# defaultdict(<class 'int'>, {'2018-07-02': 1, '2018-01-12': 1})
# osf.io/h2xmk
# osf.io/vzkcs
# defaultdict(<class 'int'>, {'2018-07-02': 1, '2018-01-12': 1})
# osf.io/7y5tu
# osf.io/at4hr
# defaultdict(<class 'int'>, {'2018-07-02': 1, '2018-01-12': 1})
# osf.io/u53dr
# osf.io/adk2s
# defaultdict(<class 'int'>, {'2018-06-29': 1, '2016-12-08': 1})
# osf.io/n7y4g
# osf.io/vrf9r
# defaultdict(<class 'int'>, {'2018-06-27': 1, '2018-06-25': 1})
# osf.io/mwu4c
# osf.io/ex672
# defaultdict(<class 'int'>, {'2018-06-19': 1, '2018-04-11': 1})
# osf.io/4m82t
# osf.io/m8hbq
# defaultdict(<class 'int'>, {'2018-06-19': 1, '2018-05-20': 1})
# osf.io/9bmxp
# osf.io/u8ckn
# defaultdict(<class 'int'>, {'2018-06-16': 1, '2018-06-09': 1})
# osf.io/sjmd2
# osf.io/ez473
# defaultdict(<class 'int'>, {'2018-06-07': 1, '2018-06-03': 1})
# osf.io/pxmkq
# osf.io/4v7zu
# defaultdict(<class 'int'>, {'2018-05-31': 1, '2018-05-07': 1})
# osf.io/yvums
# osf.io/zv8xb
# defaultdict(<class 'int'>, {'2018-05-31': 1, '2018-05-21': 1})
# osf.io/8bkqd
# osf.io/39ywm
# defaultdict(<class 'int'>, {'2018-05-24': 1, '2018-05-23': 1})
# osf.io/vq2wy
# osf.io/mv9da
# defaultdict(<class 'int'>, {'2018-05-22': 1, '2018-05-23': 1, '2018-05-21': 3})
# osf.io/kzytg
# osf.io/mwvrx
# osf.io/45p7f
# osf.io/6dky2
# osf.io/djucg
# defaultdict(<class 'int'>, {'2018-05-18': 1, '2018-01-18': 1})
# osf.io/p6ygr
# osf.io/py9ru
# defaultdict(<class 'int'>, {'2018-05-17': 1, '2018-05-15': 1})
# osf.io/4v7dh
# osf.io/v7jp5
# defaultdict(<class 'int'>, {'2018-05-16': 2, '2018-05-01': 1})
# osf.io/czu2w
# osf.io/wxarn
# osf.io/2sv3t
# defaultdict(<class 'int'>, {'2018-05-16': 1, '2018-05-15': 1})
# osf.io/ngk5v
# osf.io/wm9gs
# defaultdict(<class 'int'>, {'2018-05-15': 1, '2018-05-09': 1})
# osf.io/y3fvz
# osf.io/jthpf
# defaultdict(<class 'int'>, {'2018-05-04': 1, '2017-06-09': 1})
# osf.io/2tgm7
# osf.io/hz93j
# defaultdict(<class 'int'>, {'2018-05-03': 1, '2017-12-31': 1})
# osf.io/3ue5f
# osf.io/qmpc4
# defaultdict(<class 'int'>, {'2018-04-30': 1, '2018-03-29': 1})
# osf.io/p4ez6
# osf.io/2jtcd
# defaultdict(<class 'int'>, {'2018-04-30': 1, '2017-12-15': 1})
# osf.io/7rf9a
# osf.io/zudce
# defaultdict(<class 'int'>, {'2018-04-24': 1, '2018-04-23': 1})
# osf.io/8hxr6
# osf.io/wbrcg
# defaultdict(<class 'int'>, {'2018-04-16': 1, '2018-04-10': 2})
# osf.io/vhkt8
# osf.io/tsvxz
# osf.io/v9nzx
# defaultdict(<class 'int'>, {'2018-04-15': 1, '2017-12-21': 1})
# osf.io/sej8t
# osf.io/7kmj4
# defaultdict(<class 'int'>, {'2018-04-13': 1, '2018-04-10': 1})
# osf.io/h2gv6
# osf.io/7h563
# defaultdict(<class 'int'>, {'2018-04-11': 1, '2018-01-24': 1})
# osf.io/d7m4t
# osf.io/xz8p3
# defaultdict(<class 'int'>, {'2018-04-09': 1, '2017-09-26': 1})
# osf.io/ta3v4
# osf.io/m3xcq
# defaultdict(<class 'int'>, {'2018-04-08': 1, '2018-04-03': 1})
# osf.io/4ejmw
# osf.io/n6cx4
# defaultdict(<class 'int'>, {'2018-04-04': 1, '2018-03-27': 1})
# osf.io/ngek2
# osf.io/p74dw
# defaultdict(<class 'int'>, {'2018-04-01': 1, '2018-03-22': 1, '2017-12-16': 1})
# osf.io/wsvek
# osf.io/jnymd
# osf.io/w5skr
# defaultdict(<class 'int'>, {'2018-03-29': 1, '2017-12-08': 1})
# osf.io/sxdyt
# osf.io/phtrn
# defaultdict(<class 'int'>, {'2018-03-24': 1, '2018-03-23': 1})
# osf.io/e2khd
# osf.io/pukqm
# defaultdict(<class 'int'>, {'2018-03-21': 1, '2017-12-11': 1})
# osf.io/p75gw
# osf.io/kg5vx
# defaultdict(<class 'int'>, {'2018-03-15': 1, '2017-12-13': 1})
# osf.io/p7e9j
# osf.io/sfq25
# defaultdict(<class 'int'>, {'2018-03-09': 1, '2017-12-22': 1})
# osf.io/d7xht
# osf.io/yhwbf
# defaultdict(<class 'int'>, {'2018-03-05': 1, '2017-12-08': 1})
# osf.io/c8wv6
# osf.io/ypk4z
# defaultdict(<class 'int'>, {'2018-02-26': 1, '2018-01-03': 1})
# osf.io/x5dhc
# osf.io/sej4z
# defaultdict(<class 'int'>, {'2018-02-26': 1, '2018-02-01': 1})
# osf.io/3mah9
# osf.io/4ahve
# defaultdict(<class 'int'>, {'2018-02-26': 1, '2017-12-22': 1})
# osf.io/ntq48
# osf.io/5g6tw
# defaultdict(<class 'int'>, {'2018-02-26': 1, '2017-12-15': 1})
# osf.io/s3ep8
# osf.io/5jw9q
# defaultdict(<class 'int'>, {'2018-02-15': 1, '2018-01-02': 1})
# osf.io/vyfqh
# osf.io/8j3ym
# defaultdict(<class 'int'>, {'2018-02-06': 1, '2018-01-19': 1})
# osf.io/78yjh
# osf.io/anmfs
# defaultdict(<class 'int'>, {'2018-02-04': 1, '2018-01-31': 1, '2017-12-12': 1})
# osf.io/bzt32
# osf.io/ym7as
# osf.io/czsae
# defaultdict(<class 'int'>, {'2018-02-01': 1, '2018-01-13': 1})
# osf.io/7mzah
# osf.io/wy7gj
# defaultdict(<class 'int'>, {'2018-01-29': 3, '2018-01-24': 1})
# osf.io/23j8e
# osf.io/u5msj
# osf.io/v79xh
# osf.io/stah3
# defaultdict(<class 'int'>, {'2018-01-25': 1, '2018-01-19': 1, '2018-01-13': 1})
# osf.io/tecfd
# osf.io/qbx8m
# osf.io/3qryu
# defaultdict(<class 'int'>, {'2018-01-21': 1, '2018-01-19': 2})
# osf.io/84xg2
# osf.io/5pnc2
# osf.io/uw6ck
# defaultdict(<class 'int'>, {'2018-01-19': 3, '2018-01-13': 1})
# osf.io/3s9vd
# osf.io/qnsje
# osf.io/gvp87
# osf.io/jacfh
# defaultdict(<class 'int'>, {'2018-01-19': 2, '2018-01-13': 1})
# osf.io/g7evz
# osf.io/nft57
# osf.io/m524p
# defaultdict(<class 'int'>, {'2018-01-18': 1, '2018-01-13': 1})
# osf.io/qgtz8
# osf.io/ghkd4
# defaultdict(<class 'int'>, {'2018-01-16': 1, '2017-12-25': 1})
# osf.io/jrhg8
# osf.io/ztvkx
# defaultdict(<class 'int'>, {'2018-01-15': 1, '2018-01-12': 1})
# osf.io/z5g6f
# osf.io/bfupk
# defaultdict(<class 'int'>, {'2018-01-10': 1, '2017-11-07': 1})
# osf.io/9cv5h
# osf.io/3jbzc
# defaultdict(<class 'int'>, {'2018-01-10': 1, '2017-11-06': 1})
# osf.io/3n6fj
# osf.io/e6h2w
# defaultdict(<class 'int'>, {'2018-01-05': 1, '2017-12-21': 1, '2017-12-15': 1})
# osf.io/4wnd9
# osf.io/tbh6c
# osf.io/d2ub6
# defaultdict(<class 'int'>, {'2018-01-03': 1, '2017-12-18': 1})
# osf.io/rjdbw
# osf.io/t54nr
# defaultdict(<class 'int'>, {'2018-01-03': 1, '2017-12-18': 1})
# osf.io/qv93k
# osf.io/2kjs3
# defaultdict(<class 'int'>, {'2018-01-02': 1, '2017-09-11': 1})
# osf.io/usqav
# osf.io/snq53
# defaultdict(<class 'int'>, {'2017-12-28': 1, '2017-11-23': 1})
# osf.io/dg9aq
# osf.io/rp8c5
# defaultdict(<class 'int'>, {'2017-12-28': 1, '2017-11-24': 1})
# osf.io/vfnwy
# osf.io/83ghm
# defaultdict(<class 'int'>, {'2017-12-26': 1, '2017-10-07': 1})
# osf.io/3tvmg
# osf.io/b72em
# defaultdict(<class 'int'>, {'2017-12-22': 1, '2017-12-16': 1})
# osf.io/jcgde
# osf.io/mqzv5
# defaultdict(<class 'int'>, {'2017-12-22': 1, '2017-12-09': 1})
# osf.io/vxu6y
# osf.io/gnk7r
# defaultdict(<class 'int'>, {'2017-12-22': 1, '2017-12-06': 1})
# osf.io/txpsd
# osf.io/f6h8u
# defaultdict(<class 'int'>, {'2017-12-21': 1, '2017-12-11': 1, '2017-12-10': 1})
# osf.io/dv7x3
# osf.io/c6fx3
# osf.io/qh38k
# defaultdict(<class 'int'>, {'2017-12-17': 1, '2017-11-10': 1})
# osf.io/hwkxe
# osf.io/fbjv4
# defaultdict(<class 'int'>, {'2017-12-16': 1, '2017-12-09': 1})
# osf.io/9j86p
# osf.io/e7ujp
# defaultdict(<class 'int'>, {'2017-12-09': 2, '2017-12-08': 1})
# osf.io/evfpx
# osf.io/uwv29
# osf.io/6xqdn
# defaultdict(<class 'int'>, {'2017-12-09': 1, '2017-12-08': 1})
# osf.io/58gts
# osf.io/v35fu
# defaultdict(<class 'int'>, {'2017-12-09': 2, '2017-12-08': 1})
# osf.io/cp5ud
# osf.io/qhks4
# osf.io/7cuzn
# defaultdict(<class 'int'>, {'2017-12-07': 1, '2017-05-01': 1})
# osf.io/heamz
# osf.io/9z8ch
# defaultdict(<class 'int'>, {'2017-12-03': 1, '2017-09-01': 1})
# osf.io/n3a7s
# osf.io/ubx9g
# defaultdict(<class 'int'>, {'2017-12-01': 1, '2017-11-25': 1})
# osf.io/sfnzw
# osf.io/649xz
# defaultdict(<class 'int'>, {'2017-12-01': 1, '2017-10-31': 1})
# osf.io/5xvew
# osf.io/f3e6z
# defaultdict(<class 'int'>, {'2017-11-27': 1, '2017-10-06': 1})
# osf.io/86rjt
# osf.io/qb2p5
# defaultdict(<class 'int'>, {'2017-11-25': 1, '2017-11-24': 1})
# osf.io/aqnrj
# osf.io/253ck
# defaultdict(<class 'int'>, {'2017-11-23': 1, '2017-11-21': 1})
# osf.io/7jpy3
# osf.io/25yez
# defaultdict(<class 'int'>, {'2017-11-21': 1, '2017-11-16': 1})
# osf.io/ds4z6
# osf.io/w9cx8
# defaultdict(<class 'int'>, {'2017-11-09': 1, '2017-11-06': 1})
# osf.io/fzgjp
# osf.io/2pfe7
# defaultdict(<class 'int'>, {'2017-11-08': 1, '2017-11-01': 1})
# osf.io/jhpku
# osf.io/4twg6
# defaultdict(<class 'int'>, {'2017-11-08': 1, '2017-11-07': 1})
# osf.io/k3gx8
# osf.io/z2q8p
# defaultdict(<class 'int'>, {'2017-11-01': 1, '2017-09-19': 1})
# osf.io/e5pvf
# osf.io/z8xnv
# defaultdict(<class 'int'>, {'2017-10-25': 1, '2017-10-20': 1})
# osf.io/jn7sp
# osf.io/nh4rc
# defaultdict(<class 'int'>, {'2017-10-19': 1, '2017-10-07': 1})
# osf.io/26h4x
# osf.io/r32a5
# defaultdict(<class 'int'>, {'2017-10-19': 1, '2017-10-03': 1})
# osf.io/2v8dy
# osf.io/jg7nr
# defaultdict(<class 'int'>, {'2017-10-19': 1, '2017-10-09': 1})
# osf.io/4h2a9
# osf.io/ysvup
# defaultdict(<class 'int'>, {'2017-10-11': 1, '2017-04-19': 1})
# osf.io/d2e7u
# osf.io/nd38q
# defaultdict(<class 'int'>, {'2017-09-25': 1, '2017-08-29': 1})
# osf.io/tkzcj
# osf.io/5ah3w
# defaultdict(<class 'int'>, {'2017-09-22': 1, '2017-09-20': 1})
# osf.io/ze6v5
# osf.io/f5kys
# defaultdict(<class 'int'>, {'2017-09-21': 1, '2017-09-20': 1})
# osf.io/trfkh
# osf.io/yxjnp
# defaultdict(<class 'int'>, {'2017-09-08': 1, '2017-08-20': 1})
# osf.io/8snwq
# osf.io/rtdwa
# defaultdict(<class 'int'>, {'2017-09-07': 1, '2017-09-05': 1})
# osf.io/dg692
# osf.io/gyd6q
# defaultdict(<class 'int'>, {'2017-09-03': 1, '2017-01-29': 1})
# osf.io/pfxtd
# osf.io/es9d7
# defaultdict(<class 'int'>, {'2017-09-01': 1, '2017-08-29': 1})
# osf.io/p46jg
# osf.io/9swvu
# defaultdict(<class 'int'>, {'2017-09-01': 1, '2017-08-29': 1})
# osf.io/cfzpd
# osf.io/7b5n6
# defaultdict(<class 'int'>, {'2017-09-01': 1, '2017-08-29': 1})
# osf.io/wjzv4
# osf.io/257zs
# defaultdict(<class 'int'>, {'2017-09-01': 1, '2017-08-29': 1})
# osf.io/tke2p
# osf.io/w7s9d
# defaultdict(<class 'int'>, {'2017-09-01': 1, '2017-08-29': 1})
# osf.io/7hez3
# osf.io/zcv5t
# defaultdict(<class 'int'>, {'2017-08-31': 1, '2017-08-29': 2})
# osf.io/q3gu7
# osf.io/ua348
# osf.io/2se9x
# defaultdict(<class 'int'>, {'2017-08-31': 1, '2017-08-29': 1})
# osf.io/3r6kn
# osf.io/zadn9
# defaultdict(<class 'int'>, {'2017-08-31': 1, '2017-08-29': 1})
# osf.io/fq569
# osf.io/j4ny2
# defaultdict(<class 'int'>, {'2017-08-31': 1, '2017-08-29': 1})
# osf.io/zhnqs
# osf.io/4stvk
# defaultdict(<class 'int'>, {'2017-08-31': 1, '2017-08-24': 1})
# osf.io/xm49s
# osf.io/a6h82
# defaultdict(<class 'int'>, {'2017-08-29': 1, '2017-08-22': 1})
# osf.io/g7xy8
# osf.io/mg97s
# defaultdict(<class 'int'>, {'2017-08-29': 1, '2017-08-24': 1})
# osf.io/a9pr8
# osf.io/px7rd
# defaultdict(<class 'int'>, {'2017-08-20': 1, '2017-05-07': 1})
# osf.io/3pd6t
# osf.io/kqh23
# defaultdict(<class 'int'>, {'2017-08-16': 1, '2017-07-08': 1})
# osf.io/kj6ce
# osf.io/cfr72
# defaultdict(<class 'int'>, {'2017-08-11': 1, '2016-08-30': 1})
# osf.io/j8gbn
# osf.io/nuwdt
# defaultdict(<class 'int'>, {'2017-08-10': 1, '2017-08-08': 1})
# osf.io/gqvae
# osf.io/q27j4
# defaultdict(<class 'int'>, {'2017-08-09': 1, '2016-12-08': 1})
# osf.io/dqagb
# osf.io/qhzqe
# defaultdict(<class 'int'>, {'2017-08-09': 1, '2016-12-08': 1})
# osf.io/ydtzx
# osf.io/uek7f
# defaultdict(<class 'int'>, {'2017-08-05': 1, '2017-03-19': 1})
# osf.io/xqs8n
# osf.io/sghjy
# defaultdict(<class 'int'>, {'2017-07-01': 1, '2017-03-02': 1})
# osf.io/j837v
# osf.io/zzwq2
# defaultdict(<class 'int'>, {'2017-05-25': 1, '2017-05-04': 1})
# osf.io/8prh2
# osf.io/6x2k4
# defaultdict(<class 'int'>, {'2017-05-13': 1, '2017-05-10': 1})
# osf.io/36ngk
# osf.io/df9q4
# defaultdict(<class 'int'>, {'2017-05-10': 1, '2017-05-08': 1})
# osf.io/pcq6a
# osf.io/4arn6
# defaultdict(<class 'int'>, {'2017-05-04': 1, '2016-12-08': 1, '2016-10-27': 1})
# osf.io/53rke
# osf.io/dnns8
# osf.io/mc9r5
# defaultdict(<class 'int'>, {'2017-04-26': 1, '2017-04-10': 1})
# osf.io/xcfdq
# osf.io/erw8m
# defaultdict(<class 'int'>, {'2017-04-10': 1, '2017-02-06': 1})
# osf.io/mys63
# osf.io/h5zkx
# defaultdict(<class 'int'>, {'2017-03-24': 1, '2017-03-07': 1})
# osf.io/chc92
# osf.io/be5p9
# defaultdict(<class 'int'>, {'2017-03-05': 1, '2016-12-21': 1})
# osf.io/edw6z
# osf.io/p2akj
# defaultdict(<class 'int'>, {'2016-12-15': 1, '2016-12-11': 1})
# osf.io/n5w84
# osf.io/5mcq4
# defaultdict(<class 'int'>, {'2016-12-14': 1, '2016-12-12': 1})
# osf.io/pajqe
# osf.io/55g8x
# defaultdict(<class 'int'>, {'2016-12-08': 1, '2016-12-07': 1})
# osf.io/bfr5s
# osf.io/eucqr
# defaultdict(<class 'int'>, {'2016-09-01': 1, '2016-07-15': 1})
# osf.io/8nkya
# osf.io/2bdmj
# defaultdict(int, {2: 528, 1: 238, 4: 14, 5: 6, 6: 3, 3: 58, 15: 1})

# %%
duplicate_titles = 0

records_with_duplicate_title = []

duplicate_titles_same_authors = {}
duplicate_titles_same_first_authors = {}

records_with_duplicate_titles_same_authors = []
records_with_duplicate_titles_same_first_author = []

records_from_inarxiv = set()

for title, records in titles.items():
    if len(records) > 1:
        duplicate_titles += 1
        
        records_with_duplicate_title.append({ 'title' : title, 'records' : len(records) })

        for i in range(len(records)):
            for j in range(i + 1, len(records)):

                if len(records[i]['authors']) == len(records[j]['authors']):
                    same_authors = True
                    
                    for k in range(len(records[i]['authors'])):
                        if records[i]['authors'][k] != records[j]['authors'][k]:
                            same_authors = False
                            break
                    
                    if same_authors:
                        records_with_duplicate_titles_same_authors.append({ 'title' : title,
                                                                          'id_1' : 'osf.io/' + records[i]['id'],
                                                                          'id_2' : 'osf.io/' + records[j]['id'],
                                                                          'server_1' : records[i]['server'],
                                                                          'server_2' : records[j]['server'],
                                                                          'doi_1' : records[i]['doi'],
                                                                          'doi_2' : records[j]['doi']})
                        
                        if title not in duplicate_titles_same_authors:
                            duplicate_titles_same_authors[title] = set()
                        
                        duplicate_titles_same_authors[title].add(records[i]['id'])
                        duplicate_titles_same_authors[title].add(records[j]['id'])
                        
#                         if records[i]['server'] == 'inarxiv':
#                             records_from_inarxiv.add(records[i]['id'])
#                         if records[j]['server'] == 'inarxiv':
#                             records_from_inarxiv.add(records[j]['id'])
                        
                        
                    elif len(records[i]['authors']) > 0 and len(records[j]['authors']) > 0 and \
                            records[i]['authors'][0] == records[j]['authors'][0]:
                            records_with_duplicate_titles_same_first_author.append({ 'title' : title,
                                                                          'id_1' : 'osf.io/' + records[i]['id'],
                                                                          'id_2' : 'osf.io/' + records[j]['id'],
                                                                          'server_1' : records[i]['server'],
                                                                          'server_2' : records[j]['server'],
                                                                          'doi_1' : records[i]['doi'],
                                                                          'doi_2' : records[j]['doi']})
                            
                            if title not in duplicate_titles_same_first_authors:
                                duplicate_titles_same_first_authors[title] = set()

                            duplicate_titles_same_first_authors[title].add(records[i]['id'])
                            duplicate_titles_same_first_authors[title].add(records[j]['id'])
                            
                elif len(records[i]['authors']) > 0 and len(records[j]['authors']) > 0 and \
                            records[i]['authors'][0] == records[j]['authors'][0]:
                            records_with_duplicate_titles_same_first_author.append({ 'title' : title,
                                                                          'id_1' : 'osf.io/' + records[i]['id'],
                                                                          'id_2' : 'osf.io/' + records[j]['id'],
                                                                          'server_1' : records[i]['server'],
                                                                          'server_2' : records[j]['server'],
                                                                          'doi_1' : records[i]['doi'],
                                                                          'doi_2' : records[j]['doi']})
                            if title not in duplicate_titles_same_first_authors:
                                duplicate_titles_same_first_authors[title] = set()

                            duplicate_titles_same_first_authors[title].add(records[i]['id'])
                            duplicate_titles_same_first_authors[title].add(records[j]['id'])
                    
duplicate_titles
# Out:
# 848

# %%
dtsa = []

for title, records in duplicate_titles_same_authors.items():
    dtsa.append({ 'title' : title, 'records' : len(records)})

df = pd.DataFrame(dtsa)
df.to_csv('duplicate_titles_same_authors.csv')

# %%
df = pd.DataFrame(records_with_duplicate_titles_same_authors)
df.to_csv('records_with_exact_titles_and_all_authors.csv')

# %%
df = pd.DataFrame(records_with_duplicate_titles_same_first_author)
df.to_csv('records_with_exact_titles_and_first_authors.csv')

# %%
len(records_from_inarxiv)
# Out:
# 640

# %%
dtsfa = []

for title, records in duplicate_titles_same_first_authors.items():
    dtsfa.append({ 'title' : title, 'records' : len(records)})

df = pd.DataFrame(dtsfa)
df.to_csv('duplicate_titles_same_first_authors.csv')

# %%
len(records_with_duplicate_titles_same_authors)
# Out:
# 1071

# %%
import numpy as np
from collections import defaultdict

cutoff_date = parse_date('2019-6-1')[0]

author_names = {}
author_ids = {}

name_id_map = {}

rec = 0
no_rec = 0

for record in osf_records:
    server = record['osf_record']['relationships']['provider']['links']['related']['href'].replace( \
                'https://api.osf.io/v2/providers/preprints/', '').replace('/?format=json', '')
    
    if server not in author_names:
        author_names[server] = defaultdict(int)
        author_ids[server] = defaultdict(int)
    
    for author_list in record['osf_authors'][0]:
        for author in author_list['data']:
            if author['attributes']['bibliographic']:
                try:
#                     parse_date(author['embeds']['users']['data']['attributes']['date_registered'][:10])
                    author_data = author['embeds']['users']['data']['attributes']
                    author_id = author['embeds']['users']['data']['id']
                    
                    rec += 1
                    
                    author_names[server][author_data['full_name']] += 1
                    author_names[server][author_id] += 1
                    
#                     input(author)
                    if author_data['full_name'] in name_id_map and name_id_map[author_data['full_name']] != author_id:
                        print('Same name diff ids: {}--{}'.format(name_id_map[author_data['full_name']], author_id))
                        print(author_data['full_name'])
                    name_id_map[author_data['full_name']] = author_id
                    
                except Exception as e:
                    author_data = author['embeds']['users']['errors'][0]['meta']
                    
                    no_rec +=1
#                     input( author['embeds']['users'])
# Out:
# Same name diff ids: 4q23e--tvnzp
# Benjamin Davies
# Same name diff ids: b37ef--zu6wy
# Abdul Malik
# Same name diff ids: p4grw--9sgwp
# Abbas Bahroudi
# Same name diff ids: qctpn--4ctka
# Ninuk Wiliani
# Same name diff ids: f3qad--x4sgq
# Asrul Sani
# Same name diff ids: ypbmh--5pu3r
# Suharto
# Same name diff ids: bnepj--tvp8m
# miftahul jannah
# Same name diff ids: 4tuk2--4j57a
# Habibulla Yunuskhodjaev
# Same name diff ids: by9s6--ser2w
# Maryam Musfiroh
# Same name diff ids: kav87--heqtw
# Umida Khamidullayevna Saydikramova
# Same name diff ids: qne2z--zs4j6
# Khurmat Sabirovna Valieva
# Same name diff ids: t3pae--qyv28
# Shakhnovza Bakhtiyorovna Sagatova
# Same name diff ids: 5thvs--hf2rg
# Nilufar Bakhadirovna Mukhamadalieva
# Same name diff ids: ep6ds--zqxch
# Мухаббат Рахмоналиевна Исаева
# Same name diff ids: b9av3--rf5n9
# Fahrida Inayati
# Same name diff ids: 9j3xn--bwdfk
# Esdavina Elvandari
# Same name diff ids: prdyt--8zru7
# Hafizatul Bahri
# Same name diff ids: 8zru7--g56nf
# Hafizatul Bahri
# Same name diff ids: knurz--7zpaf
# Christer Johansson
# Same name diff ids: qe9vs--8uhw3
# Hengki Wijaya
# Same name diff ids: 8uhw3--qe9vs
# Hengki Wijaya
# Same name diff ids: pvmg6--k8237
# Triyono
# Same name diff ids: 9sgwp--p4grw
# Abbas Bahroudi
# Same name diff ids: p4grw--9sgwp
# Abbas Bahroudi
# Same name diff ids: ser2w--pswe9
# Maryam Musfiroh
# Same name diff ids: 79vqd--2856e
# Марьям Абдуллаевна Акаева
# Same name diff ids: z3sfn--bp6fj
# Разия Мурадхановна Хидирова
# Same name diff ids: 8k5dh--4zxmk
# Razali Adul Hamid
# Same name diff ids: s98ya--vaykx
# Mohd Saidin Misnan
# Same name diff ids: xw9fh--aqksf
# Nur Azizah
# Same name diff ids: d2key--mkaqc
# James Green
# Same name diff ids: 27h5p--3phmn
# Frank C Walsh
# Same name diff ids: n7r6e--h2xq4
# Jie Sui
# Same name diff ids: 259za--v97gd
# Ivan Ivanovich Krasnyuk
# Same name diff ids: hw7ep--jrsmu
# Lyailya Zhunusbekovna Kabdusheva
# Same name diff ids: jwfyx--czu92
# Zhanna Borisovna Erzhanova
# Same name diff ids: czu92--5d39v
# Zhanna Borisovna Erzhanova
# Same name diff ids: knjud--ev9yj
# Mustafa Sari
# Same name diff ids: x9y5e--dpcza
# Nur Aini
# Same name diff ids: zufvw--es9vf
# Matthew Winn
# Same name diff ids: 52t7r--w3bv8
# Majid Khorami
# Same name diff ids: h59mv--rfect
# Staci Byers
# Same name diff ids: gndhy--6gdkq
# Gulnar Dmitrievna Sharakpaeva
# Same name diff ids: 5d39v--27dyu
# Zhanna Borisovna Erzhanova
# Same name diff ids: y7s46--56jdy
# Makarius Itambu
# Same name diff ids: mkaqc--d2key
# James Green
# Same name diff ids: xfmsn--vnt4h
# Dewi Ratna Sari
# Same name diff ids: xmahd--83hnw
# Zoltan Dienes
# Same name diff ids: pj96b--hu2be
# Andrani Dwi Putri
# Same name diff ids: g6cxh--x6dn3
# Ningsih
# Same name diff ids: d2key--mkaqc
# James Green
# Same name diff ids: wxjzf--dpszj
# Ara Darzi
# Same name diff ids: mkaqc--frvj7
# James Green
# Same name diff ids: e28sg--u2vn7
# Capry Dudellah Rode
# Same name diff ids: s8c23--p9bt7
# Vella Melania
# Same name diff ids: cpe74--kz7p6
# Ronny
# Same name diff ids: tx2md--4bxk7
# Abdul Hafid Hasim
# Same name diff ids: vg9f3--v2z89
# Delfalina
# Same name diff ids: fmzkc--n6qjm
# Surya A. Venkaiah
# Same name diff ids: qn45r--324n6
# John Weisz
# Same name diff ids: ms7kn--khmgn
# Fayzulla Ochildiyev
# Same name diff ids: 27dyu--5d39v
# Zhanna Borisovna Erzhanova
# Same name diff ids: j85wr--p8dzv
# Ben Eppinger
# Same name diff ids: w3bv8--52t7r
# Majid Khorami
# Same name diff ids: pswe9--wn7br
# Maryam Musfiroh
# Same name diff ids: 5xupt--9suq6
# Laila Suryani
# Same name diff ids: rs9dt--takvh
# Pamela Jurdilla
# Same name diff ids: bqvjz--2vk69
# Ahmad Yani
# Same name diff ids: 2j3g6--rks26
# Edy Tonnizam Mohamad
# Same name diff ids: muyhv--vgdm6
# Liajum hasibuan
# Same name diff ids: nc63s--b9rdf
# Awad Magbri
# Same name diff ids: qev4f--n3em8
# Eusera El-Magbri
# Same name diff ids: nyk7r--zcjg6
# Mariam El-Magbri
# Same name diff ids: dvxcz--vszdk
# Brar Balhinder
# Same name diff ids: 6k9gz--zd2t4
# Shauket Rashid
# Same name diff ids: ym6g8--6p8me
# Max Hinne
# Same name diff ids: 4fsc2--eakhg
# Bahador Bahrami
# Same name diff ids: fmq3y--ds4v5
# Siti Ramlia Hasibuan
# Same name diff ids: uxt4b--5z8y9
# Khurshida Salavatova
# Same name diff ids: mgk2t--56zd2
# Dilshod Khudayberganov
# Same name diff ids: uzcrj--w7b6c
# Юлдуз Рахматовна Махмутазимова
# Same name diff ids: 56zd2--mgk2t
# Dilshod Khudayberganov
# Same name diff ids: 9tv4j--47mfw
# Maxsud Bazarboev
# Same name diff ids: ypa2q--eafrp
# Suhrobbek Sa’dullayev
# Same name diff ids: 5z8y9--s7djn
# Khurshida Salavatova
# Same name diff ids: rfcyz--efdpn
# Bekhzod Bakhrom ugli Aminov
# Same name diff ids: vte4z--8uxwr
# Alijon Olimjon ugli Khaitmuratov
# Same name diff ids: rwzmb--gxm4t
# Dan Sholler
# Same name diff ids: anwmf--egbfy
# Mike Tilston
# Same name diff ids: rwvsf--8kfms
# Diego Gambetta
# Same name diff ids: yu6k8--us72j
# Ylona van Dinther
# Same name diff ids: zcj26--qfch8
# Асет Джамалдиновна Султанова
# Same name diff ids: sp7y4--qjeu8
# Василий Трофимович Ярмишко
# Same name diff ids: x5fpu--uq9gz
# Александр Сергеевич Евдокимов
# Same name diff ids: rfv5g--rek2b
# Оrifjon Bahromovich Mamatkulov
# Same name diff ids: 3q4s9--qbnyd
# Shakhboz Khasanovich Khasanov
# Same name diff ids: 2hx8a--85wmj
# Temur Turakulovich Mavlonov
# Same name diff ids: 6x5ue--8rh5a
# Iskandar Тolibovich Мuminov
# Same name diff ids: ztrh6--st8hj
# Тolib Мusaevich Мuminov
# Same name diff ids: t52xf--qwzcb
# Аliakbar Kurbanovich Мukhamedov
# Same name diff ids: rek2b--bxm2t
# Оrifjon Bahromovich Mamatkulov
# Same name diff ids: 8wjeq--3xzsk
# Lochin Тirkashovich Nurmuradov
# Same name diff ids: 3cqzg--dt2vr
# Аkmal Аskarovich Safarov
# Same name diff ids: qbnyd--mwkbu
# Shakhboz Khasanovich Khasanov
# Same name diff ids: zbnup--dmcf7
# A’zam Тursunovich Khudayberdiev
# Same name diff ids: mdfgr--bdg2f
# Руслан Сергеевич Решетов
# Same name diff ids: upbtm--wd2rg
# Дмитрий Алексеевич Погожев
# Same name diff ids: y2kth--sqe68
# Мария Михайловна Кошелькова
# Same name diff ids: vuty8--w2p4f
# Анастасия Алексеевна Лентина
# Same name diff ids: 9z7an--fh7cd
# Анна Викторовна Горячева
# Same name diff ids: h3ax7--k74he
# Алексей Игоревич Безруких
# Same name diff ids: nsprw--qpnj3
# Семён Олегович Романенков
# Same name diff ids: a6s43--uh6pz
# Саида Адиловна Низамова
# Same name diff ids: 9jy4m--hq7fp
# Yoed Kenett
# Same name diff ids: 7zkh6--5bgp8
# Michael Ramscar
# Same name diff ids: efdpn--dkce5
# Bekhzod Bakhrom ugli Aminov
# Same name diff ids: 5cdbv--ecz58
# Gulira’no Masharipova
# Same name diff ids: s7djn--nzjt6
# Khurshida Salavatova
# Same name diff ids: 4j57a--q42a5
# Habibulla Yunuskhodjaev
# Same name diff ids: njbuq--hkp97
# Madina Karimova
# Same name diff ids: eafrp--une5g
# Suhrobbek Sa’dullayev
# Same name diff ids: 83hnw--xmahd
# Zoltan Dienes
# Same name diff ids: u2mea--7m4u8
# Basri Abdul Talib
# Same name diff ids: w3dpq--4sxbv
# Rawshan Ara Begum
# Same name diff ids: m6t8z--urj8z
# Chamhuri Siwar
# Same name diff ids: 42jcd--25aex
# Lubna Alam
# Same name diff ids: 8kf95--dsna6
# Nurlaely Razak
# Same name diff ids: jrsmu--qcgdv
# Lyailya Zhunusbekovna Kabdusheva
# Same name diff ids: 5d39v--ybuwd
# Zhanna Borisovna Erzhanova
# Same name diff ids: mbwfj--5eyzh
# Saule Viktorovna Ashenova
# Same name diff ids: gfsrj--gc5kj
# Aigerim Toleutayevna Murzatayeva
# Same name diff ids: ybuwd--286st
# Zhanna Borisovna Erzhanova
# Same name diff ids: wug8b--hw297
# Елена Васильевна Фалунина
# Same name diff ids: guznq--f4kp3
# Ксенія Володимирівна Заєць
# Same name diff ids: w294g--5bfn9
# Жаъфархон Исахонов
# Same name diff ids: w34vx--zdvn2
# Екатерина Вячеславовна Гордеева
# Same name diff ids: kyhd3--wekng
# Elijah Knaap
# Same name diff ids: gbps8--xydzs
# Biplab Kumar Shaha
# Same name diff ids: f3evr--nbmau
# H. M. Rakibul Islam
# Same name diff ids: urj8z--m6t8z
# Chamhuri Siwar
# Same name diff ids: 7sz9f--9ygsn
# Dung Van Nguyen
# Same name diff ids: pb3da--kea5f
# Pinthep Sethapokin
# Same name diff ids: wdra5--zxjnq
# Harifara Rabemanolontsoa
# Same name diff ids: et39d--9pkvd
# Eiji Minami
# Same name diff ids: bnuzs--va8fe
# Haruo Kawamoto
# Same name diff ids: byvsg--kbfcw
# Shiro Saka
# Same name diff ids: nvymx--rakg6
# Anjar Astuti Ferdhiani
# Same name diff ids: 7un58--rs24q
# Sri Lestari
# Same name diff ids: evxch--49myc
# Elly Proklamasiningsih
# Same name diff ids: df9hu--q59xs
# Muhammad Amin Shodiq
# Same name diff ids: jknqv--kt56e
# Tati Budiarti
# Same name diff ids: 8nsjm--kv86j
# Nizar Nasrullah
# Same name diff ids: h9ntr--vcuaw
# Akbar Yusuf
# Same name diff ids: xydzs--gbps8
# Biplab Kumar Shaha
# Same name diff ids: 7vbcz--9fesj
# Madan Mohan Dey
# Same name diff ids: 9fesj--z4r3s
# Madan Mohan Dey
# Same name diff ids: b9rdf--a5twy
# Awad Magbri
# Same name diff ids: n3em8--qma9p
# Eusera El-Magbri
# Same name diff ids: zcjg6--egqc5
# Mariam El-Magbri
# Same name diff ids: vszdk--k8f7d
# Brar Balhinder
# Same name diff ids: zd2t4--abvd2
# Shauket Rashid
# Same name diff ids: 72ndg--7pgt3
# Maurizio Alletto
# Same name diff ids: d9y8p--ma6yp
# Salvatore Amico
# Same name diff ids: b9vwy--r8xce
# Umberto Castiglione
# Same name diff ids: mtk9e--jmd8a
# Giovanni Fulco
# Same name diff ids: w24ge--76daq
# Concetta Groppuso
# Same name diff ids: v3ewa--emj6t
# Basam Zuhaer Sindi
# Same name diff ids: stn2e--vsutq
# Naif Mishkhas Alazwari
# Same name diff ids: nmgkq--h9wru
# Abdulaziz Mohammed Khateeb
# Same name diff ids: q38gt--szhvw
# Aqil Abdulmonem Alzaher
# Same name diff ids: ebsk9--53uvk
# Mohammad Abdulaziz M Alkhawajah
# Same name diff ids: yht5g--tqjcf
# Atheer Khalid Almutairi
# Same name diff ids: 5qdau--dcp6b
# Md. Wahid Murad
# Same name diff ids: 459ka--2qjrv
# Mohd Ekhwan bin Toriman
# Same name diff ids: 46mrg--ya3dw
# Mazlin Mokhtar
# Same name diff ids: g7cyj--ftxpr
# Md. Abu Rashed
# Same name diff ids: ajgk3--u8cmy
# Md. Gazi Salah Uddin
# Same name diff ids: vcuaw--h9ntr
# Akbar Yusuf
# Same name diff ids: 7ygma--d4vxu
# Md. Mahadi Hasan
# Same name diff ids: dcp6b--jx2qw
# Md. Wahid Murad
# Same name diff ids: u8cmy--h5wuv
# Md. Gazi Salah Uddin
# Same name diff ids: h5wuv--wh2gn
# Md. Gazi Salah Uddin
# Same name diff ids: 2nv5d--mxw2k
# Kazi Ashraful Alam
# Same name diff ids: w84yg--6a8gh
# Azizjon Akromov
# Same name diff ids: ptsa7--2v5fq
# Mushtariybegim Azlarova
# Same name diff ids: shf3y--w9j2d
# Bobur Mamataliev
# Same name diff ids: 9pghm--6w342
# Azimkhon Koriev
# Same name diff ids: abe62--3mjfp
# Hamidullah Bamik
# Same name diff ids: 286st--u764g
# Zhanna Borisovna Erzhanova
# Same name diff ids: fgucm--9pt5g
# Yu Sun
# Same name diff ids: ag7hf--g75dm
# Екатерина Александровна Яцевич
# Same name diff ids: fxr24--7mxsq
# Philip Nel
# Same name diff ids: 59hke--je86t
# Ulzhamilya Bibatyrovna Serikbayeva
# Same name diff ids: u764g--5d39v
# Zhanna Borisovna Erzhanova
# Same name diff ids: bgvtk--xezpk
# Musahonzoda Ikromjon
# Same name diff ids: wekng--kyhd3
# Elijah Knaap
# Same name diff ids: zdnrf--aq4v2
# Khan Md. Raziuddin Taufique
# Same name diff ids: mxw2k--2nv5d
# Kazi Ashraful Alam
# Same name diff ids: 2nv5d--mxw2k
# Kazi Ashraful Alam
# Same name diff ids: 27e8n--3cph2
# Dinar Camotim
# Same name diff ids: 3cph2--27e8n
# Dinar Camotim
# Same name diff ids: bhwmq--vu2r4
# Miguel Abambres
# Same name diff ids: vu2r4--bhwmq
# Miguel Abambres
# Same name diff ids: 27e8n--3cph2
# Dinar Camotim
# Same name diff ids: 3mjfp--abe62
# Hamidullah Bamik
# Same name diff ids: 6a8gh--8k7wu
# Azizjon Akromov
# Same name diff ids: w9j2d--wn7ab
# Bobur Mamataliev
# Same name diff ids: 6w342--5vze4
# Azimkhon Koriev
# Same name diff ids: cegp7--5aqm3
# Bambang Sulistyantara
# Same name diff ids: wa89t--pvxut
# Mansoureh Tahbaz
# Same name diff ids: 5aqm3--eds3n
# Bambang Sulistyantara
# Same name diff ids: us72j--yu6k8
# Ylona van Dinther
# Same name diff ids: q3ufr--8er2b
# Jonathan Venezia
# Same name diff ids: yu6k8--us72j
# Ylona van Dinther
# Same name diff ids: bcm9f--73wns
# R.K. Roy
# Same name diff ids: 42qkx--a7hfr
# J.S. Khuraijam
# Same name diff ids: hy23d--vxm7z
# Shilpi Singh
# Same name diff ids: 9ygd8--venxj
# Matthias Weber
# Same name diff ids: f56gr--pu4rn
# AbdolHossein Vahabie
# Same name diff ids: szq87--6stm9
# Анна Александровна Полиди
# Same name diff ids: m2jgu--gy98t
# Екатерина Викторовна Трунова
# Same name diff ids: 9w8as--phz6n
# Людмила Александровна Спектор
# Same name diff ids: xgdkt--m3kpn
# Murniati
# Same name diff ids: 7kfje--pbtvy
# Yulduz Sultanmuratova
# Same name diff ids: pbtvy--csfaj
# Yulduz Sultanmuratova
# Same name diff ids: ecz58--gqtf4
# Gulira’no Masharipova
# Same name diff ids: csfaj--2gvap
# Yulduz Sultanmuratova
# Same name diff ids: gqtf4--cghm2
# Gulira’no Masharipova
# Same name diff ids: se7q3--635xd
# Jakhongir Qakhramon ugli Qodirov
# Same name diff ids: tjfpz--c8bpu
# Kaiping Peng
# Same name diff ids: ke9p4--cjtns
# Mark Dingemanse
# Same name diff ids: dkce5--6j2qv
# Bekhzod Bakhrom ugli Aminov
# Same name diff ids: vczqe--84q3p
# Юлия Сайфуллаевна Норбекова
# Same name diff ids: axzvy--ybnxg
# Виолетта Арсеновна Агаян
# Same name diff ids: gy98t--fsk8r
# Екатерина Викторовна Трунова
# Same name diff ids: rkqgj--ektcp
# Валентина Александровна Орлова
# Same name diff ids: vcksr--xnra8
# Оксана Владимировна Мелентьева
# Same name diff ids: mpfxu--428wm
# Эдуард Ефимович Гензюк
# Same name diff ids: fbeu6--9h258
# Виктория Сергеевна Кириленко
# Same name diff ids: phz6n--gxczt
# Людмила Александровна Спектор
# Same name diff ids: wpavm--85bwf
# Анна Анатольевна Куликова
# Same name diff ids: gs4uc--7qdv5
# Анастасия Анатольевна Чертова
# Same name diff ids: fsk8r--qkgzx
# Екатерина Викторовна Трунова
# Same name diff ids: 5nawr--3hp6e
# Alan Kingstone
# Same name diff ids: fvtjy--tj5c6
# Heriyanto
# Same name diff ids: 3vzqe--2dvbq
# Wahyudi
# Same name diff ids: 9e4x7--azpgr
# Joris Mulder
# Same name diff ids: qfch8--hzbn3
# Асет Джамалдиновна Султанова
# Same name diff ids: hzbn3--qfch8
# Асет Джамалдиновна Султанова
# Same name diff ids: 56akc--wqf8z
# Yulia Asri Warlinda
# Same name diff ids: cjmnd--d5bym
# Paul J. Haverkamp
# Same name diff ids: 3tvbx--wm56b
# Afrinaldi
# Same name diff ids: s8unc--wk7ng
# Mekhriniso Ne'mat qizi Qudratova
# Same name diff ids: y6nvr--2tm3s
# Petr Slovak
# Same name diff ids: 94jqt--h7qp2
# Khusniya Ergash qizi Boysunova
# Same name diff ids: zfmtv--q89yr
# Ugilshod Anvar qizi Suyunova
# Same name diff ids: wk7ng--96gkx
# Mekhriniso Ne'mat qizi Qudratova
# Same name diff ids: puf7b--k7pag
# Zukhriddin Ilxom ugli Ziyadullayev
# Same name diff ids: 635xd--dj3q8
# Jakhongir Qakhramon ugli Qodirov
# Same name diff ids: q7axg--5fqjb
# Fabio Grati
# Same name diff ids: rzhfj--45dvg
# Кристина Витальевна Машковцева
# Same name diff ids: 9g2p6--zuyh7
# Илья Дмитриевич Белокозович
# Same name diff ids: de8wc--czpg6
# Вера Аркадьевна Шаклеина
# Same name diff ids: dj3q8--se7q3
# Jakhongir Qakhramon ugli Qodirov
# Same name diff ids: qfch8--ub2qx
# Асет Джамалдиновна Султанова
# Same name diff ids: 27mde--3rp72
# Раиса Юнусовна Султанова
# Same name diff ids: nf3kj--sbmy7
# Thu-Trang Vuong
# Same name diff ids: 7mxsq--fxr24
# Philip Nel
# Same name diff ids: 6p8me--ym6g8
# Max Hinne
# Same name diff ids: 3p7fg--xk3bz
# Hidayati
# Same name diff ids: xbv3w--mvjkf
# Said Sampara
# Same name diff ids: f3xrp--deh76
# Rahmi Holinesti
# Same name diff ids: z623e--73thd
# Riza saputra
# Same name diff ids: 8z9uv--h2wk5
# Анастасия Александровна Веселова
# Same name diff ids: zx46e--mreq3
# Александр Дмитриевич Швец
# Same name diff ids: s237e--tvg6z
# Agnieszka Wykowska
# Same name diff ids: ax5hm--txp7k
# Татьяна Владимировна Панкова
# Same name diff ids: emfz4--b7hnf
# Нишчхал
# Same name diff ids: v3a25--jmvaw
# Вероника Алексеевна Финк
# Same name diff ids: a7u5e--yuvk6
# Mark Apperley
# Same name diff ids: 498td--k2yrn
# Aynura Pashayeva
# Same name diff ids: k2yrn--hwajp
# Aynura Pashayeva
# Same name diff ids: amz2r--sbwxa
# Pari Hasanli
# Same name diff ids: gkv2q--73xbn
# Tohfa Amrahli (Bagirova)
# Same name diff ids: vp8kz--65fjx
# Marina Vladimirovna Kislinskaya
# Same name diff ids: r27kv--g9cak
# Dmitry Yurievich Kovulkin
# Same name diff ids: vec8g--zevtc
# Nikolay Vladimirovich Usov
# Same name diff ids: 6cmnt--wknvd
# Eka Vidya Putra
# Same name diff ids: xk3bz--d8kax
# Hidayati
# Same name diff ids: j8paq--39unh
# Вазген Хоренович Тирацуян
# Same name diff ids: np78z--nyw7e
# Любовь Александровна Трофимова
# Same name diff ids: r84py--3a85p
# Екатерина Алексеевна Ли
# Same name diff ids: 39unh--fd4wu
# Вазген Хоренович Тирацуян
# Same name diff ids: 8hjvy--wsvxc
# Павел Сергеевич Штода
# Same name diff ids: azpgr--5n2qh
# Joris Mulder
# Same name diff ids: xkz6e--4gzc7
# София Николаевна Немгирова
# Same name diff ids: 6vngj--vaw3f
# Айса Анатольевна Манцаева
# Same name diff ids: rxh5w--dfmak
# Максим Сергеевич Ильин
# Same name diff ids: 7kbdp--uy8xd
# Бейбулат Салихович Атаев
# Same name diff ids: fchbs--t4978
# Ольга Владимировна Письменская
# Same name diff ids: mvydf--gp64w
# Мария Александровна Латышева
# Same name diff ids: 3shjg--yrgc9
# Chris Englert
# Same name diff ids: b5qm4--7b69h
# Emmanuelle Peters
# Same name diff ids: aw7mg--buks8
# Rolando Armijo
# Same name diff ids: qd2eu--2fcpw
# Jop Klaver
# Same name diff ids: tvg6z--s237e
# Agnieszka Wykowska
# Same name diff ids: xybe7--q72un
# Вячеслав Александрович Кудашкин
# Same name diff ids: udxe2--tjb3c
# Sri Wahyuni
# Same name diff ids: s5gkb--dcbv5
# Corey Callaghan
# Same name diff ids: cjtns--ke9p4
# Mark Dingemanse
# Same name diff ids: 96bkj--tyckj
# Mohammad Shahrul Nizam Abd Wahid
# Same name diff ids: u26rs--n64xh
# Lidiah aprilliah
# Same name diff ids: bkm68--pdfxa
# Yadi Supriyadi
# Same name diff ids: qj7nr--wafq9
# Elmira Kalybaevna Adil’bekova
# Same name diff ids: 3h8ze--wp5sy
# Nuradin Alibaev
# Same name diff ids: gebsz--ght2s
# Arunas Svitojus
# Same name diff ids: uqr35--shdve
# Мария Игоревна Щеглова
# Same name diff ids: mc8an--jdxt9
# Мария Григорьевна Алпатова
# Same name diff ids: xmahd--83hnw
# Zoltan Dienes
# Same name diff ids: m3khu--9vecn
# Sitti Hajerah Hasyim
# Same name diff ids: 3mnhe--9dcvu
# Анастасия Сергеевна Шабанова
# Same name diff ids: 9dcvu--58tgq
# Анастасия Сергеевна Шабанова
# Same name diff ids: 7v3fy--vymf5
# Михаил Владимирович Кармаза
# Same name diff ids: nh3ek--3vh5q
# Роман Владимирович Мотылев
# Same name diff ids: d9a6j--hqgy7
# Вероника Александровна Одрузова
# Same name diff ids: dn3kb--vqet7
# Andrew Patterson
# Same name diff ids: 6c345--w26nh
# Lei Wang
# Same name diff ids: rwjne--57cjp
# Lei Zhang
# Same name diff ids: x3jb4--38ybs
# Карина Аскаровна Агадилова
# Same name diff ids: y3r7w--f2x6k
# Любовь Викторовна Чернова
# Same name diff ids: k98c2--7yuwa
# Syahril gunawan
# Same name diff ids: dsna6--u9gbn
# Nurlaely Razak
# Same name diff ids: 7cn9u--jzuw6
# Asmar Yulastri
# Same name diff ids: dhc9j--6phez
# Salma
# Same name diff ids: 5frwy--ek93y
# Елена Ивановна Голуб
# Same name diff ids: vktjs--ypc48
# Ирина Борисовна Иванова
# Same name diff ids: afy6m--4m68z
# Bella Alexandrowna Teobaldt
# Same name diff ids: 2dqhg--buc5t
# Ferdinandus Meka Dega
# Same name diff ids: buc5t--2dqhg
# Ferdinandus Meka Dega
# Same name diff ids: 5d39v--64dju
# Zhanna Borisovna Erzhanova
# Same name diff ids: nkdg8--h3kbf
# Joseph E. Beeney
# Same name diff ids: q56k9--u9dyq
# Muhammad Fadhil
# Same name diff ids: yjdfe--adr6w
# Ermansyah
# Same name diff ids: eyqz5--npfj8
# Nofi Nurman
# Same name diff ids: 9ky2r--hgvbf
# Hafrizal Okta Ade Putra
# Same name diff ids: p9ygb--yjvrx
# Олег Владимирович Дозоров
# Same name diff ids: yk39r--q273b
# Маржан Калжановна Нурмаханова
# Same name diff ids: 64dju--5d39v
# Zhanna Borisovna Erzhanova
# Same name diff ids: abpkq--xtq9r
# Улдай Жалгасовна Дайшкалиева
# Same name diff ids: cbpnz--mf75u
# Colin G. DeYoung
# Same name diff ids: uspdc--zgdx7
# Dewi Andriani
# Same name diff ids: venwh--c5q4h
# Bernd Strauss
# Same name diff ids: xynkp--3hmcb
# Hesti Mayasari
# Same name diff ids: hgvbf--9ky2r
# Hafrizal Okta Ade Putra
# Same name diff ids: zn8a5--4gfcq
# Christopher Bronk Ramsey
# Same name diff ids: 3pfuh--7b63r
# Paul Albert
# Same name diff ids: k7jzn--p4b6f
# Sarah Knight
# Same name diff ids: 6caez--ga9hd
# Sri Mulyani
# Same name diff ids: qnjhk--qcw3b
# Bustami muslim
# Same name diff ids: mkz5c--9ezdp
# Liza Zulbahri
# Same name diff ids: mf2r6--s3bp7
# Syahrial
# Same name diff ids: venxj--9ygd8
# Matthias Weber
# Same name diff ids: s8vnz--q9spm
# Kamaluddin
# Same name diff ids: h4vwp--n2z8b
# Indra Agus Riyanto
# Same name diff ids: ta3pc--ec8xb
# Adrien Locatelli
# Same name diff ids: fc3v6--ztc9r
# Михаил Геннадьевич Чепрасов
# Same name diff ids: 38ybs--hz5q9
# Карина Аскаровна Агадилова
# Same name diff ids: v43uc--jpfb2
# Игорь Олегович Мячин
# Same name diff ids: 5r7gf--6jszd
# Семен Данилович Соколов
# Same name diff ids: ztc9r--pr679
# Михаил Геннадьевич Чепрасов
# Same name diff ids: pr679--scbtz
# Михаил Геннадьевич Чепрасов
# Same name diff ids: 7shau--pdbzj
# Юрий Викторович Алёхин
# Same name diff ids: 6a95d--pd9rf
# Яна Владимировна Чурляева
# Same name diff ids: n2z8b--h4vwp
# Indra Agus Riyanto
# Same name diff ids: h63fm--tkz5f
# Eva Esiska
# Same name diff ids: jngbw--zrjvm
# Emenike Chiemeka Nkamnebe
# Same name diff ids: 9t5z6--khfm2
# Ifeka Ejike Okeke
# Same name diff ids: 28sjr--nbyvf
# Valentina Parma
# Same name diff ids: 8er2b--q3ufr
# Jonathan Venezia
# Same name diff ids: nj2hq--dwh78
# Alexander Belousov
# Same name diff ids: kgspr--pcxnb
# Kent A. Kiehl
# Same name diff ids: kz7p6--46ak7
# Ronny
# Same name diff ids: ghyvk--4wgzh
# Heny Setyawati
# Same name diff ids: k3htu--mpjzk
# Nurazizah
# Same name diff ids: 2a9x4--gu2rc
# Antonio Sirianni
# Same name diff ids: w7frf--xqntc
# Mark Brandt
# Same name diff ids: 83hnw--xmahd
# Zoltan Dienes
# Same name diff ids: xsy5k--6znbv
# Mitri Selisne
# Same name diff ids: uyzw7--5xd87
# Mega Iswari
# Same name diff ids: y42jp--dw8vx
# Chandra
# Same name diff ids: xqntc--w7frf
# Mark Brandt
# Same name diff ids: 58tgq--8ts9y
# Анастасия Сергеевна Шабанова
# Same name diff ids: gxm4t--rwzmb
# Dan Sholler
# Same name diff ids: 2xr9b--uq2tx
# Francois Lanusse
# Same name diff ids: 56jdy--y7s46
# Makarius Itambu
# Same name diff ids: x9gvc--r8kud
# Neduvoto Mollel
# Same name diff ids: pkd4r--vh67e
# Marko Repo
# Same name diff ids: sxnfm--zbu7y
# Stephen Hernandez
# Same name diff ids: 7r9gc--c93dn
# Heslina
# Same name diff ids: 3u84e--gq2wv
# Syamsul Alam
# Same name diff ids: dwrfy--qpa9b
# Syahril
# Same name diff ids: scbtz--z3gqk
# Михаил Геннадьевич Чепрасов
# Same name diff ids: rft82--pk4n5
# Mustika Ratu M
# Same name diff ids: tjb3c--h8msb
# Sri Wahyuni
# Same name diff ids: buks8--aw7mg
# Rolando Armijo
# Same name diff ids: p5u8c--r5spm
# Michael Laakasuo
# Same name diff ids: z3gqk--xb426
# Михаил Геннадьевич Чепрасов
# Same name diff ids: 2mh86--kcyzm
# Ahmad Taufik
# Same name diff ids: 48ds6--v2dtj
# Gerjo Kok
# Same name diff ids: p2ves--mjsx6
# Leopold Curfs
# Same name diff ids: cnjtv--q69ns
# Robert Sibarani
# Same name diff ids: q78av--h4wt3
# Daniel Storage
# Same name diff ids: es24b--a73eu
# Pavol Kačmár
# Same name diff ids: u8x35--evt5n
# Mohamed Yusoff bin Mohd Nor
# Same name diff ids: 29crp--nskm2
# Smitha Lingadahalli Ravi
# Same name diff ids: gmjz6--gvxqy
# Simine Vazire
# Same name diff ids: ej73y--7khcg
# Monica Tiara
# Same name diff ids: evt5n--u8x35
# Mohamed Yusoff bin Mohd Nor
# Same name diff ids: ms4wx--8yhu9
# Yenni Darvina
# Same name diff ids: d6fa4--ugkfh
# Irma Husnaini
# Same name diff ids: wzqmk--54e8p
# Stephen Snyder
# Same name diff ids: axqfk--rf2yp
# David Mohrig
# Same name diff ids: 325ye--x7sgm
# Agus Pahrudin
# Same name diff ids: rf2yp--axqfk
# David Mohrig
# Same name diff ids: rxa7s--s4p28
# Gary Kocurek
# Same name diff ids: r3s8x--cvmqd
# Elfizon
# Same name diff ids: d8kax--3p7fg
# Hidayati
# Same name diff ids: ayn3z--urgf8
# Richard Whittington
# Same name diff ids: 2qb6u--rbacy
# Bradley L. Schlaggar
# Same name diff ids: wzmre--g7pza
# Adam Flitton
# Same name diff ids: wd3g7--fhtdn
# Alnedral
# Same name diff ids: xw46b--tdrhe
# Aluisius Hery Pratono
# Same name diff ids: 4bngm--cdsmk
# William Ryan
# Same name diff ids: fpg8d--6ck2d
# Kevin Miller
# Same name diff ids: 8kwjy--u2ynt
# Nizwardi Jalinus
# Same name diff ids: y387j--x2d75
# Ganefri
# Same name diff ids: 3p7fg--2kfyr
# Hidayati
# Same name diff ids: 56at7--u8g54
# Hufri
# Same name diff ids: 2kfyr--d8kax
# Hidayati
# Same name diff ids: 47p8k--zmnb2
# Mary Fatimah Subet
# Same name diff ids: d8kax--ezg9w
# Hidayati
# Same name diff ids: 8yhu9--ms4wx
# Yenni Darvina
# Same name diff ids: fhtdn--qa4hk
# Alnedral
# Same name diff ids: qa4hk--wd3g7
# Alnedral
# Same name diff ids: af5zb--u4hz2
# Sonny Zinn
# Same name diff ids: d26nx--dvm4j
# Evan McQuinn
# Same name diff ids: at6s3--j8uwa
# Kenneth S. Casey
# Same name diff ids: h2pr9--nbkzt
# Paul Lemieux III
# Same name diff ids: 2y6c8--zv9ma
# Raisa Ionin
# Same name diff ids: c4gmy--m8s3p
# Philip Jones
# Same name diff ids: 4dpkr--8tb5d
# Arianna Jakositz
# Same name diff ids: 5zvmw--tcp4k
# Donald Collins
# Same name diff ids: h8jqb--4f39b
# Alia Azmi
# Same name diff ids: uqgv9--m24z9
# Fatmariza
# Same name diff ids: q9tsv--dm3fv
# Jian-Bin Li
# Same name diff ids: m3kpn--38k4j
# Murniati
# Same name diff ids: b3xgd--ejmb4
# Agus Setiawan
# Same name diff ids: 3v6zr--6zpwx
# Sri Rahayu
# Same name diff ids: 6mfe4--sgbyv
# Putri Fatimah
# Same name diff ids: p92y6--tb6fy
# Sophia Christin Weissgerber
# Same name diff ids: n2my9--hxmct
# Fernand Gobet
# Same name diff ids: hxmct--n2my9
# Fernand Gobet
# Same name diff ids: ybzd3--dwknp
# Takeshi Nakagawa
# Same name diff ids: bqv97--8qwnt
# Esy Maestro
# Same name diff ids: ywvur--c3bm8
# Azhar Jaafar@Ramli
# Same name diff ids: 3ftxj--2xpv3
# Elida
# Same name diff ids: 2rukg--gmqv9
# Ermawati Arief
# Same name diff ids: jzuw6--yz9pn
# Asmar Yulastri
# Same name diff ids: deh76--f3xrp
# Rahmi Holinesti
# Same name diff ids: cxw7a--mjcdu
# Agustina
# Same name diff ids: rp649--s5m74
# AFNITA
# Same name diff ids: x2d75--y387j
# Ganefri
# Same name diff ids: yz9pn--jzuw6
# Asmar Yulastri
# Same name diff ids: tzf59--c3pwh
# tressyalina
# Same name diff ids: gmqv9--2rukg
# Ermawati Arief
# Same name diff ids: erm95--3gzqh
# Novia Juita
# Same name diff ids: wr6bd--uxy4n
# Visca Alisia Arianti
# Same name diff ids: an7w9--t5ncf
# Alwen Bentri
# Same name diff ids: xmahd--83hnw
# Zoltan Dienes
# Same name diff ids: qj2xw--wchqy
# Yvonne Helbert
# Same name diff ids: jhnc8--72m5r
# Yulia Mona Liza
# Same name diff ids: p4gdt--7cgmu
# Idrus Hentihu
# Same name diff ids: cqt63--j947z
# Samsia Umasugi
# Same name diff ids: nbp8x--b5ept
# Abdul Latif Wabula
# Same name diff ids: 9vwuk--hq6us
# Said Abdurahman Assagaf
# Same name diff ids: uw5y9--zebhq
# Abdi Wael
# Same name diff ids: f8r4d--n7rfm
# Rosita Umanailo
# Same name diff ids: xs89f--rgb8e
# Hamiru Hamiru
# Same name diff ids: cbaqg--7j9pz
# Mansyur Nawawi
# Same name diff ids: ev7px--sju7v
# Sukainap Pulhehe
# Same name diff ids: 5a84t--wvfpc
# Mirja Ohoibor
# Same name diff ids: vaw3q--vc3ru
# Muhammad Bula
# Same name diff ids: c8x7h--cef6h
# Lutfi Rumkel
# Same name diff ids: mqxk9--xy6af
# Iskandar Hamid
# Same name diff ids: 7rf6t--unqck
# Belinda Sam
# Same name diff ids: vs3qh--7y6at
# Wa Malmia
# Same name diff ids: 3kmxa--6qbv2
# Syaiful Rachman
# Same name diff ids: 987xt--vukpq
# Salma Yusuf
# Same name diff ids: ykj63--5prk6
# M Yusran Zakaria
# Same name diff ids: b5ept--j4cvw
# Abdul Latif Wabula
# Same name diff ids: hq6us--7xcsk
# Said Abdurahman Assagaf
# Same name diff ids: zebhq--hgc9v
# Abdi Wael
# Same name diff ids: 7cgmu--q2mru
# Idrus Hentihu
# Same name diff ids: n7rfm--9m47q
# Rosita Umanailo
# Same name diff ids: 7j9pz--cvxy4
# Mansyur Nawawi
# Same name diff ids: sju7v--fe5jg
# Sukainap Pulhehe
# Same name diff ids: wvfpc--356jd
# Mirja Ohoibor
# Same name diff ids: mzpfs--68zya
# Edi Said Ningkeula
# Same name diff ids: vc3ru--x2cf4
# Muhammad Bula
# Same name diff ids: cef6h--5zdqa
# Lutfi Rumkel
# Same name diff ids: xy6af--c6ky8
# Iskandar Hamid
# Same name diff ids: mkurb--naf7t
# Irma Magfirah
# Same name diff ids: gmz3x--kmjc3
# Siami Prafitriyani
# Same name diff ids: unqck--7r84f
# Belinda Sam
# Same name diff ids: 7y6at--vw34h
# Wa Malmia
# Same name diff ids: 6qbv2--wkqej
# Syaiful Rachman
# Same name diff ids: vukpq--pju8g
# Salma Yusuf
# Same name diff ids: 5prk6--8q5n6
# M Yusran Zakaria
# Same name diff ids: 68zya--75yw3
# Edi Said Ningkeula
# Same name diff ids: 7r84f--grbwx
# Belinda Sam
# Same name diff ids: 5zdqa--vqckj
# Lutfi Rumkel
# Same name diff ids: hgc9v--5kucr
# Abdi Wael
# Same name diff ids: q2mru--jr3q8
# Idrus Hentihu
# Same name diff ids: j947z--j6hdv
# Samsia Umasugi
# Same name diff ids: 9m47q--76zyr
# Rosita Umanailo
# Same name diff ids: rdpm2--dyxhs
# Hamiru
# Same name diff ids: cvxy4--mh6ke
# Mansyur Nawawi
# Same name diff ids: fe5jg--2tk6m
# Sukainap Pulhehe
# Same name diff ids: 356jd--796as
# Mirja Ohoibor
# Same name diff ids: 28xd3--8ztwn
# Riki Bugis
# Same name diff ids: x2cf4--75kvb
# Muhammad Bula
# Same name diff ids: c6ky8--stev8
# Iskandar Hamid
# Same name diff ids: naf7t--9ewk4
# Irma Magfirah
# Same name diff ids: 7xcsk--ue4n6
# Said Abdurahman Assagaf
# Same name diff ids: kmjc3--r42by
# Siami Prafitriyani
# Same name diff ids: j4cvw--7behr
# Abdul Latif Wabula
# Same name diff ids: vw34h--zsqtv
# Wa Malmia
# Same name diff ids: wkqej--pfmwx
# Syaiful Rachman
# Same name diff ids: pju8g--pux9v
# Salma Yusuf
# Same name diff ids: 8q5n6--6mpwd
# M Yusran Zakaria
# Same name diff ids: grbwx--td9uz
# Belinda Sam
# Same name diff ids: vqckj--bsu2g
# Lutfi Rumkel
# Same name diff ids: 5kucr--26dzu
# Abdi Wael
# Same name diff ids: jr3q8--qh9kt
# Idrus Hentihu
# Same name diff ids: 76zyr--9rytw
# Rosita Umanailo
# Same name diff ids: dyxhs--sfd5n
# Hamiru
# Same name diff ids: mh6ke--qc5ez
# Mansyur Nawawi
# Same name diff ids: 2tk6m--mgsjb
# Sukainap Pulhehe
# Same name diff ids: 796as--xafvr
# Mirja Ohoibor
# Same name diff ids: 8ztwn--wtv8z
# Riki Bugis
# Same name diff ids: 75yw3--yj5pz
# Edi Said Ningkeula
# Same name diff ids: 75kvb--n98qb
# Muhammad Bula
# Same name diff ids: stev8--rd4bz
# Iskandar Hamid
# Same name diff ids: 9ewk4--6wfxe
# Irma Magfirah
# Same name diff ids: ue4n6--t96nu
# Said Abdurahman Assagaf
# Same name diff ids: r42by--kt54m
# Siami Prafitriyani
# Same name diff ids: 7behr--rjtdv
# Abdul Latif Wabula
# Same name diff ids: zsqtv--hgrw4
# Wa Malmia
# Same name diff ids: pfmwx--267s4
# Syaiful Rachman
# Same name diff ids: pux9v--6tbd4
# Salma Yusuf
# Same name diff ids: 6mpwd--dxh6z
# M Yusran Zakaria
# Same name diff ids: dxh6z--x5kqz
# M Yusran Zakaria
# Same name diff ids: 6tbd4--tmbq8
# Salma Yusuf
# Same name diff ids: 267s4--qdnx8
# Syaiful Rachman
# Same name diff ids: hgrw4--mybcg
# Wa Malmia
# Same name diff ids: td9uz--b2ynf
# Belinda Sam
# Same name diff ids: rjtdv--5f9am
# Abdul Latif Wabula
# Same name diff ids: t96nu--5s7jb
# Said Abdurahman Assagaf
# Same name diff ids: 6wfxe--kjcey
# Irma Magfirah
# Same name diff ids: kt54m--kd4gm
# Siami Prafitriyani
# Same name diff ids: rd4bz--9t53f
# Iskandar Hamid
# Same name diff ids: bsu2g--2fwmc
# Lutfi Rumkel
# Same name diff ids: n98qb--uspk7
# Muhammad Bula
# Same name diff ids: wtv8z--4hrdv
# Riki Bugis
# Same name diff ids: xafvr--b4dah
# Mirja Ohoibor
# Same name diff ids: mgsjb--wv9ep
# Sukainap Pulhehe
# Same name diff ids: sfd5n--7dkfx
# Hamiru
# Same name diff ids: 9rytw--54kdq
# Rosita Umanailo
# Same name diff ids: qh9kt--a8rch
# Idrus Hentihu
# Same name diff ids: 26dzu--qkhps
# Abdi Wael
# Same name diff ids: 5f9am--xveht
# Abdul Latif Wabula
# Same name diff ids: 5s7jb--f2hcn
# Said Abdurahman Assagaf
# Same name diff ids: qkhps--p3nzu
# Abdi Wael
# Same name diff ids: a8rch--5a2yk
# Idrus Hentihu
# Same name diff ids: 54kdq--xtzvd
# Rosita Umanailo
# Same name diff ids: 7dkfx--mxrth
# Hamiru
# Same name diff ids: qc5ez--9n6cu
# Mansyur Nawawi
# Same name diff ids: wv9ep--grv98
# Sukainap Pulhehe
# Same name diff ids: b4dah--ge5u4
# Mirja Ohoibor
# Same name diff ids: 4hrdv--vq8dj
# Riki Bugis
# Same name diff ids: yj5pz--7mye8
# Edi Said Ningkeula
# Same name diff ids: uspk7--y26s8
# Muhammad Bula
# Same name diff ids: 2fwmc--qm3fx
# Lutfi Rumkel
# Same name diff ids: 9t53f--5gh8x
# Iskandar Hamid
# Same name diff ids: kjcey--9kumn
# Irma Magfirah
# Same name diff ids: kd4gm--wgmqd
# Siami Prafitriyani
# Same name diff ids: b2ynf--7ra58
# Belinda Sam
# Same name diff ids: j6hdv--kj7as
# Samsia Umasugi
# Same name diff ids: mybcg--csh43
# Wa Malmia
# Same name diff ids: qdnx8--a3ugv
# Syaiful Rachman
# Same name diff ids: tmbq8--t27nv
# Salma Yusuf
# Same name diff ids: x5kqz--a2tzj
# M Yusran Zakaria
# Same name diff ids: pvn4x--gk65c
# Gail Steptoe-Warren
# Same name diff ids: tb6fy--p92y6
# Sophia Christin Weissgerber
# Same name diff ids: 43ftr--jak2s
# Abd. Mansyur Mus
# Same name diff ids: v2dtj--48ds6
# Gerjo Kok
# Same name diff ids: gcmy3--wb59d
# Jorgen Randers
# Same name diff ids: 2g6p3--pzcbk
# Liudmila Vyacheslavovna Fomina
# Same name diff ids: jak2s--7p8rv
# Abd. Mansyur Mus
# Same name diff ids: zmnb2--hngyz
# Mary Fatimah Subet
# Same name diff ids: rvk4h--btqdf
# Mawardi
# Same name diff ids: a2c59--6m86j
# Julian Pine
# Same name diff ids: t82dp--sx9ck
# Giovanni Sala
# Same name diff ids: mzgtr--n9t8e
# Peter Kramer
# Same name diff ids: hngyz--rpb57
# Mary Fatimah Subet
# Same name diff ids: 9nymf--vxdu9
# Mohd Khairul Adenan
# Same name diff ids: pgh86--ry4p3
# Kharull Haffis Ngairan
# Same name diff ids: bew8n--5vjur
# Jeffrey June
# Same name diff ids: ezg9w--fbgpx
# Hidayati
# Same name diff ids: ng82h--f5hej
# Minda Azhar
# Same name diff ids: eh9j3--rxmhd
# Ratna Dewi
# Same name diff ids: pnj7c--ge7mq
# Amir Mahmud
# Same name diff ids: qzabv--g678q
# Mirfan M
# Same name diff ids: j534n--u25rs
# H. Mursalim Umar Gani
# Same name diff ids: xdhn8--2uqc9
# Serlin Serang
# Same name diff ids: 7s3gb--hv6b2
# H. Zaenal Arifin
# Same name diff ids: a2f57--bt2xu
# Rusmawan Suwarman
# Same name diff ids: tqj2x--56gwa
# James Thompson
# Same name diff ids: mpucv--s2t4z
# Olivier Collignon
# Same name diff ids: 8ufbw--eq39b
# Akitoshi Uchida
# Same name diff ids: gb5er--vqa9c
# Jean-Paul Montagner
# Same name diff ids: rxufc--jmb7p
# Valerie E. Appleton
# Same name diff ids: 4gjmi--b4jvx
# Dobromir Rahnev
# Same name diff ids: ac85r--hu4dq
# Matthias Imboden
# Same name diff ids: 8p5sv--xs46v
# Benjamin Rahm
# Same name diff ids: gvxqy--gmjz6
# Simine Vazire
# Same name diff ids: sx9ck--t82dp
# Giovanni Sala
# Same name diff ids: aey5m--sybwn
# suradi
# Same name diff ids: px8yw--9mvkj
# Sudirman
# Same name diff ids: vq5au--kzpuc
# Amal Akbar
# Same name diff ids: sybwn--aey5m
# suradi
# Same name diff ids: b476m--wgvcb
# Emilio Zagheni
# Same name diff ids: 9wy5z--96rts
# Mikael Cavallet
# Same name diff ids: gmjz6--gvxqy
# Simine Vazire
# Same name diff ids: vt5dm--xnve8
# Muhammad Tamrin
# Same name diff ids: h8tcz--f6xpb
# H. Rahman Mus
# Same name diff ids: 9mvkj--hpb5q
# Sudirman
# Same name diff ids: gsk7e--av2sn
# Aryati Arfah
# Same name diff ids: aqksf--g75yu
# Nur Azizah
# Same name diff ids: ep5dy--xapcq
# Hakwan Lau
# Same name diff ids: f6xpb--synwe
# H. Rahman Mus
# Same name diff ids: hpb5q--268us
# Sudirman
# Same name diff ids: av2sn--64qre
# Aryati Arfah
# Same name diff ids: ugz8v--ph43u
# Orsolya Inhof
# Same name diff ids: fj9s8--8d3yt
# Handoko
# Same name diff ids: 2uqc9--9hzex
# Serlin Serang
# Same name diff ids: u25rs--5nmy9
# H. Mursalim Umar Gani
# Same name diff ids: gtr75--3e7xb
# Susenohadi Purnomo
# Same name diff ids: 8d3c7--cv672
# Jürgen Margraf
# Same name diff ids: 62sxh--r9bnk
# Meng-Jou Ho
# Same name diff ids: 8aqyc--2mt6w
# Shoichiro Sato
# Same name diff ids: n6dvu--cmafh
# Jiei Kuroyanagi
# Same name diff ids: 2mt6w--zcy5d
# Shoichiro Sato
# Same name diff ids: vt2a3--fk7n4
# Tanya Clement
# Same name diff ids: qfph2--y9r27
# Nivethika Jeyakumar
# Same name diff ids: 2k94t--ufkmp
# Robert Kosara
# Same name diff ids: vzcdr--tguk9
# Julia M. Haaf
# Same name diff ids: urq2a--shkyu
# Triece Turnbull
# Same name diff ids: c3fr9--nrw3a
# Joshua M. Smyth
# Same name diff ids: zvcsg--vzw68
# Richard Ryan
# Same name diff ids: 2dnzv--5seya
# (Prosiding Seminar Nasional FKIP Univeristas PGRI Banyuwangi 2018)
# Same name diff ids: 5seya--2dnzv
# (Prosiding Seminar Nasional FKIP Univeristas PGRI Banyuwangi 2018)
# Same name diff ids: 3tucs--tj4y8
# Stevan Harnad
# Same name diff ids: 9uc3d--8mksc
# Indang Dewata
# Same name diff ids: bgeqr--b5qrg
# Budhi Oktavia
# Same name diff ids: g5r8t--2sqya
# Thomas A. Widiger
# Same name diff ids: mf75u--cbpnz
# Colin G. DeYoung
# Same name diff ids: 7p8rv--gm25r
# Abd. Mansyur Mus
# Same name diff ids: 5a4h6--6cn23
# Benjamin Bernard
# Same name diff ids: djb8s--tx5fg
# Susan Carey
# Same name diff ids: 3hd95--4yg2q
# Luciano Pederzoli
# Same name diff ids: 7nca3--e5w9a
# Ramadhan Sumarmin
# Same name diff ids: b7pqr--s2tpj
# Hardeli
# Same name diff ids: 82tpb--t2y3m
# Harry Sanjaya
# Same name diff ids: nhdeq--r8xcy
# Veronica Toffolutti
# Same name diff ids: 2tsx7--yuw6n
# Gary R. Turner
# Same name diff ids: axzc8--2e4wh
# Klaas Sijtsma
# Same name diff ids: y4vuf--avwsj
# Samliok Ndobe
# Same name diff ids: a75gq--2snq5
# Lisa Feldman Barrett
# Same name diff ids: pf4nt--3sw8k
# Hardianto Djanggih
# Same name diff ids: 9r4g7--vy59d
# Amber L. Martin
# Same name diff ids: rb3xq--x3wbq
# Youn-Jeng Choi
# Same name diff ids: 926zs--trn67
# Jayashree Balakrishna
# Same name diff ids: 4f39b--h8jqb
# Alia Azmi
# Same name diff ids: 6qpyg--ja56x
# Ike Sylvia
# Same name diff ids: yq9r3--d98hm
# Desy Mardhiah
# Same name diff ids: hdj63--5w6cp
# Han van der Maas
# Same name diff ids: 5a2yk--483ht
# Idrus Hentihu
# Same name diff ids: xtzvd--7dyrf
# Rosita Umanailo
# Same name diff ids: mxrth--5cbev
# Hamiru
# Same name diff ids: 9n6cu--bdsnj
# Mansyur Nawawi
# Same name diff ids: grv98--c2szx
# Sukainap Pulhehe
# Same name diff ids: ge5u4--jm942
# Mirja Ohoibor
# Same name diff ids: qm3fx--n2e4t
# Lutfi Rumkel
# Same name diff ids: 7ra58--gyswx
# Belinda Sam
# Same name diff ids: yf9cx--z5wrs
# Fatmawati
# Same name diff ids: 8srqa--rht6j
# Alan M. Friedlander
# Same name diff ids: hypmv--r5nvg
# Millary Agung Widiawaty
# Same name diff ids: aey5m--sybwn
# suradi
# Same name diff ids: 9qmwr--qt9pj
# Andrew Neal
# Same name diff ids: zj847--exgzj
# Taslim
# Same name diff ids: rjqph--uwnf4
# Mark Nielsen
# Same name diff ids: kcjpu--jg8yt
# santy karina
# Same name diff ids: jw6n9--p28e6
# Santirianingrum Soebandhi
# Same name diff ids: u8w2p--p5y8n
# agus mursidi
# Same name diff ids: p5y8n--u8w2p
# agus mursidi
# Same name diff ids: 9cg37--5u6wb
# Lauren Schroeder
# Same name diff ids: dw8vx--yrqqg
# Chandra
# Same name diff ids: b54fw--m9en8
# Daniel Vogel
# Same name diff ids: 5tpf4--ue6ks
# Taru Lintunen
# Same name diff ids: a9b6g--9fj5e
# Konrad Wegener
# Same name diff ids: 2ahp9--ewnhr
# Refki Prayoga
# Same name diff ids: b9ey5--pjzus
# Preston White
# Same name diff ids: c7wvr--9m2r4
# Gwenyth Portillo-Wightman
# Same name diff ids: zeq9h--46rpj
# William Therrien
# Same name diff ids: gb38v--xhgzt
# Elizabeth Evans
# Same name diff ids: 9vdpz--cr8qn
# Robert Parkhurst
# Same name diff ids: nyr89--zj9p5
# Mardiyono
# Same name diff ids: qmr8p--kw4n8
# Virginia Clinton
# Same name diff ids: a32bk--sp7w3
# Erik Rybacki
# Same name diff ids: dshcp--xwh2d
# Georg Dresen
# Same name diff ids: 6cdtk--m2ws6
# Ansori
# Same name diff ids: uahct--293qz
# Philip Dearden
# Same name diff ids: v6p5e--8exj9
# Robin Roth
# Same name diff ids: hzn62--rh832
# Yoshitaka Ota
# Same name diff ids: h6asx--fj6rt
# Carina Wyborn
# Same name diff ids: 2mk3c--3gujq
# Stefan Gelcich
# Same name diff ids: n9dzg--wtndk
# Muhammad Arifin
# Same name diff ids: 9ma4p--t3g7e
# Darmawan Napitupulu
# Same name diff ids: qg5td--wb6sp
# Davide Ghiglino
# Same name diff ids: 83jcg--n5bd3
# Ebru Baykara
# Same name diff ids: knxwj--a5xnw
# Irwanto
# Same name diff ids: tw6rb--w7b45
# Hasim
# Same name diff ids: a5xnw--knxwj
# Irwanto
# Same name diff ids: 2dvbq--ws7ja
# Wahyudi
# Same name diff ids: 3fvsa--b4vxh
# Bruno Pace
# Same name diff ids: ws7ja--ne5xt
# Wahyudi
# Same name diff ids: 6rxkd--9gnj7
# Hardi Alunaza
# Same name diff ids: dsczb--r6hqw
# Emma Suckling
# Same name diff ids: cmuht--zd5xy
# Ridwan
# Same name diff ids: tje95--h7c9t
# Ahmad Yani Abdurrahman
# Same name diff ids: kpaqj--be3ty
# Dyah Prabaningrum
# Same name diff ids: k26qn--qfa5j
# Hj. Syamsuryani Syahrir
# Same name diff ids: 2gwdt--w4d93
# T. ‘Aulani Wilhelm
# Same name diff ids: s2t4z--mpucv
# Olivier Collignon
# Same name diff ids: qte4m--bqgk9
# Denise Venturi
# Same name diff ids: t3g7e--9ma4p
# Darmawan Napitupulu
# Same name diff ids: 9ma4p--t3g7e
# Darmawan Napitupulu
# Same name diff ids: 3sw8k--pf4nt
# Hardianto Djanggih
# Same name diff ids: pf4nt--3sw8k
# Hardianto Djanggih
# Same name diff ids: r7kg9--uk2g3
# Warsono
# Same name diff ids: 5nmy9--ju59d
# H. Mursalim Umar Gani
# Same name diff ids: 45abv--taz57
# Hendrawan
# Same name diff ids: 6y39c--4s6w9
# Andi Sessu
# Same name diff ids: qsbcd--bpufw
# H. Richard Beresford
# Same name diff ids: q5d69--grzdh
# Zhicheng Wang
# Same name diff ids: jqew5--bej5f
# joyeeta ghose
# Same name diff ids: vazbc--d5ykq
# Eva Schemmel
# Same name diff ids: eafsj--czduw
# Birgit Elsner
# Same name diff ids: czduw--eafsj
# Birgit Elsner
# Same name diff ids: n4q32--a67gx
# Magdalena Żemojtel-Piotrowska
# Same name diff ids: v8epa--6cfg7
# Allison Brown
# Same name diff ids: vkm3n--xw6ht
# Anthony P. Zanesco
# Same name diff ids: eaz64--kwf3e
# Rahmat
# Same name diff ids: p2vs6--gvrd5
# Ivan Toni
# Same name diff ids: 5t4gp--9qtf2
# Kevin Robinson
# Same name diff ids: 3vcbg--fwha3
# Meredith Thompson
# Same name diff ids: 83whk--yqdj6
# Roberto Bottini
# Same name diff ids: fwha3--3vcbg
# Meredith Thompson
# Same name diff ids: nt5fe--jyzj9
# Fernando De la Torre
# Same name diff ids: jyzj9--nt5fe
# Fernando De la Torre
# Same name diff ids: 2rch5--3zavp
# Xin Chen
# Same name diff ids: 4tzhd--wngsr
# Marie Eikemo
# Same name diff ids: qt74n--73eqt
# Siri Leknes
# Same name diff ids: h4vwp--n2z8b
# Indra Agus Riyanto
# Same name diff ids: g8bsx--5y6ex
# Julian Savulescu
# Same name diff ids: vwkag--da7rm
# Syamsuddin Pasamai
# Same name diff ids: p4dzf--c4e2f
# Hasanuddin
# Same name diff ids: seud5--wzpgs
# Amrin Saragih
# Same name diff ids: gq2wv--3u84e
# Syamsul Alam
# Same name diff ids: rbyct--c9h4w
# Reginaldo Christophori Lake
# Same name diff ids: 6zpwx--j5rdu
# Sri Rahayu
# Same name diff ids: z6ydg--3qjkw
# Muchti Yuda Pratama
# Same name diff ids: gvxqy--gmjz6
# Simine Vazire
# Same name diff ids: duxyk--qdsvj
# Nelle Varoquaux
# Same name diff ids: j5rdu--w7xcr
# Sri Rahayu
# Same name diff ids: rgbw9--6a5fs
# Nadia Ika Purnama
# Same name diff ids: sa4dt--9fb7s
# C. Nathan DeWall
# Same name diff ids: rtfzx--87tvh
# Rilla Sovitriana
# Same name diff ids: gndzs--bcyf4
# Tegan Cruwys
# Same name diff ids: fcm97--5ev7y
# Paayal Ladwa
# Same name diff ids: p4b6f--kj53s
# Sarah Knight
# Same name diff ids: bzsva--365ya
# Beth D. Cohen
# Same name diff ids: v49gu--rw8qs
# Ibnu Hajar
# Same name diff ids: j4fu6--scyug
# Suleman
# Same name diff ids: h2wmj--yk2xs
# Muhammad Ichsan Ali
# Same name diff ids: nj395--pnxus
# Dr. Sharon E. Roberts
# Same name diff ids: yk2xs--3za52
# Muhammad Ichsan Ali
# Same name diff ids: wr4jf--v6b24
# Ahmad Hidayat
# Same name diff ids: v6b24--69feh
# Ahmad Hidayat
# Same name diff ids: b8x4j--esw2h
# Zaman Zaini
# Same name diff ids: e8224--5z9tk
# Gustaf Gredebäck
# Same name diff ids: 7xk93--pj3zr
# Jaakko Kuorikoski
# Same name diff ids: 9r5cd--3t9m3
# Tom Griffiths
# Same name diff ids: hyrnd--s2e3m
# Maryam Hafram
# Same name diff ids: xwp6s--qu6ce
# Josina I. B. Hutubessy
# Same name diff ids: zmgh3--hvmd3
# Wendy Stone
# Same name diff ids: csg4k--sfkuc
# James Davis
# Same name diff ids: tvn2a--mnarq
# Rudi Setiawan
# Same name diff ids: 524wb--ugn54
# Dewi Shinta Wulandari Lubis
# Same name diff ids: y49jz--h2b9x
# Maria Inman
# Same name diff ids: guhs7--nk9ef
# Sujat Sen
# Same name diff ids: sxc9w--nexps
# McLain Leonard
# Same name diff ids: 54e8p--wzqmk
# Stephen Snyder
# Same name diff ids: g75yu--aqksf
# Nur Azizah
# Same name diff ids: h2b9x--y49jz
# Maria Inman
# Same name diff ids: 24rvn--7v3je
# Michael Heise
# Same name diff ids: prvxq--f754z
# Mira Engel
# Same name diff ids: 3epcf--w4r9x
# Lisanne Braat
# Same name diff ids: gfyzw--539xw
# Sumarno Sumarno
# Same name diff ids: 6qusy--8btsa
# Rodrigo Cardenas
# Same name diff ids: zx75f--yb4cp
# Isabelle Doré
# Same name diff ids: tbxrh--7dn2s
# Katherine Wagner
# Same name diff ids: 2sqya--g5r8t
# Thomas A. Widiger
# Same name diff ids: f28qd--e5xyn
# Ferdinandus Christian
# Same name diff ids: 39smj--6v7qk
# Luca Collanega
# Same name diff ids: j6kbs--ak76d
# Yan Lavallée
# Same name diff ids: 87tvh--rtfzx
# Rilla Sovitriana
# Same name diff ids: rtfzx--87tvh
# Rilla Sovitriana
# Same name diff ids: g2z47--2dywp
# Jens David Ohlin
# Same name diff ids: eakhg--4fsc2
# Bahador Bahrami
# Same name diff ids: 2yngw--br3xs
# Yasmiati
# Same name diff ids: br3xs--2yngw
# Yasmiati
# Same name diff ids: m4u8j--dmcws
# Anthony Leiserowitz
# Same name diff ids: kgj68--wyc5x
# Alexander Williams
# Same name diff ids: n2my9--f2m4d
# Fernand Gobet
# Same name diff ids: gxcv8--3hz7b
# Julia Korkman
# Same name diff ids: jzmyv--ejbmf
# Thomas Nadelhoffer
# Same name diff ids: pdcwr--wxnja
# Azim Shariff
# Same name diff ids: pqsjw--cavs3
# Romain Jolivet
# Same name diff ids: 4vm93--7c3z2
# Mark Simons
# Same name diff ids: rbk9v--ar8mj
# Juliet Biggs
# Same name diff ids: xapcq--ep5dy
# Hakwan Lau
# Same name diff ids: 2j9f4--57a8h
# Humaizi
# Same name diff ids: kdzsr--u4kcx
# Devita Sari
# Same name diff ids: 4wcx7--s3jhe
# Junaidi
# Same name diff ids: pc4ur--jd4k9
# Peter C. Gordon
# Same name diff ids: 736kz--t9hv8
# Ann-Marie Golden
# Same name diff ids: zj9p5--fr9gu
# Mardiyono
# Same name diff ids: pcyxs--bnwha
# Richard Pollnac
# Same name diff ids: mhxj3--e7rzx
# Yuni Astuti
# Same name diff ids: wuqn2--bgws4
# Evangeline Rodrigues
# Same name diff ids: ymieu--96vnb
# Hanna Jarvinen
# Same name diff ids: wn4tp--gvamw
# Puji Lestari
# Same name diff ids: 5pu3r--gd2n4
# Suharto
# Same name diff ids: ucs32--ze6m2
# Brendan J Meade
# Same name diff ids: r5nvg--g6w8r
# Millary Agung Widiawaty
# Same name diff ids: 2snq5--a75gq
# Lisa Feldman Barrett
# Same name diff ids: 3atb9--zjn5d
# Grégory Lo Monaco
# Same name diff ids: 4kan6--4kdu5
# Syamsul Bahri
# Same name diff ids: c4kxq--25cwf
# SAID ABDURAHMAN ASSAGAF
# Same name diff ids: 483ht--9ez7y
# Idrus Hentihu
# Same name diff ids: bdsnj--s4ytg
# Mansyur Nawawi
# Same name diff ids: 5gh8x--gh68z
# Iskandar Hamid
# Same name diff ids: 7dyrf--zj39m
# Rosita Umanailo
# Same name diff ids: ysp2c--ectwn
# M. Bula
# Same name diff ids: 9ez7y--k7dz8
# Idrus Hentihu
# Same name diff ids: zj39m--5cdxg
# Rosita Umanailo
# Same name diff ids: 72hrq--c7s5d
# Edy Said Ningkeula
# Same name diff ids: s4ytg--r5qn7
# Mansyur Nawawi
# Same name diff ids: js6wd--kgu29
# La Jumu
# Same name diff ids: 7ch6k--kpqe4
# Husen Bahasoan
# Same name diff ids: f2hcn--qpt5r
# Said Abdurahman Assagaf
# Same name diff ids: gh68z--2sk8g
# Iskandar Hamid
# Same name diff ids: 2sk8g--bvt2z
# Iskandar Hamid
# Same name diff ids: c7s5d--jd4bc
# Edy Said Ningkeula
# Same name diff ids: k7dz8--95wgr
# Idrus Hentihu
# Same name diff ids: r5qn7--yrc85
# Mansyur Nawawi
# Same name diff ids: ectwn--yqgjx
# M. Bula
# Same name diff ids: 5cdxg--jnb6k
# Rosita Umanailo
# Same name diff ids: kgu29--j32qn
# La Jumu
# Same name diff ids: kpqe4--mzgsf
# Husen Bahasoan
# Same name diff ids: qpt5r--vjubs
# Said Abdurahman Assagaf
# Same name diff ids: yrc85--qwbgj
# Mansyur Nawawi
# Same name diff ids: 95wgr--fhdbq
# Idrus Hentihu
# Same name diff ids: bvt2z--xk9nd
# Iskandar Hamid
# Same name diff ids: jd4bc--mtc6s
# Edy Said Ningkeula
# Same name diff ids: yqgjx--7h964
# M. Bula
# Same name diff ids: jnb6k--z8jw4
# Rosita Umanailo
# Same name diff ids: j32qn--vhpws
# La Jumu
# Same name diff ids: mzgsf--n5v9p
# Husen Bahasoan
# Same name diff ids: vjubs--b9d23
# Said Abdurahman Assagaf
# Same name diff ids: as4fy--d6nqu
# Sina Mehdizadeh
# Same name diff ids: z8jw4--9ewg3
# Rosita Umanailo
# Same name diff ids: n5v9p--stjgn
# Husen Bahasoan
# Same name diff ids: mtc6s--x3n8g
# Edy Said Ningkeula
# Same name diff ids: b9d23--d2jwq
# Said Abdurahman Assagaf
# Same name diff ids: xk9nd--vxws3
# Iskandar Hamid
# Same name diff ids: qwbgj--2nhta
# Mansyur Nawawi
# Same name diff ids: fhdbq--fxg2m
# Idrus Hentihu
# Same name diff ids: 7h964--a3gkt
# M. Bula
# Same name diff ids: vhpws--hrnpv
# La Jumu
# Same name diff ids: d2jwq--cnztw
# Said Abdurahman Assagaf
# Same name diff ids: stjgn--jc5pq
# Husen Bahasoan
# Same name diff ids: 2nhta--m9ec8
# Mansyur Nawawi
# Same name diff ids: 9ewg3--bspgw
# Rosita Umanailo
# Same name diff ids: fxg2m--gdvqm
# Idrus Hentihu
# Same name diff ids: a3gkt--t285p
# M. Bula
# Same name diff ids: x3n8g--dxr4j
# Edy Said Ningkeula
# Same name diff ids: hrnpv--gtcjw
# La Jumu
# Same name diff ids: vxws3--2nrct
# Iskandar Hamid
# Same name diff ids: gdvqm--5fdq9
# Idrus Hentihu
# Same name diff ids: m9ec8--ucmxv
# Mansyur Nawawi
# Same name diff ids: t285p--srhcp
# M. Bula
# Same name diff ids: 2nrct--xwrbu
# Iskandar Hamid
# Same name diff ids: dxr4j--9pf32
# Edy Said Ningkeula
# Same name diff ids: bspgw--c7grh
# Rosita Umanailo
# Same name diff ids: gtcjw--chpwb
# La Jumu
# Same name diff ids: jc5pq--zh95f
# Husen Bahasoan
# Same name diff ids: cnztw--hv72y
# Said Abdurahman Assagaf
# Same name diff ids: a6qwp--cnx9p
# Xiang Zhou
# Same name diff ids: pygw6--trgf9
# Nick Rawlinson
# Same name diff ids: 3sw8k--pf4nt
# Hardianto Djanggih
# Same name diff ids: 5b6ze--jfcxp
# Zsolt Unoka
# Same name diff ids: nkuxq--djx94
# Mara J. Richman
# Same name diff ids: m2ws6--xmktd
# Ansori
# Same name diff ids: 7r82b--w6srm
# Siswanto
# Same name diff ids: svkxh--3s7kt
# David F. Bradley
# Same name diff ids: 5b7fd--pkr6t
# Torbjörn Åkerstedt
# Same name diff ids: 2qncv--b7cmt
# Mats Lekander
# Same name diff ids: 2cuy5--5ghzm
# David Watson
# Same name diff ids: gx5hr--j7ug8
# Gwendolyn Gardiner
# Same name diff ids: 3g7ux--tksmd
# Sara Álvarez Solas
# Same name diff ids: udmjf--fd4tp
# Ying Lin
# Same name diff ids: vb8qs--j4z89
# Insar Damopolii
# Same name diff ids: tguk9--vzcdr
# Julia M. Haaf
# Same name diff ids: znk25--6ndyb
# Thomas V. Maher
# Same name diff ids: 8e6a3--qytj7
# David Ziegler
# Same name diff ids: 65jfs--f9rph
# Stanimira Georgieva
# Same name diff ids: s293m--s2j7y
# Thomas Krennert
# Same name diff ids: wr9t4--kb6fx
# Matthew Cohen
# Same name diff ids: 5xj9c--uwv84
# Muhammad Shahbaz
# Same name diff ids: wytzr--w2aqs
# Ghulam Mustafa
# Same name diff ids: ua7wt--c8sza
# Tetty Natalia Sipayung
# Same name diff ids: 4yg2q--3hd95
# Luciano Pederzoli
# Same name diff ids: 9p3w7--d92kv
# Manh-Tung Ho
# Same name diff ids: vzcdr--tguk9
# Julia M. Haaf
# Same name diff ids: axnzr--b896w
# Beth Lyon
# Same name diff ids: 6cfg7--v8epa
# Allison Brown
# ...
# Salim Basalamah
# Same name diff ids: yfdcp--mfd2x
# Eko Sumartono
# Same name diff ids: 7yz5v--2hauc
# Fitriani
# Same name diff ids: qce2b--mwp3h
# Purwarno
# Same name diff ids: dxhrw--ex8k2
# Andreas Roepstorff
# Same name diff ids: nge7z--6dtev
# Setyawan Purnama
# Same name diff ids: 3ve4n--sb9ve
# Enjang A Djuanda
# Same name diff ids: t2mgb--3bx24
# Nick Todd
# Same name diff ids: g5pxa--ph96m
# Kusnandar
# Same name diff ids: jpbkt--78ck9
# Michael C. Frank
# Same name diff ids: xn92w--wgmr9
# Rebecca Saxe
# Same name diff ids: xtvju--aesyv
# Margaret E. Collinson
# Same name diff ids: j5m4k--2jpa9
# Neil F. Adams
# Same name diff ids: tshg4--qn3tr
# Steven R. Manchester
# Same name diff ids: 4c3r2--vcnwr
# Gregory W. Stull
# Same name diff ids: rukmx--8ahyj
# Dan Sykes
# Same name diff ids: n9t8e--hxc5u
# Peter Kramer
# Same name diff ids: p85x7--zwtqr
# Paola Bressan
# Same name diff ids: zwtqr--w4cxn
# Paola Bressan
# Same name diff ids: wbmrv--jzyds
# Jorge Martinez-Gil
# Same name diff ids: e7sfg--q7n9m
# Klaus-Dieter Schewe
# Same name diff ids: k8y67--5kq6z
# Romza Fauzan Agniy
# Same name diff ids: jzyds--wbmrv
# Jorge Martinez-Gil
# Same name diff ids: s25za--ge3z9
# Robert Guggenberger
# Same name diff ids: 3uygn--udjyp
# Alejandra Lorena Paoletti
# Same name diff ids: wbmrv--dxtc6
# Jorge Martinez-Gil
# Same name diff ids: q7n9m--tvfjc
# Klaus-Dieter Schewe
# Same name diff ids: vd528--7znyu
# Sunarto
# Same name diff ids: 5mske--r4fx9
# Uta Frith
# Same name diff ids: r4fx9--ajuw6
# Uta Frith
# Same name diff ids: ajuw6--q9edc
# Uta Frith
# Same name diff ids: dxtc6--wbmrv
# Jorge Martinez-Gil
# Same name diff ids: wbmrv--fdh3c
# Jorge Martinez-Gil
# Same name diff ids: udjyp--hvaky
# Alejandra Lorena Paoletti
# Same name diff ids: tvfjc--6bvre
# Klaus-Dieter Schewe
# Same name diff ids: a65j8--bxctk
# Bayu Argadyanto Prabawa
# Same name diff ids: fdh3c--wbmrv
# Jorge Martinez-Gil
# Same name diff ids: wgx69--4ux2s
# Tommy Andryan Tivianton
# Same name diff ids: ufh4k--s4mwq
# Dejan Brkić
# Same name diff ids: s4mwq--x3gsh
# Dejan Brkić
# Same name diff ids: x3gsh--s7zmb
# Dejan Brkić
# Same name diff ids: s7zmb--htsw7
# Dejan Brkić
# Same name diff ids: htsw7--mjshw
# Dejan Brkić
# Same name diff ids: mjshw--9quk4
# Dejan Brkić
# Same name diff ids: 9quk4--a6dqg
# Dejan Brkić
# Same name diff ids: a6dqg--vzqt7
# Dejan Brkić
# Same name diff ids: vzqt7--8uytz
# Dejan Brkić
# Same name diff ids: 8uytz--zxw57
# Dejan Brkić
# Same name diff ids: zxw57--tfb7h
# Dejan Brkić
# Same name diff ids: tfb7h--spjvg
# Dejan Brkić
# Same name diff ids: spjvg--bhpx9
# Dejan Brkić
# Same name diff ids: bhpx9--ktbc8
# Dejan Brkić
# Same name diff ids: ktbc8--tb72r
# Dejan Brkić
# Same name diff ids: tb72r--tw786
# Dejan Brkić
# Same name diff ids: tw786--byja5
# Dejan Brkić
# Same name diff ids: byja5--psyxa
# Dejan Brkić
# Same name diff ids: psyxa--86hej
# Dejan Brkić
# Same name diff ids: 86hej--gjzn5
# Dejan Brkić
# Same name diff ids: gjzn5--nmb8d
# Dejan Brkić
# Same name diff ids: hryd8--gxe7u
# Žarko Ćojbašić
# Same name diff ids: nmb8d--vcpq3
# Dejan Brkić
# Same name diff ids: gxe7u--pqy8x
# Žarko Ćojbašić
# Same name diff ids: vcpq3--eghjp
# Dejan Brkić
# Same name diff ids: j8fxh--u8bqz
# Brkic Dejan
# Same name diff ids: eghjp--y8pbu
# Dejan Brkić
# Same name diff ids: 36g9n--dxv5z
# José F. Aldana-Montes
# Same name diff ids: dxv5z--h4rc5
# José F. Aldana-Montes
# Same name diff ids: j7cw4--3ru9a
# P. Senthil Kumar
# Same name diff ids: em3t8--esuqb
# Alex Huynh
# Same name diff ids: puz39--8njd3
# Ichio Kikuchi
# Same name diff ids: 95hcm--kj29c
# Evgeny Perkovsky
# Same name diff ids: fv3na--8k5sd
# Slamet Suprayogi
# Same name diff ids: bxctk--a65j8
# Bayu Argadyanto Prabawa
# Same name diff ids: 8k5sd--4y3e8
# Slamet Suprayogi
# Same name diff ids: 6dtev--nge7z
# Setyawan Purnama
# Same name diff ids: tr7v2--6acjf
# Maria Fissler
# Same name diff ids: 5jmfe--vew5z
# Emilya Nurjani
# Same name diff ids: 63aud--t5pe8
# Suprapto Dibyosaputro
# Same name diff ids: 5kq6z--k8y67
# Romza Fauzan Agniy
# Same name diff ids: ctvbq--3r4ba
# Anggit Priadmodjo
# Same name diff ids: e8j3f--849mg
# Adnan Abumahfouz
# Same name diff ids: mdekt--6hydc
# Meghan Donahue
# Same name diff ids: w4y9g--m95p8
# Sharifuddin Bin Andy Omar
# Same name diff ids: c3txp--4kynz
# Lodewyck S Tandipayuk
# Same name diff ids: x8d4v--vkf7b
# Ariel Rokem
# Same name diff ids: bcpez--h8n7c
# Amanda Morrison
# Same name diff ids: 6acjf--kpqc4
# Maria Fissler
# Same name diff ids: cm9re--6ujhz
# Paul Chadwick
# Same name diff ids: vg2rn--df9ca
# Matthew Jones
# Same name diff ids: vryg9--jaer2
# Adnan
# Same name diff ids: cvz56--tsj89
# Hartono
# Same name diff ids: yujp9--5gurf
# Dwatmadji Dwatmadji
# Same name diff ids: k8y67--5kq6z
# Romza Fauzan Agniy
# Same name diff ids: 86as2--6efu3
# Tjahyo Nugroho Adji
# Same name diff ids: 2hauc--a3nbx
# Fitriani
# Same name diff ids: md2af--nvswx
# Laurent Bienvenu
# Same name diff ids: c2srh--m62fc
# Damien Desfontaines
# Same name diff ids: rfauw--86ayz
# Alexander Shen
# Same name diff ids: m62fc--95en8
# Damien Desfontaines
# Same name diff ids: up5mf--7sx3j
# Cristian S. Calude
# Same name diff ids: 95en8--zk4pn
# Damien Desfontaines
# Same name diff ids: nbtmf--8krup
# Antonin Delpeuch
# Same name diff ids: 2sv9u--juadt
# Jennifer Joy-Gaba
# Same name diff ids: r9yfe--nrtu5
# Aditya Pratama
# Same name diff ids: 8krup--243w5
# Antonin Delpeuch
# Same name diff ids: 6efu3--3w5pn
# Tjahyo Nugroho Adji
# Same name diff ids: 5k8ub--x4eks
# Zainal Arifin
# Same name diff ids: 4br2z--uafxc
# Yulianto
# Same name diff ids: 4kgz9--xs5va
# Indah Fitri Astuti
# Same name diff ids: 29bgy--tsd37
# Septya Maharani
# Same name diff ids: x4eks--xa7ne
# Zainal Arifin
# Same name diff ids: tsd37--29bgy
# Septya Maharani
# Same name diff ids: xs5va--4kgz9
# Indah Fitri Astuti
# Same name diff ids: 4kgz9--xs5va
# Indah Fitri Astuti
# Same name diff ids: pbv6g--jd659
# Muhammad Ridwan
# Same name diff ids: xa7ne--x4eks
# Zainal Arifin
# Same name diff ids: uafxc--xfh63
# Yulianto
# Same name diff ids: xs5va--4kgz9
# Indah Fitri Astuti
# Same name diff ids: 29bgy--tsd37
# Septya Maharani
# Same name diff ids: m95p8--4udtr
# Sharifuddin Bin Andy Omar
# Same name diff ids: dpcza--z63r4
# Nur Aini
# Same name diff ids: xfh63--uafxc
# Yulianto
# Same name diff ids: ukmzv--6j9cv
# Fahrul Agus
# Same name diff ids: 4kgz9--a863r
# Indah Fitri Astuti
# Same name diff ids: pu7jy--g5kpj
# Awang Harsa Kridalaksana
# Same name diff ids: x4eks--8rmd9
# Zainal Arifin
# Same name diff ids: k9bf2--n27yc
# Dewi Satria Ahmar
# Same name diff ids: em83n--xv528
# Ramlawati
# Same name diff ids: 78ck9--jpbkt
# Michael C. Frank
# Same name diff ids: yu9kt--xyqs2
# Richard E. Lucas
# Same name diff ids: erx72--3wj9n
# Mathew Hardy
# Same name diff ids: brpxy--v8zyk
# Charley M. Wu
# Same name diff ids: 5p8ex--938pv
# Ap Dijksterhuis
# Same name diff ids: ja47w--e2dy8
# Andrew Marty
# Same name diff ids: p3z2s--7atwm
# Cade McCall
# Same name diff ids: q97k4--hge29
# Bradly Alicea
# Same name diff ids: y47ve--sjyf4
# Andrew Butler
# Same name diff ids: dspxk--5nwm8
# Giuseppe Pagnoni
# Same name diff ids: 479p5--ufknc
# Noel Struchiner
# Same name diff ids: h4tnf--8kcwm
# Matthew Spitzer
# Same name diff ids: tfvux--4zn5h
# Carolyn Moritz
# Same name diff ids: ps742--w8e3d
# Rhodri Cusack
# Same name diff ids: ugkyq--epwbm
# Azim Shariff
# Same name diff ids: esuqb--em3t8
# Alex Huynh
# Same name diff ids: 4rkwy--sg94y
# Ted Hopf
# Same name diff ids: wm6tj--vb5fk
# Ben Bradford
# Same name diff ids: 62nbv--k6zuq
# Kevin Feeney
# Same name diff ids: frvj7--d2key
# James Green
# Same name diff ids: 83hnw--yvktg
# Zoltan Dienes
# Same name diff ids: gmjz6--47sq5
# Simine Vazire
# Same name diff ids: djcwk--j75bv
# Utami Widiati
# Same name diff ids: 3z698--2mxwt
# Christopher Williams
# Same name diff ids: bkftg--3zas7
# Andre Sprengers
# Same name diff ids: x7zbk--h3fyp
# Cauligi S. Raghavendra
# Same name diff ids: dszhn--3xs5q
# Sriram Rao
# Same name diff ids: xth75--fj5nq
# Srikanth Kandula
# Same name diff ids: es924--m84sj
# Xiang Wang
# Same name diff ids: f2dvs--jy944
# Franz J. Neyer
# Same name diff ids: bkj6p--8hm3s
# Marisa Ponti
# Same name diff ids: zmtav--mr2t9
# Joseph Hackman
# Same name diff ids: 8kcwm--h4tnf
# Matthew Spitzer
# Same name diff ids: mqwhj--m73fb
# Alyssa Napier
# Same name diff ids: 569mu--rfwq9
# Garrett Beazley
# Same name diff ids: w7frf--xqntc
# Mark Brandt
# Same name diff ids: wyc5x--kgj68
# Alexander Williams
# Same name diff ids: gb4jr--z8ep2
# Peter Clutton
# Same name diff ids: j2c8g--wn5u2
# Amelia Aldao
# Same name diff ids: rjkvp--9nmde
# Philipp Kanske
# Same name diff ids: fvcwg--cxv32
# Maria Letizia Tanturri
# Same name diff ids: e2av5--swc98
# Kesiena Owho-Ovuakporie
# Same name diff ids: 83hfr--khnsw
# Sital Kalantry
# Same name diff ids: dsrcv--fme2z
# Matthew Harris
# Same name diff ids: et7ah--8rw37
# Jennifer S. Weinstein
# Same name diff ids: wep9y--va565
# Liam Heaphy
# Same name diff ids: 4hfrg--kqyha
# Jeffrey Lienert
# Same name diff ids: q98fz--u335j
# Sophie A. Lazarus
# Same name diff ids: 3bekv--m99px
# Juneman Abraham
# Same name diff ids: 6u4fx--7u9xc
# Carl W. Tobias
# Same name diff ids: h4tnf--8kcwm
# Matthew Spitzer
# Same name diff ids: tp5k2--2x5eg
# Guilherme Duarte
# Same name diff ids: tfmzk--ky9j7
# Katinka Dijkstra
# Same name diff ids: qdcss--gwnjy
# Stefan Bode
# Same name diff ids: hs7ql--9nwau
# Richard D. Morey
# Same name diff ids: av4he--3kf7p
# Colin Bannard
# Same name diff ids: 9nwau--hs7ql
# Richard D. Morey
# Same name diff ids: w8e3d--ps742
# Rhodri Cusack
# Same name diff ids: 47sq5--gmjz6
# Simine Vazire
# Same name diff ids: prjd6--r4sb3
# Rowena Conroy
# Same name diff ids: e2dy8--u8d4d
# Andrew Marty
# Same name diff ids: m7fae--vt572
# Airil Haimi Mohd Adnan
# Same name diff ids: csw2z--y479c
# Abdulrahman M. Alshabeb
# Same name diff ids: c7t5b--t3df5
# Muhammad Aslam Sipra
# Same name diff ids: e4fb9--p9du4
# Ting Zhou
# Same name diff ids: 62gf4--nqrwf
# Robert Krueger
# Same name diff ids: xqntc--w7frf
# Mark Brandt
# Same name diff ids: 5e3yj--48x92
# Hilde Augusteijn
# Same name diff ids: gwnjy--qdcss
# Stefan Bode
# Same name diff ids: 6kdhk--9agr2
# Roman Kotov
# Same name diff ids: nqrwf--62gf4
# Robert Krueger
# Same name diff ids: 5ghzm--smd9z
# David Watson
# Same name diff ids: ky5nf--kjppb
# Bruce Milliken
# Same name diff ids: vnqsp--cdghr
# Maria C. D'Angelo
# Same name diff ids: pxs45--h2bwa
# Stephanie McKee
# Same name diff ids: eh64c--h5m6v
# Rashid Yahiaoui
# Same name diff ids: 7c2rt--8z7hb
# Eyhab Abdulrazak Bader Eddin
# Same name diff ids: pmu83--w2zqr
# Eric Rassin
# Same name diff ids: 2g8ch--pevqy
# Kingson Man
# Same name diff ids: jwh5v--hzn34
# Andrew Gordon
# Same name diff ids: mfs2g--8v9rw
# Antonio Damasio
# Same name diff ids: j5sur--y9p87
# Gunter Maris
# Same name diff ids: 9e4x7--5n2qh
# Joris Mulder
# Same name diff ids: 92r5w--hn3np
# Emilio Ferrer
# Same name diff ids: ypv5t--76zwt
# Ophelia Deroy
# Same name diff ids: q6dn7--3fbp9
# Deepak Malghan
# Same name diff ids: 469df--g687q
# Matthew Wigdahl
# Same name diff ids: h2ggr--adqzq
# Geoffrey Fitzgibbon Hughes
# Same name diff ids: 6cxyn--fsv5q
# Claire Noble
# Same name diff ids: p2edx--p7t82
# Khalid Shahu
# Same name diff ids: 4thx3--bmzxg
# Rusma Noortyani
# Same name diff ids: cfsv7--6jauu
# Mangala Subramaniam
# Same name diff ids: b739j--nq89k
# Hans M. Koot
# Same name diff ids: wavzv--yqkfc
# Dick Kasperowski
# Same name diff ids: zx8n7--6qbyq
# Christopher Kullenberg
# Same name diff ids: 3tg5x--yfpf3
# Christopher Lucas
# Same name diff ids: g7j9q--ysqjq
# Franklin Chang
# Same name diff ids: m9nf3--u2n6d
# Seeta Peña Gangadharan
# Same name diff ids: aqn6k--k9ajw
# Elizabeth Dunn
# Same name diff ids: xbpjq--rddqq
# Christopher Keys
# Same name diff ids: 6t24g--24gde
# Yi Zhang
# Same name diff ids: hp6fg--zwspf
# Walter Boot
# Same name diff ids: whs28--4w4j4
# Lionel Chevolot
# Same name diff ids: zv43x--rzxqb
# Anna Papafragou
# Same name diff ids: e4gaq--zac7q
# Lennart Schalk
# Same name diff ids: 9x42y--nmk43
# Herbert Schriefers
# Same name diff ids: kx5r9--cj9rd
# Alexander Holland
# Same name diff ids: juadt--2sv9u
# Jennifer Joy-Gaba
# Same name diff ids: 8vdqk--tem23
# Hugh Herr
# Same name diff ids: psu6r--tfw3c
# Tim Schwanen
# Same name diff ids: 2xwnu--vj6fz
# David Banister
# Same name diff ids: 48x92--5e3yj
# Hilde Augusteijn
# Same name diff ids: z423c--fd9qg
# Kunio Yoshikawa
# Same name diff ids: h2kxc--qau56
# Lara Stas
# Same name diff ids: hj732--92483
# David Barner
# Same name diff ids: 4wu3m--ud3eg
# Yann Algan
# Same name diff ids: s7ycs--jswj3
# Nicolas Baumard
# Same name diff ids: d48c3--xh48u
# Carl Schmertmann
# Same name diff ids: rf2sa--ysscb
# Jeff Potter
# Same name diff ids: xgzck--wcm6n
# Andrea Vest Ettekal
# Same name diff ids: vfjgd--jmvtm
# Anthony B. Atkinson
# Same name diff ids: 9xteb--ssuyp
# Joan Costa-Font
# Same name diff ids: 5xgvk--u8vaw
# Frank Cowell
# Same name diff ids: uk8ap--iaucv
# Stuart Buck
# Same name diff ids: f97gk--mwbq5
# Jeremy Freese
# Same name diff ids: s96wi--a4fwy
# Macartan Humphreys
# Same name diff ids: vy36w--q35mx
# Marcia McNutt
# Same name diff ids: a4w6e--kdxc4
# Katharine Tillman
# Same name diff ids: 92483--mf8ew
# David Barner
# Same name diff ids: mf8ew--ev8qm
# David Barner
# Same name diff ids: ev8qm--w3sx6
# David Barner
# Same name diff ids: re398--2g5fv
# Alan Bale
# Same name diff ids: w3sx6--83azg
# David Barner
# Same name diff ids: 83azg--h496p
# David Barner
# Same name diff ids: 6nmfw--2x37p
# Peggy Li
# Same name diff ids: h496p--yqkw8
# David Barner
# Same name diff ids: yqkw8--gfk7d
# David Barner
# Same name diff ids: gfk7d--z395x
# David Barner
# Same name diff ids: 2x37p--czea5
# Peggy Li
# Same name diff ids: z395x--jbkq4
# David Barner
# Same name diff ids: czea5--x92rw
# Peggy Li
# Same name diff ids: eukyr--7hgqj
# Jesse Snedeker
# Same name diff ids: jbkq4--765xe
# David Barner
# Same name diff ids: 75ehm--fujng
# Asaf Bachrach
# Same name diff ids: 765xe--8cykb
# David Barner
# Same name diff ids: x92rw--r62mv
# Peggy Li
# Same name diff ids: 8cykb--pe4sx
# David Barner
# Same name diff ids: pe4sx--xqhv9
# David Barner
# Same name diff ids: 2g5fv--3ausy
# Alan Bale
# Same name diff ids: xqhv9--4kzjg
# David Barner
# Same name diff ids: x6qgy--s2z4f
# Shunji Inagaki
# Same name diff ids: 4kzjg--d4ujr
# David Barner
# Same name diff ids: r62mv--52xtb
# Peggy Li
# Same name diff ids: d4ujr--ngqwu
# David Barner
# Same name diff ids: yav7u--wr53k
# Shu-Ju Yang
# Same name diff ids: tx5fg--sbyhx
# Susan Carey
# Same name diff ids: 52xtb--sgxrz
# Peggy Li
# Same name diff ids: ngqwu--hf9gj
# David Barner
# Same name diff ids: hf9gj--fa7g2
# David Barner
# Same name diff ids: 7hgqj--ny7du
# Jesse Snedeker
# Same name diff ids: fa7g2--dt6yq
# David Barner
# Same name diff ids: ny7du--q5n62
# Jesse Snedeker
# Same name diff ids: dt6yq--r3ub4
# David Barner
# Same name diff ids: uq9dy--ju6fp
# Justin Wood
# Same name diff ids: sbyhx--dmgy9
# Susan Carey
# Same name diff ids: r3ub4--gvqmu
# David Barner
# Same name diff ids: gvqmu--fzqd2
# David Barner
# Same name diff ids: fzqd2--e3qs5
# David Barner
# Same name diff ids: ju6fp--vkxm6
# Justin Wood
# Same name diff ids: wr53k--afwjz
# Shu-Ju Yang
# Same name diff ids: dmgy9--2r6bs
# Susan Carey
# Same name diff ids: 2rw7k--k83gp
# Marc D. Hauser
# Same name diff ids: e3qs5--ymwbe
# David Barner
# Same name diff ids: ymwbe--cw862
# David Barner
# Same name diff ids: cw862--3fpr7
# David Barner
# Same name diff ids: 48dka--5e4rt
# Jesses Snedeker
# Same name diff ids: 3fpr7--hj732
# David Barner
# Same name diff ids: 3ausy--a9346
# Alan Bale
# Same name diff ids: hj732--q3uc6
# David Barner
# Same name diff ids: 6p2bd--mx63k
# Alan C. Bale
# Same name diff ids: q3uc6--25adp
# David Barner
# Same name diff ids: 7dn2s--tbxrh
# Katherine Wagner
# Same name diff ids: 25adp--hj732
# David Barner
# Same name diff ids: ypk56--wru4q
# Charles Crabtree
# Same name diff ids: wru4q--ypk56
# Charles Crabtree
# Same name diff ids: dc7vi--mq7kt
# George Alvarez
# Same name diff ids: j4m4g--a8jbg
# Mahesh Srinivasan
# Same name diff ids: qupz6--7ewkp
# Mahmudur Rahman
# Same name diff ids: eg7qi--6g8jx
# Shige Oishi
# Same name diff ids: sieb9--vna7r
# Maddalena Marini
# Same name diff ids: 4ysqf--j4hzv
# Larisa Heiphetz
# Same name diff ids: 6mevw--mg6fj
# Hartmut Wessler
# Same name diff ids: mg6fj--tg5ja
# Hartmut Wessler
# Same name diff ids: tg5ja--5u48t
# Hartmut Wessler
# Same name diff ids: 8m6nb--fnqw8
# Charlotte Löb
# Same name diff ids: hj2az--8v9qf
# Bryan Ranger
# Same name diff ids: t7pnc--w3dms
# Mark Taylor
# Same name diff ids: wh69g--kuqvh
# Jill Yavorsky
# Same name diff ids: gpybm--cndg5
# Yue Hu
# Same name diff ids: yjf7g--ds64k
# Kevan Hudson
# Same name diff ids: bgd36--3twkh
# Jungmin Song
# Same name diff ids: usrt5--wqan7
# Dong Erico Yu
# Same name diff ids: pdjsw--cemr7
# Amanda Visconti
# Same name diff ids: 9rzgp--78tru
# Brandon Butler
# Same name diff ids: r9tp5--e4y4d
# Joe Karaganis
# Same name diff ids: hxnwv--v8pxg
# Maximilian Heimstädt

# %%
rec
# Out:
# 61152

# %%
no_rec
# Out:
# 62

# %%
for record in osf_records:
    if record['id'] == 'bmp89':
        print(record.keys())
# Out:
# dict_keys(['id', 'doi', 'osf_record', 'osf_authors', 'crossref_preprint', 'crossref_peerrev_publications', 'osf_peerrev_publications', 'crossref_search_results'])

# %%
duplicate_titles = 0

records_with_duplicate_title = []

duplicate_titles_same_authors = {}
duplicate_titles_same_first_authors = {}

records_with_duplicate_titles_same_authors = []
records_with_duplicate_titles_same_first_author = []

records_from_inarxiv = set()

for title, records in titles.items():
    if len(records) > 1:
        duplicate_titles += 1
        
        records_with_duplicate_title.append({ 'title' : title, 'records' : len(records) })

        for i in range(len(records)):
            for j in range(i + 1, len(records)):

                if len(records[i]['authors']) == len(records[j]['authors']):
                    same_authors = True
                    
                    for k in range(len(records[i]['authors'])):
                        if records[i]['authors'][k] != records[j]['authors'][k]:
                            same_authors = False
                            break
                    
                    if same_authors:
                        records_with_duplicate_titles_same_authors.append({ 'title' : title,
                                                                          'id_1' : 'osf.io/' + records[i]['id'],
                                                                          'id_2' : 'osf.io/' + records[j]['id']})
                        
                        if title not in duplicate_titles_same_authors:
                            duplicate_titles_same_authors[title] = set()
                        
                        duplicate_titles_same_authors[title].add(records[i]['id'])
                        duplicate_titles_same_authors[title].add(records[j]['id'])
                        
                        if records[i]['server'] == 'inarxiv':
                            records_from_inarxiv.add(records[i]['id'])
                        if records[j]['server'] == 'inarxiv':
                            records_from_inarxiv.add(records[j]['id'])
                        
                        
                    elif len(records[i]['authors']) > 0 and len(records[j]['authors']) > 0 and \
                            records[i]['authors'][0] == records[j]['authors'][0]:
                            records_with_duplicate_titles_same_first_author.append({ 'title' : title,
                                                                          'id_1' : 'osf.io/' + records[i]['id'],
                                                                          'id_2' : 'osf.io/' + records[j]['id']})
                            
                            if title not in duplicate_titles_same_first_authors:
                                duplicate_titles_same_first_authors[title] = set()

                            duplicate_titles_same_first_authors[title].add(records[i]['id'])
                            duplicate_titles_same_first_authors[title].add(records[j]['id'])
                            
                elif len(records[i]['authors']) > 0 and len(records[j]['authors']) > 0 and \
                            records[i]['authors'][0] == records[j]['authors'][0]:
                            records_with_duplicate_titles_same_first_author.append({ 'title' : title,
                                                                          'id_1' : 'osf.io/' + records[i]['id'],
                                                                          'id_2' : 'osf.io/' + records[j]['id']})
                            if title not in duplicate_titles_same_first_authors:
                                duplicate_titles_same_first_authors[title] = set()

                            duplicate_titles_same_first_authors[title].add(records[i]['id'])
                            duplicate_titles_same_first_authors[title].add(records[j]['id'])
                    
duplicate_titlesWe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-272-31ffcc1de939> in <module>()
#      66                             duplicate_titles_same_first_authors[title].add(records[j]['id'])
#      67
# ---> 68 duplicate_titlesWe
#
# NameError: name 'duplicate_titlesWe' is not defined

# %%
osf_records[0]
# Out:
# {'id': 'a8ewc',
#  'doi': '10.31227/osf.io/a8ewc',
#  'osf_record': {'relationships': {'node': {'links': {'self': {'href': 'https://api.osf.io/v2/preprints/a8ewc/relationships/node/?format=json',
#       'meta': {}}}},
#    'files': {'links': {'related': {'href': 'https://api.osf.io/v2/preprints/a8ewc/files/?format=json',
#       'meta': {}}}},
#    'identifiers': {'links': {'related': {'href': 'https://api.osf.io/v2/preprints/a8ewc/identifiers/?format=json',
#       'meta': {}}}},
#    'contributors': {'links': {'related': {'href': 'https://api.osf.io/v2/preprints/a8ewc/contributors/?format=json',
#       'meta': {}}}},
#    'license': {'data': {'type': 'licenses', 'id': '563c1cf88c5e4a3877f9e96a'},
#     'links': {'related': {'href': 'https://api.osf.io/v2/licenses/563c1cf88c5e4a3877f9e96a/?format=json',
#       'meta': {}}}},
#    'citation': {'links': {'related': {'href': 'https://api.osf.io/v2/preprints/a8ewc/citation/?format=json',
#       'meta': {}}}},
#    'primary_file': {'data': {'type': 'files',
#      'id': '5cf1b7e28d6e05001868c097'},
#     'links': {'related': {'href': 'https://api.osf.io/v2/files/5cf1b7e28d6e05001868c097/?format=json',
#       'meta': {}}}},
#    'provider': {'links': {'related': {'href': 'https://api.osf.io/v2/providers/preprints/inarxiv/?format=json',
#       'meta': {}}}},
#    'requests': {'links': {'related': {'href': 'https://api.osf.io/v2/preprints/a8ewc/requests/?format=json',
#       'meta': {}}}},
#    'review_actions': {'links': {'related': {'href': 'https://api.osf.io/v2/preprints/a8ewc/review_actions/?format=json',
#       'meta': {}}}}},
#   'links': {'self': 'https://api.osf.io/v2/preprints/a8ewc/',
#    'html': 'https://osf.io/preprints/inarxiv/a8ewc/',
#    'preprint_doi': 'https://doi.org/10.31227/osf.io/a8ewc'},
#   'attributes': {'date_last_transitioned': '2019-05-31T23:36:36.244315',
#    'doi': None,
#    'description': 'Buku dengan judul Komitmen Kerja yang diterbitkan pada 01 April 2014 di Yogyakarta. Buku ini telah didaftarkan dan merupakan  Hak Kekayaan Intelektual (HKI)-Hak Cipta Buku Komitmen Kerja dengan nomor pendaftaran 068751',
#    'current_user_permissions': [],
#    'date_modified': '2019-05-31T23:41:42.539062',
#    'title': 'Hak Kekayaan Intelektual (HKI)-Hak Cipta Buku Komitmen Kerja',
#    'reviews_state': 'pending',
#    'is_preprint_orphan': False,
#    'license_record': {'copyright_holders': [''], 'year': '2019'},
#    'original_publication_date': '2014-06-26T17:00:00',
#    'date_published': '2019-05-31T23:36:36.244315',
#    'subjects': [[{'text': 'Social and Behavioral Sciences',
#       'id': '59bacaae54be81032c8d35e8'},
#      {'text': 'Psychology', 'id': '59bacabc54be81032c8d3856'},
#      {'text': 'Industrial and Organizational Psychology',
#       'id': '59bacac354be81032c8d39f8'}]],
#    'date_withdrawn': None,
#    'preprint_doi_created': '2019-05-31T23:41:42.473350',
#    'date_created': '2019-05-31T23:25:15.543120',
#    'public': True,
#    'tags': ['hak cipta', 'kekayaan intelektual', 'komitmen kerja'],
#    'is_published': True},
#   'type': 'preprints',
#   'id': 'a8ewc'},
#  'osf_authors': [[{'data': [{'relationships': {'preprint': {'data': {'type': 'preprints',
#          'id': 'a8ewc'},
#         'links': {'related': {'href': 'https://api.osf.io/v2/preprints/a8ewc/?format=json',
#           'meta': {}}}},
#        'users': {'data': {'type': 'users', 'id': 'jax92'},
#         'links': {'related': {'href': 'https://api.osf.io/v2/users/jax92/?format=json',
#           'meta': {}}}}},
#       'links': {'self': 'https://api.osf.io/v2/preprints/a8ewc/contributors/jax92/'},
#       'embeds': {'users': {'data': {'relationships': {'registrations': {'links': {'related': {'href': 'https://api.osf.io/v2/users/jax92/registrations/?format=json',
#              'meta': {}}}},
#           'quickfiles': {'links': {'download': {'href': 'https://files.osf.io/v1/resources/apfmzqn8jw/providers/osfstorage/?zip=',
#              'meta': {}},
#             'upload': {'href': 'https://files.osf.io/v1/resources/apfmzqn8jw/providers/osfstorage/',
#              'meta': {}},
#             'related': {'href': 'https://api.osf.io/v2/users/jax92/quickfiles/?format=json',
#              'meta': {}}}},
#           'groups': {'links': {'related': {'href': 'https://api.osf.io/v2/users/jax92/groups/?format=json',
#              'meta': {}}}},
#           'nodes': {'links': {'related': {'href': 'https://api.osf.io/v2/users/jax92/nodes/?format=json',
#              'meta': {}}}},
#           'institutions': {'links': {'self': {'href': 'https://api.osf.io/v2/users/jax92/relationships/institutions/?format=json',
#              'meta': {}},
#             'related': {'href': 'https://api.osf.io/v2/users/jax92/institutions/?format=json',
#              'meta': {}}}},
#           'preprints': {'links': {'related': {'href': 'https://api.osf.io/v2/users/jax92/preprints/?format=json',
#              'meta': {}}}}},
#          'links': {'self': 'https://api.osf.io/v2/users/jax92/',
#           'html': 'https://osf.io/jax92/',
#           'profile_image': 'https://secure.gravatar.com/avatar/ed87a44d4ac0c3617c9029882982f665?d=identicon'},
#          'attributes': {'family_name': 'Tentama',
#           'suffix': '',
#           'locale': 'en_US',
#           'date_registered': '2017-11-02T19:43:38.797567',
#           'middle_names': '',
#           'given_name': 'Fatwa',
#           'full_name': 'Fatwa Tentama',
#           'social': {},
#           'active': True,
#           'timezone': 'Asia/Bangkok',
#           'education': [],
#           'employment': []},
#          'type': 'users',
#          'id': 'jax92'}}},
#       'attributes': {'index': 0,
#        'unregistered_contributor': None,
#        'bibliographic': True,
#        'permission': 'admin'},
#       'type': 'contributors',
#       'id': 'a8ewc-jax92'}],
#     'links': {'first': None,
#      'last': None,
#      'prev': None,
#      'next': None,
#      'meta': {'total': 1, 'per_page': 10, 'total_bibliographic': 1}}}]],
#  'crossref_preprint': {'status': 'ok',
#   'message-type': 'work',
#   'message-version': '1.0.0',
#   'message': {'indexed': {'date-parts': [[2019, 6, 1]],
#     'date-time': '2019-06-01T00:12:21Z',
#     'timestamp': 1559347941465},
#    'posted': {'date-parts': [[2019, 5, 31]]},
#    'group-title': 'INA-Rxiv',
#    'reference-count': 0,
#    'publisher': 'Center for Open Science',
#    'license': [{'URL': 'https://creativecommons.org/licenses/by/4.0/legalcode',
#      'start': {'date-parts': [[2019, 5, 31]],
#       'date-time': '2019-05-31T00:00:00Z',
#       'timestamp': 1559260800000},
#      'delay-in-days': 0,
#      'content-version': 'unspecified'}],
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'short-container-title': [],
#    'abstract': '<p>Buku dengan judul Komitmen Kerja yang diterbitkan pada 01 April 2014 di Yogyakarta. Buku ini telah didaftarkan dan merupakan  Hak Kekayaan Intelektual (HKI)-Hak Cipta Buku Komitmen Kerja dengan nomor pendaftaran 068751</p>',
#    'DOI': '10.31227/osf.io/a8ewc',
#    'type': 'posted-content',
#    'created': {'date-parts': [[2019, 5, 31]],
#     'date-time': '2019-05-31T23:41:32Z',
#     'timestamp': 1559346092000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Hak Kekayaan Intelektual (HKI)-Hak Cipta Buku Komitmen Kerja'],
#    'prefix': '10.31227',
#    'author': [{'given': 'Fatwa',
#      'family': 'Tentama',
#      'sequence': 'first',
#      'affiliation': []}],
#    'member': '15934',
#    'container-title': [],
#    'original-title': [],
#    'deposited': {'date-parts': [[2019, 5, 31]],
#     'date-time': '2019-05-31T23:41:32Z',
#     'timestamp': 1559346092000},
#    'score': 1.0,
#    'subtitle': [],
#    'short-title': [],
#    'issued': {'date-parts': [[2019, 5, 31]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.31227/osf.io/a8ewc',
#    'relation': {},
#    'subtype': 'preprint'}},
#  'crossref_peerrev_publications': [],
#  'osf_peerrev_publications': None,
#  'crossref_search_results': [{'indexed': {'date-parts': [[2019, 6, 1]],
#     'date-time': '2019-06-01T00:41:49Z',
#     'timestamp': 1559349709744},
#    'posted': {'date-parts': [[2019, 6, 1]]},
#    'group-title': 'INA-Rxiv',
#    'reference-count': 0,
#    'publisher': 'Center for Open Science',
#    'license': [{'URL': 'https://creativecommons.org/licenses/by/4.0/legalcode',
#      'start': {'date-parts': [[2019, 6, 1]],
#       'date-time': '2019-06-01T00:00:00Z',
#       'timestamp': 1559347200000},
#      'delay-in-days': 0,
#      'content-version': 'unspecified'}],
#    'content-domain': {'domain': [], 'crossmark-restriction': False},
#    'abstract': '<p>Diktat Psikologi Umum 2 diterbitkan pada 01 Maret 2015 di Yogyakarta. Diktat Psikologi Umum 2 telah terdaftar dan  tercatat dalam Daftar Umum Ciptaan dengan nomor pendaftaran 078286</p>',
#    'DOI': '10.31227/osf.io/q74zb',
#    'type': 'posted-content',
#    'created': {'date-parts': [[2019, 6, 1]],
#     'date-time': '2019-06-01T00:17:49Z',
#     'timestamp': 1559348269000},
#    'source': 'Crossref',
#    'is-referenced-by-count': 0,
#    'title': ['Hak Kekayaan Intelektual (HKI)-Hak Cipta Diktat Psikologi Umum 2'],
#    'prefix': '10.31227',
#    'author': [{'given': 'Fatwa',
#      'family': 'Tentama',
#      'sequence': 'first',
#      'affiliation': []}],
#    'member': '15934',
#    'deposited': {'date-parts': [[2019, 6, 1]],
#     'date-time': '2019-06-01T00:17:49Z',
#     'timestamp': 1559348269000},
#    'score': 124.23788,
#    'issued': {'date-parts': [[2019, 6, 1]]},
#    'references-count': 0,
#    'URL': 'http://dx.doi.org/10.31227/osf.io/q74zb',
#    'subtype': 'preprint'}]}
