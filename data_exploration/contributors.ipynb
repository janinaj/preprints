# %%
import os, json
from collections import defaultdict

records_without_contributors = 0

contributor_fields = defaultdict(int)
unique_contributor_ids = set()

identifiers = { 'figshare' : 'http://figshare.com/authors/',
    'orcid' : 'http://orcid.org/',
    'gravatar' : 'http://secure.gravatar.com/avatar/',
    'mendeley' : 'http://www.mendeley.com/profiles/',
    'usgs' : 'urn://share/gov.usgs:',
    'doi' : 'http://dx.doi.org/',
    'api.osf' : 'http://api.osf.io/v2/institutions/',
    'osf' : 'http://osf.io/',
    'grid.ac' : 'http://www.grid.ac/institutes/',
    'issn' : 'urn://issn/',
    'isbn' : 'urn://isbn/',
    'csupomona' : 'http://www.csupomona.edu'
}

with open(os.path.join('..', '..', 'data', 'share-jan-2019.json')) as f:
    for line in f:
        data = json.loads(line)

        if 'contributors' in data['lists']:
            if len(data['lists']['contributors']) == 0:
                records_without_contributors += 1
            
            for contributor in data['lists']['contributors']:
                for field in contributor.keys():
                    fields[field] += 1
                    
            unique_contributor_ids.add(contributor['id'])

        else:
            records_without_contributors += 1

# %%
import os, json
from collections import defaultdict

records_without_contributors = 0

contributor_fields = defaultdict(int)
unique_contributor_ids = set()

identifiers = { 'figshare' : 'http://figshare.com/authors/',
    'orcid' : 'http://orcid.org/',
    'gravatar' : 'http://secure.gravatar.com/avatar/',
    'mendeley' : 'http://www.mendeley.com/profiles/',
    'usgs' : 'urn://share/gov.usgs:',
    'doi' : 'http://dx.doi.org/',
    'api.osf' : 'http://api.osf.io/v2/institutions/',
    'osf' : 'http://osf.io/',
    'grid.ac' : 'http://www.grid.ac/institutes/',
    'issn' : 'urn://issn/',
    'isbn' : 'urn://isbn/',
    'csupomona' : 'http://www.csupomona.edu'
}

with open(os.path.join('..', '..', 'data', 'share-jan-2019.json')) as f:
    for line in f:
        data = json.loads(line)

        if 'contributors' in data['lists']:
            if len(data['lists']['contributors']) == 0:
                records_without_contributors += 1
            
            for contributor in data['lists']['contributors']:
                for field in contributor.keys():
                    fields[field] += 1
                    
            unique_contributor_ids.add(contributor['id'])

        else:
            records_without_contributors += 1

# %%
records_without_contributors
# Out:
# 33

# %%
len(unique_contributor_ids)
# Out:
# 2200028

# %%
import os, json
from collections import defaultdict

duplicate_contributors = 0
records_with_duplicate_contributors = 0
no_order_cited = defaultdict(int)
records_with_contributor_discrepancies = 0

with open(os.path.join('..', '..', 'data', 'share-jan-2019.json')) as f:
    for line in f:
        data = json.loads(line)

        contributors = {}
        has_duplicate_contributor = False
        highest_order_cited = 0
        if 'contributors' in data['lists']:
            for contributor in data['lists']['contributors']:
                if contributor['type'] == 'person':
                    if not 'order_cited' in contributor:
                        no_order_cited[len(data['lists']['contributors'])] += 1
                    else:    
                        if contributor['order_cited'] not in contributors:
                            contributors[contributor['order_cited']] = [contributor]
                        else:
                            for dup_contributor in contributors[contributor['order_cited']]:
                                duplicate_contributors += 1
                                has_duplicate_contributor = True

                            contributors[contributor['order_cited']].append(contributor)
                    
                if 'order_cited' in contributor and int(contributor['order_cited']) > highest_order_cited:
                    highest_order_cited = int(contributor['order_cited'])
                    
            if has_duplicate_contributor:
                records_with_duplicate_contributors += 1
                
        if 'contributors' in data and highest_order_cited + 1 != len(data['contributors']):
            records_with_contributor_discrepancies += 1

# %%
duplicate_contributors
# Out:
# 70416014

# %%
records_with_duplicate_contributors
# Out:
# 454981

# %%
no_order_cited
# Out:
# defaultdict(int,
#             {4: 11574,
#              2: 5294,
#              3: 6709,
#              5: 12966,
#              10: 14211,
#              7: 12080,
#              6: 12700,
#              9: 12927,
#              20: 8096,
#              240: 156,
#              12: 13401,
#              13: 12090,
#              8: 15658,
#              15: 11351,
#              11: 13065,
#              1025: 16,
#              168: 306,
#              1030: 23,
#              16: 10393,
#              25: 5060,
#              5898: 88,
#              4568: 44,
#              4584: 90,
#              101: 382,
#              17: 9404,
#              14: 11239,
#              18: 9127,
#              21: 6697,
#              11746: 28,
#              52: 981,
#              100: 329,
#              19: 8480,
#              14732: 35,
#              113: 219,
#              26: 4652,
#              3069: 106,
#              62: 707,
#              166: 183,
#              73: 409,
# ...

# %%
records_with_contributor_discrepancies
# Out:
# 478439

# %%
import os, json
from collections import defaultdict

records_with_both_contributors_and_creators = 0
records_with_cc_discrepancies = 0

creators_with_no_order_cited = 0
contributors_with_no_order_cited = 0
both_with_no_order_cited = 0


with open(os.path.join('..', '..', 'data', 'share-jan-2019.json')) as f:
    for line in f:
        data = json.loads(line)

        has_creator = False
        has_contributor = False
        creator_has_no_order_cited = False
        contributor_has_no_order_cited = False
        
        highest_order_cited = 0
        
        if 'contributors' in data['lists']:
            for contributor in data['lists']['contributors']:
                if contributor['type'] == 'person':
                    if contributor['relation'] == 'creator':
                        has_creator = True
                        if 'order_cited' not in contributor:
                            creator_has_no_order_cited = True
                    elif contributor['relation'] == 'contributor':
                        has_contributor = True
                        if 'order_cited' not in contributor:
                            contributor_has_no_order_cited  = True
                            
                if 'order_cited' in contributor and int(contributor['order_cited']) > highest_order_cited:
                    highest_order_cited = int(contributor['order_cited'])
                        

        if has_creator and has_contributor:
            records_with_both_contributors_and_creators += 1
            
            if creator_has_no_order_cited and contributor_has_no_order_cited:
                both_with_no_order_cited += 1
            elif creator_has_no_order_cited:
                creators_with_no_order_cited += 1
            elif contributor_has_no_order_cited:
                contributors_with_no_order_cited += 1
            elif 'contributors' in data and highest_order_cited + 1 != len(data['contributors']):
                records_with_cc_discrepancies += 1

# %%
records_with_both_contributors_and_creators
# Out:
# 82732

# %%
both_with_no_order_cited
# Out:
# 0

# %%
creators_with_no_order_cited
# Out:
# 0

# %%
contributors_with_no_order_cited
# Out:
# 82157

# %%
records_with_cc_discrepancies
# Out:
# 489
